# %%
# %cd /mnt/FasterRCNN/faster-rcnn.pytorch
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# !pip install -r requirements.txt
# !pip install scipy==1.2.1
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting cython
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/48/bbca549da0b0f636c0f161e84d30172c40aafe99552680f297da7fedf102/Cython-0.29.24-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 863 kB/s eta 0:00:01
# Requirement already satisfied: cffi in /root/miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.14.0)
# Collecting opencv-python
#   Downloading https://mirrors.aliyun.com/pypi/packages/6b/73/a8921d221a673600dc744033786eeab56ed5116686a1b932b724a33003c6/opencv_python-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (49.9 MB)
#      |████████████████████████████████| 49.9 MB 1.2 MB/s eta 0:00:01     |███████▎                        | 11.3 MB 1.6 MB/s eta 0:00:24     |█████████▉                      | 15.4 MB 153 kB/s eta 0:03:45     |████████████████                | 24.9 MB 757 kB/s eta 0:00:34     |███████████████████████████▍    | 42.7 MB 3.9 MB/s eta 0:00:02
# Collecting scipy
#   Downloading https://mirrors.aliyun.com/pypi/packages/b5/6b/8bc0b61ebf824f8c3979a31368bbe38dd247590049a994ab0ed077cb56dc/scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.3 MB/s eta 0:00:01    |▎                               | 204 kB 1.6 MB/s eta 0:00:18
# Collecting msgpack
#   Downloading https://mirrors.aliyun.com/pypi/packages/b7/88/b0d0c339044360036e51d3afda0d2b0f9503087fddff8867496198b24cda/msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
#      |████████████████████████████████| 273 kB 992 kB/s eta 0:00:01
# Collecting easydict
#   Downloading https://mirrors.aliyun.com/pypi/packages/4c/c5/5757886c4f538c1b3f95f6745499a24bffa389a805dee92d093e2d9ba7db/easydict-1.9.tar.gz (6.4 kB)
# Collecting matplotlib
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/ec/3d77b10ac3d30590f5431fd2dc59c58d20c020af107b47f8974896afc5c9/matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 1.1 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading https://mirrors.aliyun.com/pypi/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 1.3 MB/s eta 0:00:01     |████████████████████▋           | 409 kB 1.3 MB/s eta 0:00:01
# Collecting tensorboardX
#   Downloading https://mirrors.aliyun.com/pypi/packages/99/0b/a26bbe92667c549d39c40b80c5ddec638fbae9521f04aeef26560e07e504/tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: pycparser in /root/miniconda3/lib/python3.7/site-packages (from cffi->-r requirements.txt (line 2)) (2.19)
# Collecting numpy>=1.14.5
#   Downloading https://mirrors.aliyun.com/pypi/packages/68/2d/0fe6592a96a1da097a33fb87b9618197c8a1801e84c7483fa7b93794a87c/numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 779 kB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.4.7)
# Collecting kiwisolver>=1.0.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/09/6b/6e567cb2e86d4e5939a9233f8734e26021b6a9c1bc4b1edccba236a84cc2/kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 2.0 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/41/07/ecb2a0d55460385163c82a4bd65263a00510966dddbd54876796bd18857c/Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 511 kB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading https://mirrors.aliyun.com/pypi/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.8.1)
# Collecting protobuf>=3.8.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/6e/62/eeec5be0b69442d2ffc7acdf54469fb4c76aa42288fe38decc537973a90a/protobuf-3.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 781 kB/s eta 0:00:01
# Requirement already satisfied: six in /root/miniconda3/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 7)) (1.14.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6349 sha256=66d08bcd6589517411d25c2aa93f1080166f8e79f08eb2c346c76abd0e269f1a
#   Stored in directory: /root/.cache/pip/wheels/fd/84/74/82b22ad24a25b8d076e622a39a4af726d0909790f5c299451c
# Successfully built easydict
# Installing collected packages: cython, numpy, opencv-python, scipy, msgpack, easydict, kiwisolver, pillow, cycler, matplotlib, pyyaml, protobuf, tensorboardX
# Successfully installed cycler-0.10.0 cython-0.29.24 easydict-1.9 kiwisolver-1.3.2 matplotlib-3.4.3 msgpack-1.0.2 numpy-1.21.2 opencv-python-4.5.3.56 pillow-8.3.2 protobuf-3.18.1 pyyaml-5.4.1 scipy-1.7.1 tensorboardX-2.4
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting scipy==1.2.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/3e/7e/5cee36eee5b3194687232f6150a89a38f784883c612db7f4da2ab190980d/scipy-1.2.1-cp37-cp37m-manylinux1_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 371 kB/s eta 0:00:01    |██████████▎                     | 8.0 MB 498 kB/s eta 0:00:34     |███████████▋                    | 8.9 MB 497 kB/s eta 0:00:32     |███████████████████             | 14.7 MB 401 kB/s eta 0:00:26     |███████████████████▎            | 14.9 MB 751 kB/s eta 0:00:14     |███████████████████▌            | 15.1 MB 751 kB/s eta 0:00:13     |████████████████████▎           | 15.7 MB 751 kB/s eta 0:00:13
# Requirement already satisfied: numpy>=1.8.2 in /root/miniconda3/lib/python3.7/site-packages (from scipy==1.2.1) (1.21.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
# Successfully installed scipy-1.2.1

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting pycocotools
#   Downloading https://mirrors.aliyun.com/pypi/packages/de/df/056875d697c45182ed6d2ae21f62015896fdb841906fe48e7268e791c467/pycocotools-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: setuptools>=18.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (45.2.0.post20200210)
# Requirement already satisfied: cython>=0.27.3 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (0.29.24)
# Requirement already satisfied: matplotlib>=2.1.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (3.4.3)
# Requirement already satisfied: numpy>=1.16 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.1)
# Requirement already satisfied: cycler>=0.10 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (8.3.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.3.2)
# Requirement already satisfied: six>=1.5 in /root/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.14.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272845 sha256=88d40bdaaf398af9aeea19b5f5a393d93525359a740915745485bb9d68cd47cf
#   Stored in directory: /root/.cache/pip/wheels/60/03/30/0cc037d5ac8ecd261e4c9e4fdb4f2c429074cd52a7a844c61e
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.2

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !conda install ipykernel -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# Warning: >10 possible package resolutions (only showing differing packages):
#   - https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   - defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   ... and othedone
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.7.5   |       h06a4308_1         113 KB  defaults
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB  defaults
#     conda-4.10.3               |   py37h06a4308_0         2.9 MB  defaults
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         179 KB  defaults
#     openssl-1.1.1l             |       h7f8727e_0         2.5 MB  defaults
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.7.5-h06a4308_1
#   certifi            conda-forge::certifi-2020.12.5-py37h8~ --> pkgs/main::certifi-2021.5.30-py37h06a4308_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.10.3-py37h06a4308_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1l-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ipykernel          conda-forge::ipykernel-5.4.2-py37h888~ --> pkgs/main::ipykernel-5.3.4-py37h5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# ipykernel-5.3.4      | 179 KB    | ##################################### | 100%
# ca-certificates-2021 | 113 KB    | ##################################### | 100%
# certifi-2021.5.30    | 139 KB    | ##################################### | 100%
# openssl-1.1.1l       | 2.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torch
#   Downloading https://mirrors.aliyun.com/pypi/packages/ad/da/a1693073397b30fc3390def5a33cbe630f1b9446ea296845680af95080af/torch-1.9.1-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 63.6 MB/s eta 0:00:01   |▌                               | 12.5 MB 1.5 MB/s eta 0:09:06     |▋                               | 14.8 MB 759 kB/s eta 0:17:56     |▉                               | 22.4 MB 1.5 MB/s eta 0:09:10     |█▎                              | 34.6 MB 545 kB/s eta 0:24:22     |█▍                              | 36.7 MB 719 kB/s eta 0:18:25     |█▉                              | 48.1 MB 358 kB/s eta 0:36:27     |██                              | 53.4 MB 1.4 MB/s eta 0:08:59     |██▎                             | 59.8 MB 1.4 MB/s eta 0:08:56     |██▍                             | 61.8 MB 4.8 MB/s eta 0:02:41     |██▋                             | 66.9 MB 1.5 MB/s eta 0:08:20     |███▋                            | 92.8 MB 1.5 MB/s eta 0:08:27     |███▋                            | 93.8 MB 1.5 MB/s eta 0:08:26     |████                            | 101.4 MB 11.8 MB/s eta 0:01:02     |████                            | 102.8 MB 11.8 MB/s eta 0:01:02     |████▏                           | 108.6 MB 247 kB/s eta 0:48:46     |█████                           | 130.2 MB 1.2 MB/s eta 0:09:23     |█████▉                          | 150.9 MB 46.7 MB/s eta 0:00:15     |██████████▊                     | 277.7 MB 1.6 MB/s eta 0:05:56     |███████████▎                    | 293.2 MB 1.5 MB/s eta 0:05:49     |███████████▎                    | 294.0 MB 1.5 MB/s eta 0:05:58     |███████████▍                    | 295.3 MB 1.5 MB/s eta 0:05:57     |███████████▌                    | 297.8 MB 1.6 MB/s eta 0:05:42     |███████████▊                    | 304.3 MB 1.6 MB/s eta 0:05:29     |███████████▊                    | 305.0 MB 1.6 MB/s eta 0:05:28     |████████████▏                   | 314.9 MB 2.1 MB/s eta 0:04:12     |█████████████▉                  | 358.6 MB 46.0 MB/s eta 0:00:11     |███████████████▊                | 407.3 MB 31.4 MB/s eta 0:00:14     |████████████████                | 413.3 MB 45.4 MB/s eta 0:00:10     |████████████████▎               | 423.2 MB 1.6 MB/s eta 0:04:16     |████████████████▊               | 434.3 MB 27.8 MB/s eta 0:00:15     |██████████████████              | 468.6 MB 1.6 MB/s eta 0:03:50�████████▋           | 534.4 MB 1.5 MB/s eta 0:03:13     |█████████████████████▍          | 556.4 MB 1.6 MB/s eta 0:02:57        | 579.4 MB 34.3 MB/s eta 0:00:08��██▎     | 683.7 MB 34.3 MB/s eta 0:00:05��███████████▏| 809.3 MB 45.7 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch) (3.7.4.3)
# Installing collected packages: torch
# Successfully installed torch-1.9.1
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torchvision
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/6c/daa50a536812da895a4eecaefdffbffd90736c47898d942501080a5b42a5/torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 1.7 MB/s eta 0:00:01    |██████▍                         | 4.4 MB 792 kB/s eta 0:00:23��██████████████▉             | 13.1 MB 1.7 MB/s eta 0:00:06
# Requirement already satisfied: torch==1.9.1 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.9.1)
# Requirement already satisfied: numpy in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.21.2)
# Requirement already satisfied: pillow>=5.3.0 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (8.3.2)
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch==1.9.1->torchvision) (3.7.4.3)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.10.1

# %%
# %cd lib
# !python setup.py build develop
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# running build
# running build_py
# running build_ext
# /root/miniconda3/lib/python3.7/site-packages/torch/utils/cpp_extension.py:370: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running develop
# running egg_info
# writing faster_rcnn.egg-info/PKG-INFO
# writing dependency_links to faster_rcnn.egg-info/dependency_links.txt
# writing top-level names to faster_rcnn.egg-info/top_level.txt
# reading manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# writing manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.7/model/_C.cpython-37m-x86_64-linux-gnu.so -> model
# Creating /root/miniconda3/lib/python3.7/site-packages/faster-rcnn.egg-link (link to .)
# Adding faster-rcnn 0.1 to easy-install.pth file
#
# Installed /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# Processing dependencies for faster-rcnn==0.1
# Finished processing dependencies for faster-rcnn==0.1

# %%
# %cd ..
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# modify trainval_net.py line 195

# !CUDA_VISIBLE_DEVICES=0 python trainval_net.py \
                   --dataset Age --net res101 \
                   --epoch 10 --bs 8 --nw 2\
                   --lr 1e-3 --lr_decay_step 5 \
                   --cuda --use_tfb  
#                    --r True --checksession 1 --checkepoch 5 --checkpoint 765
# Out:
# Called with args:
# Namespace(batch_size=8, checkepoch=1, checkpoint=0, checkpoint_interval=10000, checksession=1, class_agnostic=False, cuda=True, dataset='Age', disp_interval=100, large_scale=False, lr=0.001, lr_decay_gamma=0.1, lr_decay_step=5, mGPUs=False, max_epochs=10, net='res101', num_workers=2, optimizer='sgd', resume=False, save_dir='models', session=1, start_epoch=1, use_tfboard=True)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 20,
#            'DOUBLE_BIAS': False,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.001,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0001},
#  'USE_GPU_NMS': True}
# Loaded dataset `Age` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Age_gt_roidb.pkl
# done
# before filtering, there are 15330 images...
# after filtering, there are 15330 images...
# 15330 roidb entries
# Loading pretrained weights from data/pretrained_model/resnet101_caffe.pth
# [session 1][epoch  1][iter    0/1916] loss: 2.8936, lr: 1.00e-03
# 			fg/bg=(132/892), time cost: 1.982566
# 			rpn_cls: 0.7188, rpn_box: 0.0291, rcnn_cls: 1.8608, rcnn_box 0.2848
# [session 1][epoch  1][iter  100/1916] loss: 0.9854, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.606199
# 			rpn_cls: 0.0186, rpn_box: 0.0157, rcnn_cls: 0.5041, rcnn_box 0.3271
# [session 1][epoch  1][iter  200/1916] loss: 0.6054, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 96.833447
# 			rpn_cls: 0.0046, rpn_box: 0.0149, rcnn_cls: 0.3603, rcnn_box 0.1614
# [session 1][epoch  1][iter  300/1916] loss: 0.4648, lr: 1.00e-03
# 			fg/bg=(219/805), time cost: 96.552634
# 			rpn_cls: 0.0961, rpn_box: 0.0165, rcnn_cls: 0.3142, rcnn_box 0.1674
# [session 1][epoch  1][iter  400/1916] loss: 0.3885, lr: 1.00e-03
# 			fg/bg=(198/826), time cost: 96.699614
# 			rpn_cls: 0.0107, rpn_box: 0.0071, rcnn_cls: 0.2997, rcnn_box 0.1294
# [session 1][epoch  1][iter  500/1916] loss: 0.3471, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 97.752665
# 			rpn_cls: 0.0034, rpn_box: 0.0058, rcnn_cls: 0.2602, rcnn_box 0.0774
# [session 1][epoch  1][iter  600/1916] loss: 0.3423, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 97.223294
# 			rpn_cls: 0.0025, rpn_box: 0.0026, rcnn_cls: 0.2648, rcnn_box 0.0775
# [session 1][epoch  1][iter  700/1916] loss: 0.3485, lr: 1.00e-03
# 			fg/bg=(236/788), time cost: 96.819973
# 			rpn_cls: 0.0212, rpn_box: 0.0100, rcnn_cls: 0.2156, rcnn_box 0.1267
# [session 1][epoch  1][iter  800/1916] loss: 0.3390, lr: 1.00e-03
# 			fg/bg=(221/803), time cost: 97.031130
# 			rpn_cls: 0.0117, rpn_box: 0.0034, rcnn_cls: 0.2343, rcnn_box 0.0892
# [session 1][epoch  1][iter  900/1916] loss: 0.3159, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 97.081397
# 			rpn_cls: 0.0228, rpn_box: 0.0079, rcnn_cls: 0.6412, rcnn_box 0.1164
# [session 1][epoch  1][iter 1000/1916] loss: 0.2924, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.896126
# 			rpn_cls: 0.0035, rpn_box: 0.0041, rcnn_cls: 0.2076, rcnn_box 0.0467
# [session 1][epoch  1][iter 1100/1916] loss: 0.2844, lr: 1.00e-03
# 			fg/bg=(219/805), time cost: 97.219336
# 			rpn_cls: 0.0019, rpn_box: 0.0058, rcnn_cls: 0.1695, rcnn_box 0.0588
# [session 1][epoch  1][iter 1200/1916] loss: 0.2920, lr: 1.00e-03
# 			fg/bg=(224/800), time cost: 97.362281
# 			rpn_cls: 0.0013, rpn_box: 0.0049, rcnn_cls: 0.2961, rcnn_box 0.0892
# [session 1][epoch  1][iter 1300/1916] loss: 0.2926, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 96.950314
# 			rpn_cls: 0.0014, rpn_box: 0.0028, rcnn_cls: 0.1485, rcnn_box 0.0376
# [session 1][epoch  1][iter 1400/1916] loss: 0.2793, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 97.092928
# 			rpn_cls: 0.0324, rpn_box: 0.0056, rcnn_cls: 0.2426, rcnn_box 0.0804
# [session 1][epoch  1][iter 1500/1916] loss: 0.2661, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 97.269810
# 			rpn_cls: 0.0085, rpn_box: 0.0037, rcnn_cls: 0.2288, rcnn_box 0.0505
# [session 1][epoch  1][iter 1600/1916] loss: 0.2791, lr: 1.00e-03
# 			fg/bg=(216/808), time cost: 97.423369
# 			rpn_cls: 0.0014, rpn_box: 0.0072, rcnn_cls: 0.4081, rcnn_box 0.0722
# [session 1][epoch  1][iter 1700/1916] loss: 0.2659, lr: 1.00e-03
# 			fg/bg=(224/800), time cost: 97.132549
# 			rpn_cls: 0.0014, rpn_box: 0.0025, rcnn_cls: 0.1080, rcnn_box 0.0506
# [session 1][epoch  1][iter 1800/1916] loss: 0.2764, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.847937
# 			rpn_cls: 0.0037, rpn_box: 0.0025, rcnn_cls: 0.1654, rcnn_box 0.0313
# [session 1][epoch  1][iter 1900/1916] loss: 0.2624, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.973948
# 			rpn_cls: 0.0186, rpn_box: 0.0106, rcnn_cls: 0.3117, rcnn_box 0.1052
# [session 1][epoch  2][iter    0/1916] loss: 0.2581, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 1.536903
# 			rpn_cls: 0.0016, rpn_box: 0.0023, rcnn_cls: 0.2186, rcnn_box 0.0356
# [session 1][epoch  2][iter  100/1916] loss: 0.2461, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 97.126176
# 			rpn_cls: 0.0011, rpn_box: 0.0017, rcnn_cls: 0.4335, rcnn_box 0.0475
# [session 1][epoch  2][iter  200/1916] loss: 0.2362, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.831373
# 			rpn_cls: 0.0053, rpn_box: 0.0028, rcnn_cls: 0.2917, rcnn_box 0.0258
# [session 1][epoch  2][iter  300/1916] loss: 0.2420, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 97.104911
# 			rpn_cls: 0.0011, rpn_box: 0.0018, rcnn_cls: 0.1859, rcnn_box 0.0247
# [session 1][epoch  2][iter  400/1916] loss: 0.2412, lr: 1.00e-03
# 			fg/bg=(185/839), time cost: 96.498026
# 			rpn_cls: 0.0030, rpn_box: 0.0030, rcnn_cls: 0.1285, rcnn_box 0.0324
# [session 1][epoch  2][iter  500/1916] loss: 0.2248, lr: 1.00e-03
# 			fg/bg=(181/843), time cost: 97.208912
# 			rpn_cls: 0.0019, rpn_box: 0.0018, rcnn_cls: 0.1037, rcnn_box 0.0312
# [session 1][epoch  2][iter  600/1916] loss: 0.2236, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 97.044562
# 			rpn_cls: 0.0107, rpn_box: 0.0033, rcnn_cls: 0.2409, rcnn_box 0.0533
# [session 1][epoch  2][iter  700/1916] loss: 0.2476, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 97.669621
# 			rpn_cls: 0.0016, rpn_box: 0.0027, rcnn_cls: 0.3255, rcnn_box 0.0303
# [session 1][epoch  2][iter  800/1916] loss: 0.2242, lr: 1.00e-03
# 			fg/bg=(247/777), time cost: 97.062224
# 			rpn_cls: 0.0009, rpn_box: 0.0025, rcnn_cls: 0.2237, rcnn_box 0.0421
# [session 1][epoch  2][iter  900/1916] loss: 0.2297, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.452444
# 			rpn_cls: 0.0023, rpn_box: 0.0025, rcnn_cls: 0.1551, rcnn_box 0.0524
# [session 1][epoch  2][iter 1000/1916] loss: 0.2269, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 96.439636
# 			rpn_cls: 0.0019, rpn_box: 0.0030, rcnn_cls: 0.2653, rcnn_box 0.0424
# [session 1][epoch  2][iter 1100/1916] loss: 0.2238, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 96.752286
# 			rpn_cls: 0.0021, rpn_box: 0.0048, rcnn_cls: 0.2005, rcnn_box 0.0776
# [session 1][epoch  2][iter 1200/1916] loss: 0.2235, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 97.404660
# 			rpn_cls: 0.0016, rpn_box: 0.0040, rcnn_cls: 0.1826, rcnn_box 0.0408
# [session 1][epoch  2][iter 1300/1916] loss: 0.2230, lr: 1.00e-03
# 			fg/bg=(203/821), time cost: 96.829099
# 			rpn_cls: 0.0019, rpn_box: 0.0029, rcnn_cls: 0.1280, rcnn_box 0.0348
# [session 1][epoch  2][iter 1400/1916] loss: 0.2209, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 96.675533
# 			rpn_cls: 0.0053, rpn_box: 0.0034, rcnn_cls: 0.2030, rcnn_box 0.0380
# [session 1][epoch  2][iter 1500/1916] loss: 0.2171, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 96.694495
# 			rpn_cls: 0.0006, rpn_box: 0.0011, rcnn_cls: 0.1612, rcnn_box 0.0199
# [session 1][epoch  2][iter 1600/1916] loss: 0.2211, lr: 1.00e-03
# 			fg/bg=(181/843), time cost: 97.119073
# 			rpn_cls: 0.0154, rpn_box: 0.0027, rcnn_cls: 0.1329, rcnn_box 0.0321
# [session 1][epoch  2][iter 1700/1916] loss: 0.2208, lr: 1.00e-03
# 			fg/bg=(195/829), time cost: 97.267268
# 			rpn_cls: 0.0075, rpn_box: 0.0019, rcnn_cls: 0.1467, rcnn_box 0.0244
# [session 1][epoch  2][iter 1800/1916] loss: 0.2010, lr: 1.00e-03
# 			fg/bg=(198/826), time cost: 96.657195
# 			rpn_cls: 0.0084, rpn_box: 0.0045, rcnn_cls: 0.1523, rcnn_box 0.0339
# [session 1][epoch  2][iter 1900/1916] loss: 0.2128, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 96.931601
# 			rpn_cls: 0.0013, rpn_box: 0.0080, rcnn_cls: 0.1614, rcnn_box 0.0453
# [session 1][epoch  3][iter    0/1916] loss: 0.1674, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 1.958272
# 			rpn_cls: 0.0009, rpn_box: 0.0017, rcnn_cls: 0.1210, rcnn_box 0.0437
# [session 1][epoch  3][iter  100/1916] loss: 0.1889, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.969778
# 			rpn_cls: 0.0197, rpn_box: 0.0023, rcnn_cls: 0.0817, rcnn_box 0.0360
# [session 1][epoch  3][iter  200/1916] loss: 0.1928, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 96.642549
# 			rpn_cls: 0.0017, rpn_box: 0.0045, rcnn_cls: 0.1375, rcnn_box 0.0982
# [session 1][epoch  3][iter  300/1916] loss: 0.1944, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 97.234968
# 			rpn_cls: 0.0059, rpn_box: 0.0022, rcnn_cls: 0.1307, rcnn_box 0.0189
# [session 1][epoch  3][iter  400/1916] loss: 0.2058, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 97.050842
# 			rpn_cls: 0.0015, rpn_box: 0.0019, rcnn_cls: 0.2406, rcnn_box 0.0273
# [session 1][epoch  3][iter  500/1916] loss: 0.2033, lr: 1.00e-03
# 			fg/bg=(188/836), time cost: 96.638685
# 			rpn_cls: 0.0118, rpn_box: 0.0027, rcnn_cls: 0.0493, rcnn_box 0.0373
# [session 1][epoch  3][iter  600/1916] loss: 0.1915, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 97.258258
# 			rpn_cls: 0.0039, rpn_box: 0.0039, rcnn_cls: 0.1077, rcnn_box 0.0651
# [session 1][epoch  3][iter  700/1916] loss: 0.1910, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 97.256226
# 			rpn_cls: 0.0012, rpn_box: 0.0017, rcnn_cls: 0.0695, rcnn_box 0.0431
# [session 1][epoch  3][iter  800/1916] loss: 0.1965, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 96.523964
# 			rpn_cls: 0.0011, rpn_box: 0.0038, rcnn_cls: 0.1812, rcnn_box 0.0512
# [session 1][epoch  3][iter  900/1916] loss: 0.1914, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.777367
# 			rpn_cls: 0.0247, rpn_box: 0.0041, rcnn_cls: 0.1871, rcnn_box 0.0475
# [session 1][epoch  3][iter 1000/1916] loss: 0.1768, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.437665
# 			rpn_cls: 0.0006, rpn_box: 0.0015, rcnn_cls: 0.0723, rcnn_box 0.0274
# [session 1][epoch  3][iter 1100/1916] loss: 0.1918, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 97.123147
# 			rpn_cls: 0.0074, rpn_box: 0.0051, rcnn_cls: 0.1481, rcnn_box 0.0498
# [session 1][epoch  3][iter 1200/1916] loss: 0.1857, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.398482
# 			rpn_cls: 0.0008, rpn_box: 0.0020, rcnn_cls: 0.1597, rcnn_box 0.0318
# [session 1][epoch  3][iter 1300/1916] loss: 0.1885, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.514184
# 			rpn_cls: 0.0014, rpn_box: 0.0028, rcnn_cls: 0.0652, rcnn_box 0.0258
# [session 1][epoch  3][iter 1400/1916] loss: 0.1801, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 96.615378
# 			rpn_cls: 0.0039, rpn_box: 0.0048, rcnn_cls: 0.0897, rcnn_box 0.0410
# [session 1][epoch  3][iter 1500/1916] loss: 0.1959, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 97.006680
# 			rpn_cls: 0.0020, rpn_box: 0.0016, rcnn_cls: 0.0898, rcnn_box 0.0314
# [session 1][epoch  3][iter 1600/1916] loss: 0.1883, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 96.569879
# 			rpn_cls: 0.0006, rpn_box: 0.0014, rcnn_cls: 0.0663, rcnn_box 0.0251
# [session 1][epoch  3][iter 1700/1916] loss: 0.1903, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.688637
# 			rpn_cls: 0.0033, rpn_box: 0.0039, rcnn_cls: 0.2419, rcnn_box 0.0616
# [session 1][epoch  3][iter 1800/1916] loss: 0.1793, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.815380
# 			rpn_cls: 0.0066, rpn_box: 0.0034, rcnn_cls: 0.1266, rcnn_box 0.0358
# [session 1][epoch  3][iter 1900/1916] loss: 0.1894, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 96.926338
# 			rpn_cls: 0.0009, rpn_box: 0.0024, rcnn_cls: 0.1139, rcnn_box 0.0338
# [session 1][epoch  4][iter    0/1916] loss: 0.1064, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 1.506499
# 			rpn_cls: 0.0008, rpn_box: 0.0014, rcnn_cls: 0.0903, rcnn_box 0.0139
# [session 1][epoch  4][iter  100/1916] loss: 0.1647, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.909522
# 			rpn_cls: 0.0139, rpn_box: 0.0032, rcnn_cls: 0.0943, rcnn_box 0.0470
# [session 1][epoch  4][iter  200/1916] loss: 0.1673, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 97.269483
# 			rpn_cls: 0.0018, rpn_box: 0.0014, rcnn_cls: 0.0516, rcnn_box 0.0223
# [session 1][epoch  4][iter  300/1916] loss: 0.1800, lr: 1.00e-03
# 			fg/bg=(195/829), time cost: 96.777521
# 			rpn_cls: 0.0026, rpn_box: 0.0021, rcnn_cls: 0.1720, rcnn_box 0.0278
# [session 1][epoch  4][iter  400/1916] loss: 0.1781, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.732067
# 			rpn_cls: 0.0006, rpn_box: 0.0027, rcnn_cls: 0.1652, rcnn_box 0.0319
# [session 1][epoch  4][iter  500/1916] loss: 0.1787, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.420615
# 			rpn_cls: 0.0068, rpn_box: 0.0014, rcnn_cls: 0.1290, rcnn_box 0.0399
# [session 1][epoch  4][iter  600/1916] loss: 0.1730, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 97.192586
# 			rpn_cls: 0.0008, rpn_box: 0.0011, rcnn_cls: 0.0478, rcnn_box 0.0168
# [session 1][epoch  4][iter  700/1916] loss: 0.1584, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 96.761564
# 			rpn_cls: 0.0125, rpn_box: 0.0022, rcnn_cls: 0.0805, rcnn_box 0.0222
# [session 1][epoch  4][iter  800/1916] loss: 0.1686, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.437502
# 			rpn_cls: 0.0004, rpn_box: 0.0013, rcnn_cls: 0.0423, rcnn_box 0.0199
# [session 1][epoch  4][iter  900/1916] loss: 0.1604, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.149267
# 			rpn_cls: 0.0025, rpn_box: 0.0011, rcnn_cls: 0.1600, rcnn_box 0.0170
# [session 1][epoch  4][iter 1000/1916] loss: 0.1672, lr: 1.00e-03
# 			fg/bg=(184/840), time cost: 97.155890
# 			rpn_cls: 0.0050, rpn_box: 0.0038, rcnn_cls: 0.1414, rcnn_box 0.0330
# [session 1][epoch  4][iter 1100/1916] loss: 0.1711, lr: 1.00e-03
# 			fg/bg=(177/847), time cost: 96.880224
# 			rpn_cls: 0.0078, rpn_box: 0.0016, rcnn_cls: 0.1364, rcnn_box 0.0142
# [session 1][epoch  4][iter 1200/1916] loss: 0.1491, lr: 1.00e-03
# 			fg/bg=(173/851), time cost: 96.564978
# 			rpn_cls: 0.0017, rpn_box: 0.0021, rcnn_cls: 0.1034, rcnn_box 0.0320
# [session 1][epoch  4][iter 1300/1916] loss: 0.1643, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 96.569869
# 			rpn_cls: 0.0009, rpn_box: 0.0021, rcnn_cls: 0.1446, rcnn_box 0.0183
# [session 1][epoch  4][iter 1400/1916] loss: 0.1687, lr: 1.00e-03
# 			fg/bg=(188/836), time cost: 96.665978
# 			rpn_cls: 0.0012, rpn_box: 0.0039, rcnn_cls: 0.0937, rcnn_box 0.0399
# [session 1][epoch  4][iter 1500/1916] loss: 0.1708, lr: 1.00e-03
# 			fg/bg=(188/836), time cost: 96.519709
# 			rpn_cls: 0.0007, rpn_box: 0.0012, rcnn_cls: 0.0504, rcnn_box 0.0213
# [session 1][epoch  4][iter 1600/1916] loss: 0.1545, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.443817
# 			rpn_cls: 0.0033, rpn_box: 0.0028, rcnn_cls: 0.1010, rcnn_box 0.0275
# [session 1][epoch  4][iter 1700/1916] loss: 0.1693, lr: 1.00e-03
# 			fg/bg=(184/840), time cost: 96.638043
# 			rpn_cls: 0.0011, rpn_box: 0.0019, rcnn_cls: 0.1115, rcnn_box 0.0192
# [session 1][epoch  4][iter 1800/1916] loss: 0.1571, lr: 1.00e-03
# 			fg/bg=(216/808), time cost: 96.571872
# 			rpn_cls: 0.0030, rpn_box: 0.0039, rcnn_cls: 0.1417, rcnn_box 0.0485
# [session 1][epoch  4][iter 1900/1916] loss: 0.1625, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.893529
# 			rpn_cls: 0.0055, rpn_box: 0.0021, rcnn_cls: 0.0898, rcnn_box 0.0443
# [session 1][epoch  5][iter    0/1916] loss: 0.1436, lr: 1.00e-03
# 			fg/bg=(185/839), time cost: 1.516230
# 			rpn_cls: 0.0030, rpn_box: 0.0026, rcnn_cls: 0.0947, rcnn_box 0.0433
# [session 1][epoch  5][iter  100/1916] loss: 0.1387, lr: 1.00e-03
# 			fg/bg=(189/835), time cost: 96.927936
# 			rpn_cls: 0.0048, rpn_box: 0.0019, rcnn_cls: 0.0300, rcnn_box 0.0253
# [session 1][epoch  5][iter  200/1916] loss: 0.1422, lr: 1.00e-03
# 			fg/bg=(171/853), time cost: 97.244705
# 			rpn_cls: 0.0034, rpn_box: 0.0015, rcnn_cls: 0.1034, rcnn_box 0.0450
# [session 1][epoch  5][iter  300/1916] loss: 0.1409, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.565648
# 			rpn_cls: 0.0029, rpn_box: 0.0036, rcnn_cls: 0.0847, rcnn_box 0.0392
# [session 1][epoch  5][iter  400/1916] loss: 0.1463, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.493109
# 			rpn_cls: 0.0013, rpn_box: 0.0013, rcnn_cls: 0.0835, rcnn_box 0.0308
# [session 1][epoch  5][iter  500/1916] loss: 0.1548, lr: 1.00e-03
# 			fg/bg=(209/815), time cost: 96.866672
# 			rpn_cls: 0.0006, rpn_box: 0.0030, rcnn_cls: 0.0947, rcnn_box 0.0303
# [session 1][epoch  5][iter  600/1916] loss: 0.1495, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 97.017310
# 			rpn_cls: 0.0037, rpn_box: 0.0033, rcnn_cls: 0.1139, rcnn_box 0.0347
# [session 1][epoch  5][iter  700/1916] loss: 0.1537, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 96.379579
# 			rpn_cls: 0.0009, rpn_box: 0.0037, rcnn_cls: 0.1511, rcnn_box 0.0239
# [session 1][epoch  5][iter  800/1916] loss: 0.1449, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.889957
# 			rpn_cls: 0.0027, rpn_box: 0.0058, rcnn_cls: 0.1029, rcnn_box 0.0281
# [session 1][epoch  5][iter  900/1916] loss: 0.1463, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.358428
# 			rpn_cls: 0.0009, rpn_box: 0.0094, rcnn_cls: 0.0929, rcnn_box 0.0400
# [session 1][epoch  5][iter 1000/1916] loss: 0.1480, lr: 1.00e-03
# 			fg/bg=(182/842), time cost: 96.363624
# 			rpn_cls: 0.0003, rpn_box: 0.0025, rcnn_cls: 0.0846, rcnn_box 0.0193
# [session 1][epoch  5][iter 1100/1916] loss: 0.1462, lr: 1.00e-03
# 			fg/bg=(185/839), time cost: 96.729104
# 			rpn_cls: 0.0007, rpn_box: 0.0016, rcnn_cls: 0.0367, rcnn_box 0.0213
# [session 1][epoch  5][iter 1200/1916] loss: 0.1478, lr: 1.00e-03
# 			fg/bg=(167/857), time cost: 96.235501
# 			rpn_cls: 0.0005, rpn_box: 0.0009, rcnn_cls: 0.0482, rcnn_box 0.0190
# [session 1][epoch  5][iter 1300/1916] loss: 0.1507, lr: 1.00e-03
# 			fg/bg=(178/846), time cost: 96.045416
# 			rpn_cls: 0.0070, rpn_box: 0.0027, rcnn_cls: 0.1467, rcnn_box 0.0296
# [session 1][epoch  5][iter 1400/1916] loss: 0.1525, lr: 1.00e-03
# 			fg/bg=(198/826), time cost: 96.498020
# 			rpn_cls: 0.0062, rpn_box: 0.0016, rcnn_cls: 0.1211, rcnn_box 0.0223
# [session 1][epoch  5][iter 1500/1916] loss: 0.1451, lr: 1.00e-03
# 			fg/bg=(172/852), time cost: 96.804936
# 			rpn_cls: 0.0012, rpn_box: 0.0023, rcnn_cls: 0.1107, rcnn_box 0.0137
# [session 1][epoch  5][iter 1600/1916] loss: 0.1542, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 96.999475
# 			rpn_cls: 0.0014, rpn_box: 0.0017, rcnn_cls: 0.2041, rcnn_box 0.0202
# [session 1][epoch  5][iter 1700/1916] loss: 0.1470, lr: 1.00e-03
# 			fg/bg=(183/841), time cost: 96.741714
# 			rpn_cls: 0.0012, rpn_box: 0.0021, rcnn_cls: 0.1589, rcnn_box 0.0352
# [session 1][epoch  5][iter 1800/1916] loss: 0.1349, lr: 1.00e-03
# 			fg/bg=(175/849), time cost: 96.311298
# 			rpn_cls: 0.0005, rpn_box: 0.0029, rcnn_cls: 0.1055, rcnn_box 0.0257
# [session 1][epoch  5][iter 1900/1916] loss: 0.1443, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 96.245606
# 			rpn_cls: 0.0006, rpn_box: 0.0019, rcnn_cls: 0.1161, rcnn_box 0.0209
# [session 1][epoch  6][iter    0/1916] loss: 0.1408, lr: 1.00e-04
# 			fg/bg=(194/830), time cost: 1.355207
# 			rpn_cls: 0.0028, rpn_box: 0.0028, rcnn_cls: 0.1017, rcnn_box 0.0335
# [session 1][epoch  6][iter  100/1916] loss: 0.1173, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 96.453697
# 			rpn_cls: 0.0005, rpn_box: 0.0012, rcnn_cls: 0.0837, rcnn_box 0.0208
# [session 1][epoch  6][iter  200/1916] loss: 0.1281, lr: 1.00e-04
# 			fg/bg=(170/854), time cost: 96.921775
# 			rpn_cls: 0.0008, rpn_box: 0.0020, rcnn_cls: 0.0823, rcnn_box 0.0171
# [session 1][epoch  6][iter  300/1916] loss: 0.1104, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.665780
# 			rpn_cls: 0.0012, rpn_box: 0.0033, rcnn_cls: 0.0619, rcnn_box 0.0308
# [session 1][epoch  6][iter  400/1916] loss: 0.1102, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 96.355366
# 			rpn_cls: 0.0007, rpn_box: 0.0015, rcnn_cls: 0.0544, rcnn_box 0.0148
# [session 1][epoch  6][iter  500/1916] loss: 0.1032, lr: 1.00e-04
# 			fg/bg=(184/840), time cost: 96.431648
# 			rpn_cls: 0.0005, rpn_box: 0.0009, rcnn_cls: 0.0436, rcnn_box 0.0097
# [session 1][epoch  6][iter  600/1916] loss: 0.1106, lr: 1.00e-04
# 			fg/bg=(172/852), time cost: 96.615600
# 			rpn_cls: 0.0029, rpn_box: 0.0011, rcnn_cls: 0.0680, rcnn_box 0.0137
# [session 1][epoch  6][iter  700/1916] loss: 0.1143, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 96.272998
# 			rpn_cls: 0.0108, rpn_box: 0.0028, rcnn_cls: 0.1994, rcnn_box 0.0295
# [session 1][epoch  6][iter  800/1916] loss: 0.1137, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 96.465517
# 			rpn_cls: 0.0005, rpn_box: 0.0018, rcnn_cls: 0.0575, rcnn_box 0.0387
# [session 1][epoch  6][iter  900/1916] loss: 0.0996, lr: 1.00e-04
# 			fg/bg=(178/846), time cost: 96.232542
# 			rpn_cls: 0.0010, rpn_box: 0.0024, rcnn_cls: 0.0814, rcnn_box 0.0292
# [session 1][epoch  6][iter 1000/1916] loss: 0.1057, lr: 1.00e-04
# 			fg/bg=(189/835), time cost: 96.833391
# 			rpn_cls: 0.0034, rpn_box: 0.0011, rcnn_cls: 0.0738, rcnn_box 0.0219
# [session 1][epoch  6][iter 1100/1916] loss: 0.1052, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.338388
# 			rpn_cls: 0.0124, rpn_box: 0.0024, rcnn_cls: 0.1032, rcnn_box 0.0338
# [session 1][epoch  6][iter 1200/1916] loss: 0.1057, lr: 1.00e-04
# 			fg/bg=(193/831), time cost: 96.373698
# 			rpn_cls: 0.0084, rpn_box: 0.0012, rcnn_cls: 0.0659, rcnn_box 0.0204
# [session 1][epoch  6][iter 1300/1916] loss: 0.1028, lr: 1.00e-04
# 			fg/bg=(184/840), time cost: 96.389240
# 			rpn_cls: 0.0008, rpn_box: 0.0011, rcnn_cls: 0.0595, rcnn_box 0.0221
# [session 1][epoch  6][iter 1400/1916] loss: 0.1078, lr: 1.00e-04
# 			fg/bg=(192/832), time cost: 96.654122
# 			rpn_cls: 0.0010, rpn_box: 0.0016, rcnn_cls: 0.0349, rcnn_box 0.0199
# [session 1][epoch  6][iter 1500/1916] loss: 0.1119, lr: 1.00e-04
# 			fg/bg=(192/832), time cost: 97.189460
# 			rpn_cls: 0.0080, rpn_box: 0.0020, rcnn_cls: 0.0476, rcnn_box 0.0152
# [session 1][epoch  6][iter 1600/1916] loss: 0.1034, lr: 1.00e-04
# 			fg/bg=(175/849), time cost: 96.450839
# 			rpn_cls: 0.0005, rpn_box: 0.0010, rcnn_cls: 0.1139, rcnn_box 0.0147
# [session 1][epoch  6][iter 1700/1916] loss: 0.1125, lr: 1.00e-04
# 			fg/bg=(170/854), time cost: 96.900362
# 			rpn_cls: 0.0012, rpn_box: 0.0024, rcnn_cls: 0.0528, rcnn_box 0.0412
# [session 1][epoch  6][iter 1800/1916] loss: 0.1088, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 96.519800
# 			rpn_cls: 0.0007, rpn_box: 0.0023, rcnn_cls: 0.0493, rcnn_box 0.0197
# [session 1][epoch  6][iter 1900/1916] loss: 0.1011, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 96.344811
# 			rpn_cls: 0.0005, rpn_box: 0.0014, rcnn_cls: 0.0463, rcnn_box 0.0198
# [session 1][epoch  7][iter    0/1916] loss: 0.1011, lr: 1.00e-04
# 			fg/bg=(171/853), time cost: 1.585564
# 			rpn_cls: 0.0006, rpn_box: 0.0008, rcnn_cls: 0.0877, rcnn_box 0.0120
# [session 1][epoch  7][iter  100/1916] loss: 0.1081, lr: 1.00e-04
# 			fg/bg=(180/844), time cost: 96.574831
# 			rpn_cls: 0.0014, rpn_box: 0.0012, rcnn_cls: 0.0451, rcnn_box 0.0104
# [session 1][epoch  7][iter  200/1916] loss: 0.1042, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.697702
# 			rpn_cls: 0.0049, rpn_box: 0.0011, rcnn_cls: 0.0465, rcnn_box 0.0131
# [session 1][epoch  7][iter  300/1916] loss: 0.1001, lr: 1.00e-04
# 			fg/bg=(167/857), time cost: 96.396998
# 			rpn_cls: 0.0015, rpn_box: 0.0027, rcnn_cls: 0.0527, rcnn_box 0.0101
# [session 1][epoch  7][iter  400/1916] loss: 0.1012, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 96.816684
# 			rpn_cls: 0.0011, rpn_box: 0.0009, rcnn_cls: 0.0803, rcnn_box 0.0111
# [session 1][epoch  7][iter  500/1916] loss: 0.0986, lr: 1.00e-04
# 			fg/bg=(187/837), time cost: 96.356077
# 			rpn_cls: 0.0019, rpn_box: 0.0013, rcnn_cls: 0.0832, rcnn_box 0.0123
# [session 1][epoch  7][iter  600/1916] loss: 0.1088, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.668719
# 			rpn_cls: 0.0009, rpn_box: 0.0015, rcnn_cls: 0.0890, rcnn_box 0.0132
# [session 1][epoch  7][iter  700/1916] loss: 0.1015, lr: 1.00e-04
# 			fg/bg=(181/843), time cost: 96.456839
# 			rpn_cls: 0.0053, rpn_box: 0.0014, rcnn_cls: 0.0528, rcnn_box 0.0201
# [session 1][epoch  7][iter  800/1916] loss: 0.1069, lr: 1.00e-04
# 			fg/bg=(182/842), time cost: 97.106586
# 			rpn_cls: 0.0007, rpn_box: 0.0011, rcnn_cls: 0.0361, rcnn_box 0.0288
# [session 1][epoch  7][iter  900/1916] loss: 0.1017, lr: 1.00e-04
# 			fg/bg=(195/829), time cost: 96.793126
# 			rpn_cls: 0.0054, rpn_box: 0.0015, rcnn_cls: 0.0776, rcnn_box 0.0124
# [session 1][epoch  7][iter 1000/1916] loss: 0.1006, lr: 1.00e-04
# 			fg/bg=(189/835), time cost: 96.799506
# 			rpn_cls: 0.0003, rpn_box: 0.0016, rcnn_cls: 0.1284, rcnn_box 0.0198
# [session 1][epoch  7][iter 1100/1916] loss: 0.0955, lr: 1.00e-04
# 			fg/bg=(169/855), time cost: 96.162623
# 			rpn_cls: 0.0005, rpn_box: 0.0007, rcnn_cls: 0.0295, rcnn_box 0.0146
# [session 1][epoch  7][iter 1200/1916] loss: 0.1028, lr: 1.00e-04
# 			fg/bg=(179/845), time cost: 96.487387
# 			rpn_cls: 0.0025, rpn_box: 0.0020, rcnn_cls: 0.0813, rcnn_box 0.0176
# [session 1][epoch  7][iter 1300/1916] loss: 0.1100, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 96.740438
# 			rpn_cls: 0.0006, rpn_box: 0.0016, rcnn_cls: 0.0459, rcnn_box 0.0205
# [session 1][epoch  7][iter 1400/1916] loss: 0.1020, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.454371
# 			rpn_cls: 0.0003, rpn_box: 0.0012, rcnn_cls: 0.0396, rcnn_box 0.0136
# [session 1][epoch  7][iter 1500/1916] loss: 0.0974, lr: 1.00e-04
# 			fg/bg=(199/825), time cost: 96.470480
# 			rpn_cls: 0.0012, rpn_box: 0.0012, rcnn_cls: 0.0490, rcnn_box 0.0135
# [session 1][epoch  7][iter 1600/1916] loss: 0.0939, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 96.637799
# 			rpn_cls: 0.0008, rpn_box: 0.0023, rcnn_cls: 0.0313, rcnn_box 0.0322
# [session 1][epoch  7][iter 1700/1916] loss: 0.1029, lr: 1.00e-04
# 			fg/bg=(182/842), time cost: 96.210245
# 			rpn_cls: 0.0008, rpn_box: 0.0026, rcnn_cls: 0.1590, rcnn_box 0.0255
# [session 1][epoch  7][iter 1800/1916] loss: 0.1027, lr: 1.00e-04
# 			fg/bg=(174/850), time cost: 96.708203
# 			rpn_cls: 0.0005, rpn_box: 0.0010, rcnn_cls: 0.0869, rcnn_box 0.0099
# [session 1][epoch  7][iter 1900/1916] loss: 0.0979, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.433558
# 			rpn_cls: 0.0005, rpn_box: 0.0020, rcnn_cls: 0.1095, rcnn_box 0.0210
# [session 1][epoch  8][iter    0/1916] loss: 0.0888, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 2.128245
# 			rpn_cls: 0.0002, rpn_box: 0.0014, rcnn_cls: 0.0682, rcnn_box 0.0190
# [session 1][epoch  8][iter  100/1916] loss: 0.0936, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 97.048748
# 			rpn_cls: 0.0006, rpn_box: 0.0011, rcnn_cls: 0.0911, rcnn_box 0.0182
# [session 1][epoch  8][iter  200/1916] loss: 0.0951, lr: 1.00e-04
# 			fg/bg=(177/847), time cost: 96.703563
# 			rpn_cls: 0.0036, rpn_box: 0.0012, rcnn_cls: 0.1014, rcnn_box 0.0135
# [session 1][epoch  8][iter  300/1916] loss: 0.0978, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 96.535689
# 			rpn_cls: 0.0038, rpn_box: 0.0011, rcnn_cls: 0.1200, rcnn_box 0.0096
# [session 1][epoch  8][iter  400/1916] loss: 0.1034, lr: 1.00e-04
# 			fg/bg=(183/841), time cost: 96.802890
# 			rpn_cls: 0.0009, rpn_box: 0.0013, rcnn_cls: 0.0332, rcnn_box 0.0139
# [session 1][epoch  8][iter  500/1916] loss: 0.1037, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 96.765540
# 			rpn_cls: 0.0004, rpn_box: 0.0011, rcnn_cls: 0.0435, rcnn_box 0.0134
# [session 1][epoch  8][iter  600/1916] loss: 0.1060, lr: 1.00e-04
# 			fg/bg=(187/837), time cost: 96.473453
# 			rpn_cls: 0.0005, rpn_box: 0.0020, rcnn_cls: 0.1700, rcnn_box 0.0200
# [session 1][epoch  8][iter  700/1916] loss: 0.0989, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 96.746913
# 			rpn_cls: 0.0007, rpn_box: 0.0010, rcnn_cls: 0.1134, rcnn_box 0.0198
# [session 1][epoch  8][iter  800/1916] loss: 0.0926, lr: 1.00e-04
# 			fg/bg=(199/825), time cost: 96.272222
# 			rpn_cls: 0.0018, rpn_box: 0.0025, rcnn_cls: 0.0361, rcnn_box 0.0327
# [session 1][epoch  8][iter  900/1916] loss: 0.1061, lr: 1.00e-04
# 			fg/bg=(187/837), time cost: 97.158671
# 			rpn_cls: 0.0003, rpn_box: 0.0012, rcnn_cls: 0.0306, rcnn_box 0.0191
# [session 1][epoch  8][iter 1000/1916] loss: 0.0996, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 97.253111
# 			rpn_cls: 0.0028, rpn_box: 0.0022, rcnn_cls: 0.0471, rcnn_box 0.0248
# [session 1][epoch  8][iter 1100/1916] loss: 0.0970, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 98.537000
# 			rpn_cls: 0.0017, rpn_box: 0.0022, rcnn_cls: 0.0544, rcnn_box 0.0351
# [session 1][epoch  8][iter 1200/1916] loss: 0.1000, lr: 1.00e-04
# 			fg/bg=(194/830), time cost: 98.103295
# 			rpn_cls: 0.0005, rpn_box: 0.0015, rcnn_cls: 0.0316, rcnn_box 0.0188
# [session 1][epoch  8][iter 1300/1916] loss: 0.0954, lr: 1.00e-04
# 			fg/bg=(199/825), time cost: 97.767728
# 			rpn_cls: 0.0040, rpn_box: 0.0026, rcnn_cls: 0.0515, rcnn_box 0.0257
# [session 1][epoch  8][iter 1400/1916] loss: 0.0910, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 97.846917
# 			rpn_cls: 0.0004, rpn_box: 0.0023, rcnn_cls: 0.0658, rcnn_box 0.0202
# [session 1][epoch  8][iter 1500/1916] loss: 0.0985, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 97.206725
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.0467, rcnn_box 0.0332
# [session 1][epoch  8][iter 1600/1916] loss: 0.0910, lr: 1.00e-04
# 			fg/bg=(179/845), time cost: 97.565441
# 			rpn_cls: 0.0152, rpn_box: 0.0011, rcnn_cls: 0.0464, rcnn_box 0.0167
# [session 1][epoch  8][iter 1700/1916] loss: 0.0939, lr: 1.00e-04
# 			fg/bg=(191/833), time cost: 97.985583
# 			rpn_cls: 0.0016, rpn_box: 0.0016, rcnn_cls: 0.0564, rcnn_box 0.0305
# [session 1][epoch  8][iter 1800/1916] loss: 0.0967, lr: 1.00e-04
# 			fg/bg=(180/844), time cost: 98.257393
# 			rpn_cls: 0.0007, rpn_box: 0.0015, rcnn_cls: 0.1065, rcnn_box 0.0163
# [session 1][epoch  8][iter 1900/1916] loss: 0.0914, lr: 1.00e-04
# 			fg/bg=(169/855), time cost: 97.377680
# 			rpn_cls: 0.0012, rpn_box: 0.0008, rcnn_cls: 0.0439, rcnn_box 0.0243
# [session 1][epoch  9][iter    0/1916] loss: 0.0748, lr: 1.00e-04
# 			fg/bg=(187/837), time cost: 1.361250
# 			rpn_cls: 0.0010, rpn_box: 0.0011, rcnn_cls: 0.0622, rcnn_box 0.0105
# [session 1][epoch  9][iter  100/1916] loss: 0.0968, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 98.603027
# 			rpn_cls: 0.0039, rpn_box: 0.0040, rcnn_cls: 0.1143, rcnn_box 0.0300
# [session 1][epoch  9][iter  200/1916] loss: 0.0890, lr: 1.00e-04
# 			fg/bg=(173/851), time cost: 97.465662
# 			rpn_cls: 0.0006, rpn_box: 0.0007, rcnn_cls: 0.0414, rcnn_box 0.0085
# [session 1][epoch  9][iter  300/1916] loss: 0.0922, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 97.602247
# 			rpn_cls: 0.0077, rpn_box: 0.0012, rcnn_cls: 0.0273, rcnn_box 0.0194
# [session 1][epoch  9][iter  400/1916] loss: 0.0987, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 98.202116
# 			rpn_cls: 0.0115, rpn_box: 0.0025, rcnn_cls: 0.0624, rcnn_box 0.0307
# [session 1][epoch  9][iter  500/1916] loss: 0.1051, lr: 1.00e-04
# 			fg/bg=(193/831), time cost: 97.803138
# 			rpn_cls: 0.0073, rpn_box: 0.0019, rcnn_cls: 0.0256, rcnn_box 0.0201
# [session 1][epoch  9][iter  600/1916] loss: 0.0981, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 96.665405
# 			rpn_cls: 0.0052, rpn_box: 0.0009, rcnn_cls: 0.0348, rcnn_box 0.0110
# [session 1][epoch  9][iter  700/1916] loss: 0.0914, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 96.650115
# 			rpn_cls: 0.0048, rpn_box: 0.0023, rcnn_cls: 0.1473, rcnn_box 0.0187
# [session 1][epoch  9][iter  800/1916] loss: 0.0888, lr: 1.00e-04
# 			fg/bg=(182/842), time cost: 97.073807
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.0711, rcnn_box 0.0149
# [session 1][epoch  9][iter  900/1916] loss: 0.0870, lr: 1.00e-04
# 			fg/bg=(189/835), time cost: 96.395758
# 			rpn_cls: 0.0025, rpn_box: 0.0008, rcnn_cls: 0.0540, rcnn_box 0.0112
# [session 1][epoch  9][iter 1000/1916] loss: 0.0918, lr: 1.00e-04
# 			fg/bg=(169/855), time cost: 96.614990
# 			rpn_cls: 0.0029, rpn_box: 0.0014, rcnn_cls: 0.0422, rcnn_box 0.0145
# [session 1][epoch  9][iter 1100/1916] loss: 0.0928, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.323180
# 			rpn_cls: 0.0003, rpn_box: 0.0023, rcnn_cls: 0.2418, rcnn_box 0.0271
# [session 1][epoch  9][iter 1200/1916] loss: 0.1012, lr: 1.00e-04
# 			fg/bg=(178/846), time cost: 95.870116
# 			rpn_cls: 0.0050, rpn_box: 0.0016, rcnn_cls: 0.0735, rcnn_box 0.0133
# [session 1][epoch  9][iter 1300/1916] loss: 0.0926, lr: 1.00e-04
# 			fg/bg=(176/848), time cost: 96.906016
# 			rpn_cls: 0.0086, rpn_box: 0.0014, rcnn_cls: 0.0482, rcnn_box 0.0141
# [session 1][epoch  9][iter 1400/1916] loss: 0.0998, lr: 1.00e-04
# 			fg/bg=(182/842), time cost: 96.896232
# 			rpn_cls: 0.0153, rpn_box: 0.0018, rcnn_cls: 0.0902, rcnn_box 0.0191
# [session 1][epoch  9][iter 1500/1916] loss: 0.0897, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 96.479953
# 			rpn_cls: 0.0050, rpn_box: 0.0012, rcnn_cls: 0.0606, rcnn_box 0.0187
# [session 1][epoch  9][iter 1600/1916] loss: 0.0903, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 97.045679
# 			rpn_cls: 0.0011, rpn_box: 0.0013, rcnn_cls: 0.0219, rcnn_box 0.0164
# [session 1][epoch  9][iter 1700/1916] loss: 0.0955, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 97.296513
# 			rpn_cls: 0.0011, rpn_box: 0.0012, rcnn_cls: 0.0622, rcnn_box 0.0253
# [session 1][epoch  9][iter 1800/1916] loss: 0.0891, lr: 1.00e-04
# 			fg/bg=(182/842), time cost: 97.222082
# 			rpn_cls: 0.0004, rpn_box: 0.0009, rcnn_cls: 0.0457, rcnn_box 0.0174
# [session 1][epoch  9][iter 1900/1916] loss: 0.0873, lr: 1.00e-04
# 			fg/bg=(184/840), time cost: 97.427940
# 			rpn_cls: 0.0009, rpn_box: 0.0025, rcnn_cls: 0.2319, rcnn_box 0.0132
# [session 1][epoch 10][iter    0/1916] loss: 0.0469, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 1.391919
# 			rpn_cls: 0.0043, rpn_box: 0.0022, rcnn_cls: 0.0263, rcnn_box 0.0141
# [session 1][epoch 10][iter  100/1916] loss: 0.0946, lr: 1.00e-04
# 			fg/bg=(181/843), time cost: 97.413950
# 			rpn_cls: 0.0004, rpn_box: 0.0008, rcnn_cls: 0.0518, rcnn_box 0.0160
# [session 1][epoch 10][iter  200/1916] loss: 0.0916, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 97.094100
# 			rpn_cls: 0.0007, rpn_box: 0.0016, rcnn_cls: 0.0492, rcnn_box 0.0112
# [session 1][epoch 10][iter  300/1916] loss: 0.0852, lr: 1.00e-04
# 			fg/bg=(183/841), time cost: 97.076411
# 			rpn_cls: 0.0008, rpn_box: 0.0018, rcnn_cls: 0.0730, rcnn_box 0.0259
# [session 1][epoch 10][iter  400/1916] loss: 0.0894, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.266663
# 			rpn_cls: 0.0006, rpn_box: 0.0048, rcnn_cls: 0.0623, rcnn_box 0.0278
# [session 1][epoch 10][iter  500/1916] loss: 0.0950, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.598515
# 			rpn_cls: 0.0006, rpn_box: 0.0014, rcnn_cls: 0.1547, rcnn_box 0.0255
# [session 1][epoch 10][iter  600/1916] loss: 0.0868, lr: 1.00e-04
# 			fg/bg=(184/840), time cost: 97.052806
# 			rpn_cls: 0.0004, rpn_box: 0.0010, rcnn_cls: 0.0500, rcnn_box 0.0140
# [session 1][epoch 10][iter  700/1916] loss: 0.0925, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 97.191170
# 			rpn_cls: 0.0003, rpn_box: 0.0007, rcnn_cls: 0.0279, rcnn_box 0.0165
# [session 1][epoch 10][iter  800/1916] loss: 0.0941, lr: 1.00e-04
# 			fg/bg=(183/841), time cost: 97.485899
# 			rpn_cls: 0.0011, rpn_box: 0.0022, rcnn_cls: 0.0454, rcnn_box 0.0286
# [session 1][epoch 10][iter  900/1916] loss: 0.0841, lr: 1.00e-04
# 			fg/bg=(176/848), time cost: 97.269179
# 			rpn_cls: 0.0019, rpn_box: 0.0010, rcnn_cls: 0.0269, rcnn_box 0.0133
# [session 1][epoch 10][iter 1000/1916] loss: 0.0874, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.540255
# 			rpn_cls: 0.0031, rpn_box: 0.0029, rcnn_cls: 0.0625, rcnn_box 0.0505
# [session 1][epoch 10][iter 1100/1916] loss: 0.0871, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.418819
# 			rpn_cls: 0.0007, rpn_box: 0.0012, rcnn_cls: 0.0467, rcnn_box 0.0147
# [session 1][epoch 10][iter 1200/1916] loss: 0.0875, lr: 1.00e-04
# 			fg/bg=(181/843), time cost: 96.689666
# 			rpn_cls: 0.0004, rpn_box: 0.0006, rcnn_cls: 0.0380, rcnn_box 0.0086
# [session 1][epoch 10][iter 1300/1916] loss: 0.0864, lr: 1.00e-04
# 			fg/bg=(180/844), time cost: 96.699647
# 			rpn_cls: 0.0005, rpn_box: 0.0014, rcnn_cls: 0.0205, rcnn_box 0.0122
# [session 1][epoch 10][iter 1400/1916] loss: 0.0876, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 96.432680
# 			rpn_cls: 0.0003, rpn_box: 0.0011, rcnn_cls: 0.0202, rcnn_box 0.0153
# [session 1][epoch 10][iter 1500/1916] loss: 0.0873, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 96.377619
# 			rpn_cls: 0.0028, rpn_box: 0.0013, rcnn_cls: 0.1029, rcnn_box 0.0258
# [session 1][epoch 10][iter 1600/1916] loss: 0.0981, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 97.491491
# 			rpn_cls: 0.0008, rpn_box: 0.0018, rcnn_cls: 0.0842, rcnn_box 0.0348
# [session 1][epoch 10][iter 1700/1916] loss: 0.0892, lr: 1.00e-04
# 			fg/bg=(187/837), time cost: 96.752510
# 			rpn_cls: 0.0023, rpn_box: 0.0015, rcnn_cls: 0.0381, rcnn_box 0.0177
# [session 1][epoch 10][iter 1800/1916] loss: 0.0904, lr: 1.00e-04
# 			fg/bg=(189/835), time cost: 96.374332
# 			rpn_cls: 0.0021, rpn_box: 0.0024, rcnn_cls: 0.0618, rcnn_box 0.0216
# [session 1][epoch 10][iter 1900/1916] loss: 0.0857, lr: 1.00e-04
# 			fg/bg=(176/848), time cost: 96.443393
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.0528, rcnn_box 0.0118
# save model: models/res101/Age/faster_rcnn_1_10_1915.pth

# %%
# !CUDA_VISIBLE_DEVICES=0 python demo.py --net vgg16 --dataset Race  --checksession 1  --checkepoch 10 \
                --checkpoint 957  --cuda --load_dir models
# Out:
# Called with args:
# Namespace(batch_size=1, cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', image_dir='images', load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False, webcam_num=-1)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# load model successfully!
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# demo.py:234: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_data = Variable(im_data, volatile=True)
# demo.py:235: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_info = Variable(im_info, volatile=True)
# demo.py:236: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   num_boxes = Variable(num_boxes, volatile=True)
# demo.py:237: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   gt_boxes = Variable(gt_boxes, volatile=True)
# Loaded Photo: 8 images.
# demo.py:279: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   im_in = np.array(imread(im_file))
# /root/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# im_detect: 0/8 0.323s 0.007s

# %%
# !python test_net.py --dataset Gender --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Gender` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Gender_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Gender/faster_rcnn_1_10_957.pth
# load model successfully!
# Evaluating detections0.315s 0.002s
# Writing male VOC results file
# Writing female VOC results file
# Writing unsure VOC results file
# VOC07 metric? Yes
# Reading annotation for 1/3067
# Reading annotation for 101/3067
# Reading annotation for 201/3067
# Reading annotation for 301/3067
# Reading annotation for 401/3067
# Reading annotation for 501/3067
# Reading annotation for 601/3067
# Reading annotation for 701/3067
# Reading annotation for 801/3067
# Reading annotation for 901/3067
# Reading annotation for 1001/3067
# Reading annotation for 1101/3067
# Reading annotation for 1201/3067
# Reading annotation for 1301/3067
# Reading annotation for 1401/3067
# Reading annotation for 1501/3067
# Reading annotation for 1601/3067
# Reading annotation for 1701/3067
# Reading annotation for 1801/3067
# Reading annotation for 1901/3067
# Reading annotation for 2001/3067
# Reading annotation for 2101/3067
# Reading annotation for 2201/3067
# Reading annotation for 2301/3067
# Reading annotation for 2401/3067
# Reading annotation for 2501/3067
# Reading annotation for 2601/3067
# Reading annotation for 2701/3067
# Reading annotation for 2801/3067
# Reading annotation for 2901/3067
# Reading annotation for 3001/3067
# Saving cached annotations to /mnt/FasterRCNN/faster-rcnn.pytorch/data/Gender/ImageSets/Main/test.txt_annots.pkl
# AP for male = 0.8504
# AP for female = 0.8568
# AP for unsure = 0.6992
# Mean AP = 0.8021
# ~~~~~~~~
# Results:
# 0.850
# 0.857
# 0.699
# 0.802
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# test time: 1132.3115s

# %%
# !python test_net.py --dataset Emotion --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Emotion` for training
# Set proposal method: gt
# Preparing training data...
# Emotion gt roidb loaded from /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Emotion_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Emotion/faster_rcnn_1_10_957.pth
# load model successfully!
# ^C
# Traceback (most recent call last):
#   File "test_net.py", line 213, in <module>
#     fasterRCNN.cuda()
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 552, in _apply
#     param_applied = fn(param)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
# KeyboardInterrupt
