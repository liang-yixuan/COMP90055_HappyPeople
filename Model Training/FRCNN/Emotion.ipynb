# %%
# %cd /mnt/FasterRCNN/faster-rcnn.pytorch
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 2.0 MB 43.1 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 49.9 MB 21.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 24.8 MB 1.6 MB/s eta 0:00:01��██████████▎       | 18.8 MB 1.6 MB/s eta 0:00:04     |█████████████████████████████▍  | 22.7 MB 1.6 MB/s eta 0:00:02
# ...
#      |████████████████████████████████| 273 kB 4.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.3 MB 38.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 636 kB 43.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 124 kB 33.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 15.7 MB 49.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 41.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 3.1 MB 35.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.1 MB 39.6 MB/s eta 0:00:01
# ...

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272852 sha256=00c3d28b59263a6ba1be584f5ea2e5842ec1638245f4eb6cf676126c2c1ed9f6
#   Stored in directory: /root/.cache/pip/wheels/60/03/30/0cc037d5ac8ecd261e4c9e4fdb4f2c429074cd52a7a844c61e
# Successfully built pycocotools
# ...

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !conda install ipykernel -y
# Out:
# ...
# Solving environment: /
# ...
#   - https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
# ...

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 831.4 MB 14.4 MB/s eta 0:00:01     |██████▋                         | 171.7 MB 27.2 MB/s eta 0:00:25MB 55.2 MB/s eta 0:00:11     |███████████████▊                | 407.4 MB 8.6 MB/s eta 0:00:50     |████████████████▌               | 429.7 MB 13.4 MB/s eta 0:00:30     |██████████████████              | 466.3 MB 8.6 MB/s eta 0:00:43MB/s eta 0:00:06
# ...
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 22.1 MB 22.1 MB/s eta 0:00:01    |███████████████                 | 10.4 MB 3.4 MB/s eta 0:00:04
# ...

# %%
# %cd lib
# !python setup.py build develop
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# running build
# running build_py
# copying datasets/voc_eval.py -> build/lib.linux-x86_64-3.7/datasets
# copying datasets/happy_people.py -> build/lib.linux-x86_64-3.7/datasets
# running build_ext
# /root/miniconda3/lib/python3.7/site-packages/torch/utils/cpp_extension.py:370: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running develop
# running egg_info
# writing faster_rcnn.egg-info/PKG-INFO
# writing dependency_links to faster_rcnn.egg-info/dependency_links.txt
# writing top-level names to faster_rcnn.egg-info/top_level.txt
# reading manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# writing manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.7/model/_C.cpython-37m-x86_64-linux-gnu.so -> model
# ...

# %%
# %cd ..
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# modify trainval_net.py line 195

# !CUDA_VISIBLE_DEVICES=0 python trainval_net.py \
                   --dataset Emotion --net res101 \
                   --epoch 10 --bs 8 --nw 2\
                   --lr 1e-3 --lr_decay_step 5 \
                   --cuda --use_tfb  
#                    --r True --checksession 1 --checkepoch 5 --checkpoint 765
# Out:
# Called with args:
# Namespace(batch_size=8, checkepoch=1, checkpoint=0, checkpoint_interval=10000, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', disp_interval=100, large_scale=False, lr=0.001, lr_decay_gamma=0.1, lr_decay_step=5, mGPUs=False, max_epochs=10, net='res101', num_workers=2, optimizer='sgd', resume=False, save_dir='models', session=1, start_epoch=1, use_tfboard=True)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0 python demo.py --net vgg16 --dataset Race  --checksession 1  --checkepoch 10 \
                --checkpoint 957  --cuda --load_dir models
# Out:
# Called with args:
# Namespace(batch_size=1, cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', image_dir='images', load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False, webcam_num=-1)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Emotion --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Gender --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Age --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Age', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Race --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Emotion --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Gender --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Age --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Age', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Race --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Race', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# test 2.0

# %%
# !python test_net.py --dataset Emotion --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Gender --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Age --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Age', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Race --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
# ...

# %%
# !python test_net.py --dataset Emotion --cfg 'cfgs/res101.yml' --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/res101.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Gender --cfg 'cfgs/res101.yml' --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/res101.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Age --cfg 'cfgs/res101.yml' --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/res101.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Age', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...

# %%
# !python test_net.py --dataset Race --cfg 'cfgs/res101.yml' --net res101 --checksession 1 --checkepoch 10 --checkpoint 1915 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/res101.yml', checkepoch=10, checkpoint=1915, checksession=1, class_agnostic=False, cuda=True, dataset='Race', large_scale=False, load_dir='models', mGPUs=False, net='res101', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
# ...
