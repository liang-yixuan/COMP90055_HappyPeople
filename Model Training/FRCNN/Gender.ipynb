# %%
# %cd /mnt/FasterRCNN/faster-rcnn.pytorch
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# !pip install -r requirements.txt
# !pip install scipy==1.2.1
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting cython
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/48/bbca549da0b0f636c0f161e84d30172c40aafe99552680f297da7fedf102/Cython-0.29.24-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 32.5 MB/s eta 0:00:01
# Requirement already satisfied: cffi in /root/miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.14.0)
# Collecting opencv-python
#   Downloading https://mirrors.aliyun.com/pypi/packages/6b/73/a8921d221a673600dc744033786eeab56ed5116686a1b932b724a33003c6/opencv_python-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (49.9 MB)
#      |████████████████████████████████| 49.9 MB 7.2 MB/s eta 0:00:013    |██                              | 3.1 MB 45.6 MB/s eta 0:00:02     |███████████                     | 17.1 MB 11.1 MB/s eta 0:00:03     |███████████████                 | 23.3 MB 11.1 MB/s eta 0:00:03     |███████████████████▎            | 30.1 MB 7.4 MB/s eta 0:00:03     |████████████████████████████▊   | 44.9 MB 7.2 MB/s eta 0:00:01
# Collecting scipy
#   Downloading https://mirrors.aliyun.com/pypi/packages/b5/6b/8bc0b61ebf824f8c3979a31368bbe38dd247590049a994ab0ed077cb56dc/scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 8.3 MB/s eta 0:00:01     |████▋                           | 4.1 MB 59.8 MB/s eta 0:00:01     |███████████████████             | 17.0 MB 9.6 MB/s eta 0:00:02
# Collecting msgpack
#   Downloading https://mirrors.aliyun.com/pypi/packages/b7/88/b0d0c339044360036e51d3afda0d2b0f9503087fddff8867496198b24cda/msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
#      |████████████████████████████████| 273 kB 7.0 MB/s eta 0:00:01
# Collecting easydict
#   Downloading https://mirrors.aliyun.com/pypi/packages/4c/c5/5757886c4f538c1b3f95f6745499a24bffa389a805dee92d093e2d9ba7db/easydict-1.9.tar.gz (6.4 kB)
# Collecting matplotlib
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/ec/3d77b10ac3d30590f5431fd2dc59c58d20c020af107b47f8974896afc5c9/matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 31.7 MB/s eta 0:00:01    |███▉                            | 1.2 MB 31.7 MB/s eta 0:00:01     |█████████████████████████▏      | 8.1 MB 31.7 MB/s eta 0:00:01     |█████████████████████████████▌  | 9.5 MB 31.7 MB/s eta 0:00:01     |███████████████████████████████▏| 10.0 MB 31.7 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading https://mirrors.aliyun.com/pypi/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 33.2 MB/s eta 0:00:01
# Collecting tensorboardX
#   Downloading https://mirrors.aliyun.com/pypi/packages/99/0b/a26bbe92667c549d39c40b80c5ddec638fbae9521f04aeef26560e07e504/tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 66.7 MB/s eta 0:00:01
# Requirement already satisfied: pycparser in /root/miniconda3/lib/python3.7/site-packages (from cffi->-r requirements.txt (line 2)) (2.19)
# Collecting numpy>=1.14.5
#   Downloading https://mirrors.aliyun.com/pypi/packages/68/2d/0fe6592a96a1da097a33fb87b9618197c8a1801e84c7483fa7b93794a87c/numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 10.0 MB/s eta 0:00:01    |███████████████                 | 7.4 MB 54.9 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.8.1)
# Collecting kiwisolver>=1.0.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/09/6b/6e567cb2e86d4e5939a9233f8734e26021b6a9c1bc4b1edccba236a84cc2/kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 65.7 MB/s eta 0:00:01
# Collecting cycler>=0.10
#   Downloading https://mirrors.aliyun.com/pypi/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/41/07/ecb2a0d55460385163c82a4bd65263a00510966dddbd54876796bd18857c/Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 1.3 MB/s eta 0:00:01
# Collecting protobuf>=3.8.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/6e/62/eeec5be0b69442d2ffc7acdf54469fb4c76aa42288fe38decc537973a90a/protobuf-3.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 670 kB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /root/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 7)) (1.14.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6349 sha256=b9ea01bb6d6e81f2705d843af2a8d51edac6d4da8f5c46aa8d3845ccf6100131
#   Stored in directory: /root/.cache/pip/wheels/fd/84/74/82b22ad24a25b8d076e622a39a4af726d0909790f5c299451c
# Successfully built easydict
# Installing collected packages: cython, numpy, opencv-python, scipy, msgpack, easydict, kiwisolver, cycler, pillow, matplotlib, pyyaml, protobuf, tensorboardX
# Successfully installed cycler-0.10.0 cython-0.29.24 easydict-1.9 kiwisolver-1.3.2 matplotlib-3.4.3 msgpack-1.0.2 numpy-1.21.2 opencv-python-4.5.3.56 pillow-8.3.2 protobuf-3.18.1 pyyaml-5.4.1 scipy-1.7.1 tensorboardX-2.4
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting scipy==1.2.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/3e/7e/5cee36eee5b3194687232f6150a89a38f784883c612db7f4da2ab190980d/scipy-1.2.1-cp37-cp37m-manylinux1_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 9.6 MB/s eta 0:00:01    |████                            | 3.1 MB 1.5 MB/s eta 0:00:15     |██████████████████████████████▊ | 23.8 MB 9.6 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.8.2 in /root/miniconda3/lib/python3.7/site-packages (from scipy==1.2.1) (1.21.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
# Successfully installed scipy-1.2.1

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting pycocotools
#   Downloading https://mirrors.aliyun.com/pypi/packages/de/df/056875d697c45182ed6d2ae21f62015896fdb841906fe48e7268e791c467/pycocotools-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: setuptools>=18.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (45.2.0.post20200210)
# Requirement already satisfied: cython>=0.27.3 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (0.29.24)
# Requirement already satisfied: matplotlib>=2.1.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (3.4.3)
# Requirement already satisfied: pillow>=6.2.0 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (8.3.2)
# Requirement already satisfied: cycler>=0.10 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.3.2)
# Requirement already satisfied: numpy>=1.16 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.21.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.4.7)
# Requirement already satisfied: six in /root/miniconda3/lib/python3.7/site-packages (from cycler>=0.10->matplotlib>=2.1.0->pycocotools) (1.14.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272852 sha256=dda9f7cf35de14fbd6d2ca9b200a8a8904a26873b5e2c2e1973ab54e1fc432ec
#   Stored in directory: /root/.cache/pip/wheels/60/03/30/0cc037d5ac8ecd261e4c9e4fdb4f2c429074cd52a7a844c61e
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.2

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !conda install ipykernel -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# Warning: >10 possible package resolutions (only showing differing packages):
#   - https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   - defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   ... and othedone
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.7.5   |       h06a4308_1         113 KB  defaults
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB  defaults
#     conda-4.10.3               |   py37h06a4308_0         2.9 MB  defaults
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         179 KB  defaults
#     openssl-1.1.1l             |       h7f8727e_0         2.5 MB  defaults
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.7.5-h06a4308_1
#   certifi            conda-forge::certifi-2020.12.5-py37h8~ --> pkgs/main::certifi-2021.5.30-py37h06a4308_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.10.3-py37h06a4308_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1l-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ipykernel          conda-forge::ipykernel-5.4.2-py37h888~ --> pkgs/main::ipykernel-5.3.4-py37h5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
# ipykernel-5.3.4      | 179 KB    | ##################################### | 100%
# ca-certificates-2021 | 113 KB    | ##################################### | 100%
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# certifi-2021.5.30    | 139 KB    | ##################################### | 100%
# openssl-1.1.1l       | 2.5 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torch
#   Downloading https://mirrors.aliyun.com/pypi/packages/ad/da/a1693073397b30fc3390def5a33cbe630f1b9446ea296845680af95080af/torch-1.9.1-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 3.7 MB/s eta 0:00:012  |▍                               | 9.0 MB 3.5 MB/s eta 0:03:57     |█                               | 23.1 MB 21.6 MB/s eta 0:00:38     |█▍                              | 36.6 MB 3.7 MB/s eta 0:03:34     |█▌                              | 38.3 MB 3.7 MB/s eta 0:03:33     |█▉                              | 46.4 MB 857 kB/s eta 0:15:16     |██                              | 50.8 MB 4.6 MB/s eta 0:02:50     |██▏                             | 55.5 MB 4.6 MB/s eta 0:02:49     |██▍                             | 62.5 MB 2.6 MB/s eta 0:04:57     |██▊                             | 69.6 MB 8.8 MB/s eta 0:01:28     |██▉                             | 72.8 MB 8.8 MB/s eta 0:01:27     |███                             | 75.6 MB 6.1 MB/s eta 0:02:04     |███                             | 76.0 MB 6.1 MB/s eta 0:02:04     |███▎                            | 84.9 MB 8.0 MB/s eta 0:01:34     |███▌                            | 89.7 MB 8.0 MB/s eta 0:01:33     |████                            | 101.4 MB 7.3 MB/s eta 0:01:40     |████                            | 105.9 MB 9.9 MB/s eta 0:01:13     |████▏                           | 107.4 MB 9.9 MB/s eta 0:01:13     |████▏                           | 108.2 MB 9.9 MB/s eta 0:01:13     |████▎                           | 110.3 MB 10.5 MB/s eta 0:01:09     |████▊                           | 122.1 MB 4.6 MB/s eta 0:02:36     |█████                           | 129.3 MB 45.8 MB/s eta 0:00:16     |█████▌                          | 141.8 MB 7.6 MB/s eta 0:01:31     |█████▋                          | 144.8 MB 7.6 MB/s eta 0:01:31     |█████▋                          | 146.9 MB 7.6 MB/s eta 0:01:30     |██████                          | 157.4 MB 6.6 MB/s eta 0:01:43     |██████▌                         | 169.6 MB 2.3 MB/s eta 0:04:45     |██████▉                         | 178.2 MB 19.3 MB/s eta 0:00:34     |███████                         | 179.7 MB 5.1 MB/s eta 0:02:08     |███████▉                        | 203.4 MB 3.1 MB/s eta 0:03:24     |████████▍                       | 216.8 MB 344 kB/s eta 0:29:47     |█████████▎                      | 241.5 MB 7.8 MB/s eta 0:01:16     |██████████▎                     | 265.9 MB 3.4 MB/s eta 0:02:45     |██████████▍                     | 268.7 MB 3.7 MB/s eta 0:02:32     |██████████▊                     | 279.6 MB 10.4 MB/s eta 0:00:53     |██████████▉                     | 282.0 MB 3.4 MB/s eta 0:02:43     |███████████                     | 285.4 MB 4.8 MB/s eta 0:01:54     |█████████████▎                  | 343.9 MB 6.3 MB/s eta 0:01:18     |█████████████▍                  | 346.6 MB 6.2 MB/s eta 0:01:19     |██████████████▌                 | 376.6 MB 7.8 MB/s eta 0:00:59     |███████████████                 | 390.0 MB 8.3 MB/s eta 0:00:53     |███████████████▍                | 398.4 MB 8.1 MB/s eta 0:00:54     |███████████████▍                | 399.8 MB 7.6 MB/s eta 0:00:57     |████████████████▍               | 424.8 MB 7.0 MB/s eta 0:00:59     |████████████████▌               | 429.8 MB 7.0 MB/s eta 0:00:58     |█████████████████               | 442.3 MB 2.4 MB/s eta 0:02:42     |█████████████████▏              | 446.2 MB 5.1 MB/s eta 0:01:15     |█████████████████▌              | 453.6 MB 7.0 MB/s eta 0:00:54     |█████████████████▋              | 457.5 MB 7.0 MB/s eta 0:00:54     |██████████████████▏             | 471.4 MB 3.5 MB/s eta 0:01:42     |███████████████████▍            | 504.7 MB 6.5 MB/s eta 0:00:51     |███████████████████▉            | 515.8 MB 7.0 MB/s eta 0:00:45     |████████████████████▎           | 525.7 MB 6.8 MB/s eta 0:00:46     |████████████████████▋           | 534.2 MB 4.4 MB/s eta 0:01:08     |█████████████████████▎          | 552.3 MB 27.0 MB/s eta 0:00:11     |█████████████████████▌          | 557.3 MB 27.0 MB/s eta 0:00:11     |█████████████████████▌          | 558.3 MB 27.0 MB/s eta 0:00:11     |█████████████████████▌          | 559.8 MB 27.0 MB/s eta 0:00:11     | ...
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch) (3.7.4.3)
# Installing collected packages: torch
# Successfully installed torch-1.9.1
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torchvision
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/6c/daa50a536812da895a4eecaefdffbffd90736c47898d942501080a5b42a5/torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 4.3 MB/s eta 0:00:01    |█████████████▏                  | 9.1 MB 4.5 MB/s eta 0:00:03     |███████████████████▊            | 13.7 MB 7.7 MB/s eta 0:00:02     |██████████████████████          | 15.2 MB 7.7 MB/s eta 0:00:01     |█████████████████████████▌      | 17.7 MB 6.2 MB/s eta 0:00:01     |███████████████████████████▏    | 18.8 MB 6.2 MB/s eta 0:00:01     |█████████████████████████████▉  | 20.6 MB 4.3 MB/s eta 0:00:01     |██████████████████████████████▎ | 20.9 MB 4.3 MB/s eta 0:00:01     |███████████████████████████████▉| 22.0 MB 4.3 MB/s eta 0:00:01
# Requirement already satisfied: torch==1.9.1 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.9.1)
# Requirement already satisfied: pillow>=5.3.0 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (8.3.2)
# Requirement already satisfied: numpy in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.21.2)
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch==1.9.1->torchvision) (3.7.4.3)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.10.1

# %%
# %cd lib
# !python setup.py build develop
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# running build
# running build_py
# running build_ext
# /root/miniconda3/lib/python3.7/site-packages/torch/utils/cpp_extension.py:370: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running develop
# running egg_info
# writing faster_rcnn.egg-info/PKG-INFO
# writing dependency_links to faster_rcnn.egg-info/dependency_links.txt
# writing top-level names to faster_rcnn.egg-info/top_level.txt
# reading manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# writing manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.7/model/_C.cpython-37m-x86_64-linux-gnu.so -> model
# Creating /root/miniconda3/lib/python3.7/site-packages/faster-rcnn.egg-link (link to .)
# Adding faster-rcnn 0.1 to easy-install.pth file
#
# Installed /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# Processing dependencies for faster-rcnn==0.1
# Finished processing dependencies for faster-rcnn==0.1

# %%
# %cd ..
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# modify trainval_net.py line 195

# !CUDA_VISIBLE_DEVICES=0 python trainval_net.py \
                   --dataset Gender --net res101 \
                   --epoch 10 --bs 8 --nw 2\
                   --lr 1e-3 --lr_decay_step 5 \
                   --cuda --use_tfb  
#                    --r True --checksession 1 --checkepoch 5 --checkpoint 765
# Out:
# Called with args:
# Namespace(batch_size=8, checkepoch=1, checkpoint=0, checkpoint_interval=10000, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', disp_interval=100, large_scale=False, lr=0.001, lr_decay_gamma=0.1, lr_decay_step=5, mGPUs=False, max_epochs=10, net='res101', num_workers=2, optimizer='sgd', resume=False, save_dir='models', session=1, start_epoch=1, use_tfboard=True)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 20,
#            'DOUBLE_BIAS': False,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.001,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0001},
#  'USE_GPU_NMS': True}
# Loaded dataset `Gender` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Gender_gt_roidb.pkl
# done
# before filtering, there are 15330 images...
# after filtering, there are 15330 images...
# 15330 roidb entries
# Loading pretrained weights from data/pretrained_model/resnet101_caffe.pth
# [session 1][epoch  1][iter    0/1916] loss: 2.3514, lr: 1.00e-03
# 			fg/bg=(45/979), time cost: 1.952099
# 			rpn_cls: 0.7280, rpn_box: 0.0431, rcnn_cls: 1.4685, rcnn_box 0.1118
# [session 1][epoch  1][iter  100/1916] loss: 0.8053, lr: 1.00e-03
# 			fg/bg=(183/841), time cost: 95.866612
# 			rpn_cls: 0.0102, rpn_box: 0.0110, rcnn_cls: 0.2316, rcnn_box 0.2286
# [session 1][epoch  1][iter  200/1916] loss: 0.4354, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.157359
# 			rpn_cls: 0.0023, rpn_box: 0.0073, rcnn_cls: 0.2176, rcnn_box 0.1088
# [session 1][epoch  1][iter  300/1916] loss: 0.3466, lr: 1.00e-03
# 			fg/bg=(230/794), time cost: 96.787270
# 			rpn_cls: 0.0168, rpn_box: 0.0075, rcnn_cls: 0.2551, rcnn_box 0.2555
# [session 1][epoch  1][iter  400/1916] loss: 0.3132, lr: 1.00e-03
# 			fg/bg=(231/793), time cost: 96.594261
# 			rpn_cls: 0.0307, rpn_box: 0.0087, rcnn_cls: 0.3743, rcnn_box 0.1663
# [session 1][epoch  1][iter  500/1916] loss: 0.2843, lr: 1.00e-03
# 			fg/bg=(229/795), time cost: 96.666086
# 			rpn_cls: 0.0020, rpn_box: 0.0052, rcnn_cls: 0.1246, rcnn_box 0.0964
# [session 1][epoch  1][iter  600/1916] loss: 0.2806, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 96.681550
# 			rpn_cls: 0.0015, rpn_box: 0.0069, rcnn_cls: 0.1141, rcnn_box 0.0590
# [session 1][epoch  1][iter  700/1916] loss: 0.2556, lr: 1.00e-03
# 			fg/bg=(238/786), time cost: 97.175997
# 			rpn_cls: 0.0090, rpn_box: 0.0030, rcnn_cls: 0.2224, rcnn_box 0.0795
# [session 1][epoch  1][iter  800/1916] loss: 0.2707, lr: 1.00e-03
# 			fg/bg=(226/798), time cost: 96.767660
# 			rpn_cls: 0.0033, rpn_box: 0.0048, rcnn_cls: 0.1119, rcnn_box 0.0989
# [session 1][epoch  1][iter  900/1916] loss: 0.2489, lr: 1.00e-03
# 			fg/bg=(209/815), time cost: 96.946506
# 			rpn_cls: 0.0034, rpn_box: 0.0028, rcnn_cls: 0.1295, rcnn_box 0.0478
# [session 1][epoch  1][iter 1000/1916] loss: 0.2418, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 97.151414
# 			rpn_cls: 0.0011, rpn_box: 0.0018, rcnn_cls: 0.1905, rcnn_box 0.0412
# [session 1][epoch  1][iter 1100/1916] loss: 0.2301, lr: 1.00e-03
# 			fg/bg=(219/805), time cost: 96.930814
# 			rpn_cls: 0.0336, rpn_box: 0.0098, rcnn_cls: 0.2303, rcnn_box 0.1182
# [session 1][epoch  1][iter 1200/1916] loss: 0.2394, lr: 1.00e-03
# 			fg/bg=(227/797), time cost: 96.812958
# 			rpn_cls: 0.0409, rpn_box: 0.0051, rcnn_cls: 0.1650, rcnn_box 0.0849
# [session 1][epoch  1][iter 1300/1916] loss: 0.2297, lr: 1.00e-03
# 			fg/bg=(229/795), time cost: 97.470048
# 			rpn_cls: 0.0073, rpn_box: 0.0081, rcnn_cls: 0.1856, rcnn_box 0.0821
# [session 1][epoch  1][iter 1400/1916] loss: 0.2244, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 97.406530
# 			rpn_cls: 0.0260, rpn_box: 0.0041, rcnn_cls: 0.2132, rcnn_box 0.0622
# [session 1][epoch  1][iter 1500/1916] loss: 0.2219, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 96.902348
# 			rpn_cls: 0.0031, rpn_box: 0.0034, rcnn_cls: 0.0989, rcnn_box 0.0443
# [session 1][epoch  1][iter 1600/1916] loss: 0.2363, lr: 1.00e-03
# 			fg/bg=(238/786), time cost: 97.087561
# 			rpn_cls: 0.0011, rpn_box: 0.0024, rcnn_cls: 0.3195, rcnn_box 0.0770
# [session 1][epoch  1][iter 1700/1916] loss: 0.2096, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 98.085803
# 			rpn_cls: 0.0124, rpn_box: 0.0024, rcnn_cls: 0.1083, rcnn_box 0.0517
# [session 1][epoch  1][iter 1800/1916] loss: 0.2170, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.996319
# 			rpn_cls: 0.0011, rpn_box: 0.0014, rcnn_cls: 0.0869, rcnn_box 0.0371
# [session 1][epoch  1][iter 1900/1916] loss: 0.2113, lr: 1.00e-03
# 			fg/bg=(203/821), time cost: 96.966188
# 			rpn_cls: 0.0026, rpn_box: 0.0020, rcnn_cls: 0.1307, rcnn_box 0.0407
# [session 1][epoch  2][iter    0/1916] loss: 0.1403, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 1.342411
# 			rpn_cls: 0.0007, rpn_box: 0.0022, rcnn_cls: 0.0983, rcnn_box 0.0392
# [session 1][epoch  2][iter  100/1916] loss: 0.1815, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 97.060193
# 			rpn_cls: 0.0015, rpn_box: 0.0049, rcnn_cls: 0.0778, rcnn_box 0.0274
# [session 1][epoch  2][iter  200/1916] loss: 0.1985, lr: 1.00e-03
# 			fg/bg=(234/790), time cost: 96.978902
# 			rpn_cls: 0.0012, rpn_box: 0.0027, rcnn_cls: 0.1464, rcnn_box 0.0279
# [session 1][epoch  2][iter  300/1916] loss: 0.1857, lr: 1.00e-03
# 			fg/bg=(243/781), time cost: 96.984461
# 			rpn_cls: 0.0010, rpn_box: 0.0041, rcnn_cls: 0.0697, rcnn_box 0.0682
# [session 1][epoch  2][iter  400/1916] loss: 0.1767, lr: 1.00e-03
# 			fg/bg=(224/800), time cost: 97.078333
# 			rpn_cls: 0.0127, rpn_box: 0.0041, rcnn_cls: 0.1935, rcnn_box 0.0890
# [session 1][epoch  2][iter  500/1916] loss: 0.1768, lr: 1.00e-03
# 			fg/bg=(219/805), time cost: 96.878793
# 			rpn_cls: 0.0005, rpn_box: 0.0010, rcnn_cls: 0.2038, rcnn_box 0.0319
# [session 1][epoch  2][iter  600/1916] loss: 0.2038, lr: 1.00e-03
# 			fg/bg=(228/796), time cost: 96.778343
# 			rpn_cls: 0.0011, rpn_box: 0.0028, rcnn_cls: 0.1817, rcnn_box 0.0754
# [session 1][epoch  2][iter  700/1916] loss: 0.1766, lr: 1.00e-03
# 			fg/bg=(230/794), time cost: 97.020764
# 			rpn_cls: 0.0009, rpn_box: 0.0028, rcnn_cls: 0.1517, rcnn_box 0.0314
# [session 1][epoch  2][iter  800/1916] loss: 0.1729, lr: 1.00e-03
# 			fg/bg=(224/800), time cost: 97.028065
# 			rpn_cls: 0.0014, rpn_box: 0.0033, rcnn_cls: 0.1521, rcnn_box 0.0438
# [session 1][epoch  2][iter  900/1916] loss: 0.1657, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.972239
# 			rpn_cls: 0.0083, rpn_box: 0.0022, rcnn_cls: 0.1756, rcnn_box 0.0395
# [session 1][epoch  2][iter 1000/1916] loss: 0.1731, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 97.078757
# 			rpn_cls: 0.0030, rpn_box: 0.0039, rcnn_cls: 0.0741, rcnn_box 0.0431
# [session 1][epoch  2][iter 1100/1916] loss: 0.1757, lr: 1.00e-03
# 			fg/bg=(240/784), time cost: 96.857169
# 			rpn_cls: 0.0053, rpn_box: 0.0026, rcnn_cls: 0.2156, rcnn_box 0.0546
# [session 1][epoch  2][iter 1200/1916] loss: 0.1969, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.932081
# 			rpn_cls: 0.0190, rpn_box: 0.0051, rcnn_cls: 0.1590, rcnn_box 0.1059
# [session 1][epoch  2][iter 1300/1916] loss: 0.1753, lr: 1.00e-03
# 			fg/bg=(234/790), time cost: 96.817176
# 			rpn_cls: 0.0086, rpn_box: 0.0021, rcnn_cls: 0.1547, rcnn_box 0.0415
# [session 1][epoch  2][iter 1400/1916] loss: 0.1729, lr: 1.00e-03
# 			fg/bg=(229/795), time cost: 97.667795
# 			rpn_cls: 0.0041, rpn_box: 0.0034, rcnn_cls: 0.2639, rcnn_box 0.0882
# [session 1][epoch  2][iter 1500/1916] loss: 0.1788, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.899927
# 			rpn_cls: 0.0028, rpn_box: 0.0035, rcnn_cls: 0.0698, rcnn_box 0.0641
# [session 1][epoch  2][iter 1600/1916] loss: 0.1647, lr: 1.00e-03
# 			fg/bg=(221/803), time cost: 97.061018
# 			rpn_cls: 0.0011, rpn_box: 0.0019, rcnn_cls: 0.0399, rcnn_box 0.0298
# [session 1][epoch  2][iter 1700/1916] loss: 0.1603, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 96.977883
# 			rpn_cls: 0.0139, rpn_box: 0.0026, rcnn_cls: 0.1829, rcnn_box 0.1399
# [session 1][epoch  2][iter 1800/1916] loss: 0.1636, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 96.940846
# 			rpn_cls: 0.0066, rpn_box: 0.0046, rcnn_cls: 0.0696, rcnn_box 0.0374
# [session 1][epoch  2][iter 1900/1916] loss: 0.1612, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 97.051649
# 			rpn_cls: 0.0020, rpn_box: 0.0026, rcnn_cls: 0.1330, rcnn_box 0.0337
# [session 1][epoch  3][iter    0/1916] loss: 0.0990, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 1.337743
# 			rpn_cls: 0.0018, rpn_box: 0.0022, rcnn_cls: 0.0678, rcnn_box 0.0272
# [session 1][epoch  3][iter  100/1916] loss: 0.1549, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 96.927263
# 			rpn_cls: 0.0030, rpn_box: 0.0016, rcnn_cls: 0.2019, rcnn_box 0.0434
# [session 1][epoch  3][iter  200/1916] loss: 0.1653, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.967636
# 			rpn_cls: 0.0064, rpn_box: 0.0022, rcnn_cls: 0.1530, rcnn_box 0.0405
# [session 1][epoch  3][iter  300/1916] loss: 0.1543, lr: 1.00e-03
# 			fg/bg=(234/790), time cost: 97.042766
# 			rpn_cls: 0.0009, rpn_box: 0.0038, rcnn_cls: 0.0615, rcnn_box 0.0442
# [session 1][epoch  3][iter  400/1916] loss: 0.1452, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 96.927070
# 			rpn_cls: 0.0011, rpn_box: 0.0036, rcnn_cls: 0.0830, rcnn_box 0.0402
# [session 1][epoch  3][iter  500/1916] loss: 0.1330, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 96.945427
# 			rpn_cls: 0.0020, rpn_box: 0.0030, rcnn_cls: 0.0430, rcnn_box 0.0209
# [session 1][epoch  3][iter  600/1916] loss: 0.1540, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 96.855439
# 			rpn_cls: 0.0013, rpn_box: 0.0022, rcnn_cls: 0.0671, rcnn_box 0.0250
# [session 1][epoch  3][iter  700/1916] loss: 0.1420, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.815406
# 			rpn_cls: 0.0160, rpn_box: 0.0023, rcnn_cls: 0.0439, rcnn_box 0.0266
# [session 1][epoch  3][iter  800/1916] loss: 0.1424, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 96.888599
# 			rpn_cls: 0.0013, rpn_box: 0.0022, rcnn_cls: 0.0652, rcnn_box 0.0394
# [session 1][epoch  3][iter  900/1916] loss: 0.1500, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 97.058377
# 			rpn_cls: 0.0008, rpn_box: 0.0015, rcnn_cls: 0.1517, rcnn_box 0.0232
# [session 1][epoch  3][iter 1000/1916] loss: 0.1614, lr: 1.00e-03
# 			fg/bg=(224/800), time cost: 97.210102
# 			rpn_cls: 0.0053, rpn_box: 0.0018, rcnn_cls: 0.1276, rcnn_box 0.0208
# [session 1][epoch  3][iter 1100/1916] loss: 0.1436, lr: 1.00e-03
# 			fg/bg=(222/802), time cost: 96.551780
# 			rpn_cls: 0.0014, rpn_box: 0.0015, rcnn_cls: 0.0683, rcnn_box 0.0319
# [session 1][epoch  3][iter 1200/1916] loss: 0.1584, lr: 1.00e-03
# 			fg/bg=(222/802), time cost: 96.817480
# 			rpn_cls: 0.0012, rpn_box: 0.0024, rcnn_cls: 0.1104, rcnn_box 0.0421
# [session 1][epoch  3][iter 1300/1916] loss: 0.1406, lr: 1.00e-03
# 			fg/bg=(228/796), time cost: 96.807476
# 			rpn_cls: 0.0011, rpn_box: 0.0038, rcnn_cls: 0.0794, rcnn_box 0.0376
# [session 1][epoch  3][iter 1400/1916] loss: 0.1488, lr: 1.00e-03
# 			fg/bg=(198/826), time cost: 96.891014
# 			rpn_cls: 0.0018, rpn_box: 0.0042, rcnn_cls: 0.1482, rcnn_box 0.0583
# [session 1][epoch  3][iter 1500/1916] loss: 0.1500, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 97.391530
# 			rpn_cls: 0.0007, rpn_box: 0.0019, rcnn_cls: 0.0557, rcnn_box 0.0279
# [session 1][epoch  3][iter 1600/1916] loss: 0.1414, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 97.587830
# 			rpn_cls: 0.0009, rpn_box: 0.0025, rcnn_cls: 0.0815, rcnn_box 0.0388
# [session 1][epoch  3][iter 1700/1916] loss: 0.1448, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 96.893922
# 			rpn_cls: 0.0007, rpn_box: 0.0014, rcnn_cls: 0.1211, rcnn_box 0.0335
# [session 1][epoch  3][iter 1800/1916] loss: 0.1510, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 96.830969
# 			rpn_cls: 0.0006, rpn_box: 0.0016, rcnn_cls: 0.1392, rcnn_box 0.0235
# [session 1][epoch  3][iter 1900/1916] loss: 0.1484, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 96.654672
# 			rpn_cls: 0.0029, rpn_box: 0.0028, rcnn_cls: 0.1061, rcnn_box 0.0544
# [session 1][epoch  4][iter    0/1916] loss: 0.1263, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 1.333880
# 			rpn_cls: 0.0107, rpn_box: 0.0019, rcnn_cls: 0.0887, rcnn_box 0.0250
# [session 1][epoch  4][iter  100/1916] loss: 0.1305, lr: 1.00e-03
# 			fg/bg=(228/796), time cost: 96.773042
# 			rpn_cls: 0.0015, rpn_box: 0.0017, rcnn_cls: 0.0667, rcnn_box 0.0181
# [session 1][epoch  4][iter  200/1916] loss: 0.1273, lr: 1.00e-03
# 			fg/bg=(233/791), time cost: 97.419167
# 			rpn_cls: 0.0013, rpn_box: 0.0030, rcnn_cls: 0.0480, rcnn_box 0.0692
# [session 1][epoch  4][iter  300/1916] loss: 0.1191, lr: 1.00e-03
# 			fg/bg=(211/813), time cost: 96.802405
# 			rpn_cls: 0.0008, rpn_box: 0.0012, rcnn_cls: 0.1269, rcnn_box 0.0260
# [session 1][epoch  4][iter  400/1916] loss: 0.1308, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 96.874346
# 			rpn_cls: 0.0050, rpn_box: 0.0017, rcnn_cls: 0.0789, rcnn_box 0.0226
# [session 1][epoch  4][iter  500/1916] loss: 0.1303, lr: 1.00e-03
# 			fg/bg=(227/797), time cost: 96.934555
# 			rpn_cls: 0.0007, rpn_box: 0.0017, rcnn_cls: 0.0271, rcnn_box 0.0274
# [session 1][epoch  4][iter  600/1916] loss: 0.1359, lr: 1.00e-03
# 			fg/bg=(182/842), time cost: 96.756498
# 			rpn_cls: 0.0087, rpn_box: 0.0019, rcnn_cls: 0.1005, rcnn_box 0.0273
# [session 1][epoch  4][iter  700/1916] loss: 0.1335, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 96.821588
# 			rpn_cls: 0.0015, rpn_box: 0.0010, rcnn_cls: 0.1004, rcnn_box 0.0211
# [session 1][epoch  4][iter  800/1916] loss: 0.1193, lr: 1.00e-03
# 			fg/bg=(225/799), time cost: 96.798462
# 			rpn_cls: 0.0124, rpn_box: 0.0035, rcnn_cls: 0.0970, rcnn_box 0.0447
# [session 1][epoch  4][iter  900/1916] loss: 0.1275, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.706124
# 			rpn_cls: 0.0010, rpn_box: 0.0018, rcnn_cls: 0.0861, rcnn_box 0.0217
# [session 1][epoch  4][iter 1000/1916] loss: 0.1269, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.658574
# 			rpn_cls: 0.0013, rpn_box: 0.0023, rcnn_cls: 0.0460, rcnn_box 0.0316
# [session 1][epoch  4][iter 1100/1916] loss: 0.1248, lr: 1.00e-03
# 			fg/bg=(232/792), time cost: 96.715303
# 			rpn_cls: 0.0005, rpn_box: 0.0019, rcnn_cls: 0.0655, rcnn_box 0.0313
# [session 1][epoch  4][iter 1200/1916] loss: 0.1363, lr: 1.00e-03
# 			fg/bg=(228/796), time cost: 96.654374
# 			rpn_cls: 0.0008, rpn_box: 0.0015, rcnn_cls: 0.0342, rcnn_box 0.0296
# [session 1][epoch  4][iter 1300/1916] loss: 0.1271, lr: 1.00e-03
# 			fg/bg=(209/815), time cost: 96.547776
# 			rpn_cls: 0.0017, rpn_box: 0.0015, rcnn_cls: 0.0720, rcnn_box 0.0322
# [session 1][epoch  4][iter 1400/1916] loss: 0.1372, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 96.727954
# 			rpn_cls: 0.0081, rpn_box: 0.0008, rcnn_cls: 0.0388, rcnn_box 0.0134
# [session 1][epoch  4][iter 1500/1916] loss: 0.1273, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 96.877446
# 			rpn_cls: 0.0022, rpn_box: 0.0014, rcnn_cls: 0.1232, rcnn_box 0.0289
# [session 1][epoch  4][iter 1600/1916] loss: 0.1298, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 97.047335
# 			rpn_cls: 0.0008, rpn_box: 0.0022, rcnn_cls: 0.0480, rcnn_box 0.0158
# [session 1][epoch  4][iter 1700/1916] loss: 0.1288, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 96.759804
# 			rpn_cls: 0.0004, rpn_box: 0.0017, rcnn_cls: 0.1149, rcnn_box 0.0164
# [session 1][epoch  4][iter 1800/1916] loss: 0.1307, lr: 1.00e-03
# 			fg/bg=(209/815), time cost: 96.778286
# 			rpn_cls: 0.0019, rpn_box: 0.0014, rcnn_cls: 0.1055, rcnn_box 0.0530
# [session 1][epoch  4][iter 1900/1916] loss: 0.1341, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 96.969854
# 			rpn_cls: 0.0010, rpn_box: 0.0024, rcnn_cls: 0.2273, rcnn_box 0.0355
# [session 1][epoch  5][iter    0/1916] loss: 0.1270, lr: 1.00e-03
# 			fg/bg=(229/795), time cost: 1.549296
# 			rpn_cls: 0.0056, rpn_box: 0.0022, rcnn_cls: 0.0923, rcnn_box 0.0268
# [session 1][epoch  5][iter  100/1916] loss: 0.1037, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.641964
# 			rpn_cls: 0.0010, rpn_box: 0.0010, rcnn_cls: 0.0524, rcnn_box 0.0234
# [session 1][epoch  5][iter  200/1916] loss: 0.1102, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.596590
# 			rpn_cls: 0.0109, rpn_box: 0.0012, rcnn_cls: 0.0454, rcnn_box 0.0146
# [session 1][epoch  5][iter  300/1916] loss: 0.1257, lr: 1.00e-03
# 			fg/bg=(195/829), time cost: 96.484698
# 			rpn_cls: 0.0012, rpn_box: 0.0013, rcnn_cls: 0.0665, rcnn_box 0.0195
# [session 1][epoch  5][iter  400/1916] loss: 0.1127, lr: 1.00e-03
# 			fg/bg=(222/802), time cost: 96.523785
# 			rpn_cls: 0.0006, rpn_box: 0.0013, rcnn_cls: 0.1490, rcnn_box 0.0255
# [session 1][epoch  5][iter  500/1916] loss: 0.1220, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.645539
# 			rpn_cls: 0.0018, rpn_box: 0.0020, rcnn_cls: 0.0768, rcnn_box 0.0308
# [session 1][epoch  5][iter  600/1916] loss: 0.1048, lr: 1.00e-03
# 			fg/bg=(216/808), time cost: 96.630746
# 			rpn_cls: 0.0012, rpn_box: 0.0035, rcnn_cls: 0.0956, rcnn_box 0.0405
# [session 1][epoch  5][iter  700/1916] loss: 0.1204, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.920076
# 			rpn_cls: 0.0006, rpn_box: 0.0011, rcnn_cls: 0.0278, rcnn_box 0.0119
# [session 1][epoch  5][iter  800/1916] loss: 0.1084, lr: 1.00e-03
# 			fg/bg=(202/822), time cost: 96.580937
# 			rpn_cls: 0.0021, rpn_box: 0.0013, rcnn_cls: 0.0647, rcnn_box 0.0150
# [session 1][epoch  5][iter  900/1916] loss: 0.1205, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 96.588313
# 			rpn_cls: 0.0055, rpn_box: 0.0008, rcnn_cls: 0.0986, rcnn_box 0.0197
# [session 1][epoch  5][iter 1000/1916] loss: 0.1200, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 97.424344
# 			rpn_cls: 0.0067, rpn_box: 0.0047, rcnn_cls: 0.0694, rcnn_box 0.0283
# [session 1][epoch  5][iter 1100/1916] loss: 0.1220, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 97.110699
# 			rpn_cls: 0.0094, rpn_box: 0.0044, rcnn_cls: 0.0644, rcnn_box 0.0397
# [session 1][epoch  5][iter 1200/1916] loss: 0.1055, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 96.822891
# 			rpn_cls: 0.0006, rpn_box: 0.0009, rcnn_cls: 0.0260, rcnn_box 0.0156
# [session 1][epoch  5][iter 1300/1916] loss: 0.1176, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.614078
# 			rpn_cls: 0.0011, rpn_box: 0.0023, rcnn_cls: 0.0818, rcnn_box 0.0199
# [session 1][epoch  5][iter 1400/1916] loss: 0.1197, lr: 1.00e-03
# 			fg/bg=(234/790), time cost: 96.630036
# 			rpn_cls: 0.0050, rpn_box: 0.0028, rcnn_cls: 0.1209, rcnn_box 0.0343
# [session 1][epoch  5][iter 1500/1916] loss: 0.1212, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 96.665672
# 			rpn_cls: 0.0006, rpn_box: 0.0014, rcnn_cls: 0.0342, rcnn_box 0.0212
# [session 1][epoch  5][iter 1600/1916] loss: 0.1131, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 96.705038
# 			rpn_cls: 0.0008, rpn_box: 0.0022, rcnn_cls: 0.0653, rcnn_box 0.0288
# [session 1][epoch  5][iter 1700/1916] loss: 0.1220, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.667284
# 			rpn_cls: 0.0006, rpn_box: 0.0013, rcnn_cls: 0.0703, rcnn_box 0.0206
# [session 1][epoch  5][iter 1800/1916] loss: 0.1132, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.647012
# 			rpn_cls: 0.0036, rpn_box: 0.0011, rcnn_cls: 0.0935, rcnn_box 0.0252
# [session 1][epoch  5][iter 1900/1916] loss: 0.1106, lr: 1.00e-03
# 			fg/bg=(182/842), time cost: 96.559030
# 			rpn_cls: 0.0017, rpn_box: 0.0018, rcnn_cls: 0.1257, rcnn_box 0.0226
# [session 1][epoch  6][iter    0/1916] loss: 0.0741, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 1.388020
# 			rpn_cls: 0.0017, rpn_box: 0.0022, rcnn_cls: 0.0504, rcnn_box 0.0198
# [session 1][epoch  6][iter  100/1916] loss: 0.0944, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.498858
# 			rpn_cls: 0.0009, rpn_box: 0.0032, rcnn_cls: 0.0572, rcnn_box 0.0181
# [session 1][epoch  6][iter  200/1916] loss: 0.0878, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.728371
# 			rpn_cls: 0.0006, rpn_box: 0.0009, rcnn_cls: 0.0264, rcnn_box 0.0123
# [session 1][epoch  6][iter  300/1916] loss: 0.0893, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.845733
# 			rpn_cls: 0.0087, rpn_box: 0.0017, rcnn_cls: 0.0595, rcnn_box 0.0153
# [session 1][epoch  6][iter  400/1916] loss: 0.0809, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 97.181516
# 			rpn_cls: 0.0063, rpn_box: 0.0013, rcnn_cls: 0.0290, rcnn_box 0.0211
# [session 1][epoch  6][iter  500/1916] loss: 0.0906, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.743413
# 			rpn_cls: 0.0020, rpn_box: 0.0006, rcnn_cls: 0.0530, rcnn_box 0.0131
# [session 1][epoch  6][iter  600/1916] loss: 0.0888, lr: 1.00e-04
# 			fg/bg=(223/801), time cost: 96.633162
# 			rpn_cls: 0.0004, rpn_box: 0.0011, rcnn_cls: 0.0335, rcnn_box 0.0280
# [session 1][epoch  6][iter  700/1916] loss: 0.0848, lr: 1.00e-04
# 			fg/bg=(207/817), time cost: 96.714360
# 			rpn_cls: 0.0006, rpn_box: 0.0010, rcnn_cls: 0.0455, rcnn_box 0.0198
# [session 1][epoch  6][iter  800/1916] loss: 0.0810, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.741818
# 			rpn_cls: 0.0019, rpn_box: 0.0023, rcnn_cls: 0.0758, rcnn_box 0.0262
# [session 1][epoch  6][iter  900/1916] loss: 0.0853, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.566278
# 			rpn_cls: 0.0097, rpn_box: 0.0041, rcnn_cls: 0.0199, rcnn_box 0.0152
# [session 1][epoch  6][iter 1000/1916] loss: 0.0787, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.865608
# 			rpn_cls: 0.0006, rpn_box: 0.0006, rcnn_cls: 0.0638, rcnn_box 0.0119
# [session 1][epoch  6][iter 1100/1916] loss: 0.0842, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.640591
# 			rpn_cls: 0.0007, rpn_box: 0.0014, rcnn_cls: 0.0263, rcnn_box 0.0173
# [session 1][epoch  6][iter 1200/1916] loss: 0.0746, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.697191
# 			rpn_cls: 0.0147, rpn_box: 0.0017, rcnn_cls: 0.0495, rcnn_box 0.0182
# [session 1][epoch  6][iter 1300/1916] loss: 0.0775, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.657087
# 			rpn_cls: 0.0003, rpn_box: 0.0006, rcnn_cls: 0.0240, rcnn_box 0.0131
# [session 1][epoch  6][iter 1400/1916] loss: 0.0774, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.658812
# 			rpn_cls: 0.0013, rpn_box: 0.0016, rcnn_cls: 0.0783, rcnn_box 0.0279
# [session 1][epoch  6][iter 1500/1916] loss: 0.0778, lr: 1.00e-04
# 			fg/bg=(226/798), time cost: 96.546415
# 			rpn_cls: 0.0054, rpn_box: 0.0067, rcnn_cls: 0.0329, rcnn_box 0.0268
# [session 1][epoch  6][iter 1600/1916] loss: 0.0806, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.654100
# 			rpn_cls: 0.0007, rpn_box: 0.0017, rcnn_cls: 0.0230, rcnn_box 0.0169
# [session 1][epoch  6][iter 1700/1916] loss: 0.0788, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.715006
# 			rpn_cls: 0.0043, rpn_box: 0.0014, rcnn_cls: 0.0686, rcnn_box 0.0142
# [session 1][epoch  6][iter 1800/1916] loss: 0.0794, lr: 1.00e-04
# 			fg/bg=(222/802), time cost: 96.688991
# 			rpn_cls: 0.0004, rpn_box: 0.0009, rcnn_cls: 0.0826, rcnn_box 0.0214
# [session 1][epoch  6][iter 1900/1916] loss: 0.0823, lr: 1.00e-04
# 			fg/bg=(204/820), time cost: 96.975549
# 			rpn_cls: 0.0009, rpn_box: 0.0013, rcnn_cls: 0.0284, rcnn_box 0.0154
# [session 1][epoch  7][iter    0/1916] loss: 0.0452, lr: 1.00e-04
# 			fg/bg=(199/825), time cost: 1.632127
# 			rpn_cls: 0.0008, rpn_box: 0.0009, rcnn_cls: 0.0319, rcnn_box 0.0116
# [session 1][epoch  7][iter  100/1916] loss: 0.0795, lr: 1.00e-04
# 			fg/bg=(224/800), time cost: 96.669677
# 			rpn_cls: 0.0020, rpn_box: 0.0032, rcnn_cls: 0.0491, rcnn_box 0.0326
# [session 1][epoch  7][iter  200/1916] loss: 0.0774, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.708599
# 			rpn_cls: 0.0006, rpn_box: 0.0019, rcnn_cls: 0.0525, rcnn_box 0.0251
# [session 1][epoch  7][iter  300/1916] loss: 0.0727, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.522291
# 			rpn_cls: 0.0067, rpn_box: 0.0026, rcnn_cls: 0.1165, rcnn_box 0.0219
# [session 1][epoch  7][iter  400/1916] loss: 0.0795, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.682805
# 			rpn_cls: 0.0005, rpn_box: 0.0012, rcnn_cls: 0.0185, rcnn_box 0.0164
# [session 1][epoch  7][iter  500/1916] loss: 0.0775, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.417868
# 			rpn_cls: 0.0082, rpn_box: 0.0062, rcnn_cls: 0.0435, rcnn_box 0.0392
# [session 1][epoch  7][iter  600/1916] loss: 0.0779, lr: 1.00e-04
# 			fg/bg=(191/833), time cost: 96.593314
# 			rpn_cls: 0.0104, rpn_box: 0.0030, rcnn_cls: 0.0211, rcnn_box 0.0222
# [session 1][epoch  7][iter  700/1916] loss: 0.0811, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.492329
# 			rpn_cls: 0.0006, rpn_box: 0.0010, rcnn_cls: 0.0286, rcnn_box 0.0121
# [session 1][epoch  7][iter  800/1916] loss: 0.0772, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.693813
# 			rpn_cls: 0.0014, rpn_box: 0.0013, rcnn_cls: 0.1622, rcnn_box 0.0277
# [session 1][epoch  7][iter  900/1916] loss: 0.0793, lr: 1.00e-04
# 			fg/bg=(229/795), time cost: 96.548322
# 			rpn_cls: 0.0003, rpn_box: 0.0016, rcnn_cls: 0.0229, rcnn_box 0.0278
# [session 1][epoch  7][iter 1000/1916] loss: 0.0758, lr: 1.00e-04
# 			fg/bg=(237/787), time cost: 96.773287
# 			rpn_cls: 0.0011, rpn_box: 0.0035, rcnn_cls: 0.0615, rcnn_box 0.0303
# [session 1][epoch  7][iter 1100/1916] loss: 0.0802, lr: 1.00e-04
# 			fg/bg=(227/797), time cost: 96.595353
# 			rpn_cls: 0.0038, rpn_box: 0.0020, rcnn_cls: 0.0671, rcnn_box 0.0344
# [session 1][epoch  7][iter 1200/1916] loss: 0.0774, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.617760
# 			rpn_cls: 0.0008, rpn_box: 0.0017, rcnn_cls: 0.0421, rcnn_box 0.0298
# [session 1][epoch  7][iter 1300/1916] loss: 0.0825, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.605047
# 			rpn_cls: 0.0007, rpn_box: 0.0012, rcnn_cls: 0.0378, rcnn_box 0.0215
# [session 1][epoch  7][iter 1400/1916] loss: 0.0729, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 96.580859
# 			rpn_cls: 0.0008, rpn_box: 0.0016, rcnn_cls: 0.0240, rcnn_box 0.0143
# [session 1][epoch  7][iter 1500/1916] loss: 0.0796, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.635413
# 			rpn_cls: 0.0127, rpn_box: 0.0012, rcnn_cls: 0.0175, rcnn_box 0.0154
# [session 1][epoch  7][iter 1600/1916] loss: 0.0833, lr: 1.00e-04
# 			fg/bg=(223/801), time cost: 97.081599
# 			rpn_cls: 0.0011, rpn_box: 0.0018, rcnn_cls: 0.0538, rcnn_box 0.0445
# [session 1][epoch  7][iter 1700/1916] loss: 0.0759, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.435481
# 			rpn_cls: 0.0128, rpn_box: 0.0014, rcnn_cls: 0.0510, rcnn_box 0.0351
# [session 1][epoch  7][iter 1800/1916] loss: 0.0753, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.651637
# 			rpn_cls: 0.0011, rpn_box: 0.0017, rcnn_cls: 0.0177, rcnn_box 0.0159
# [session 1][epoch  7][iter 1900/1916] loss: 0.0766, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.815691
# 			rpn_cls: 0.0004, rpn_box: 0.0007, rcnn_cls: 0.0319, rcnn_box 0.0216
# [session 1][epoch  8][iter    0/1916] loss: 0.0351, lr: 1.00e-04
# 			fg/bg=(202/822), time cost: 1.647541
# 			rpn_cls: 0.0002, rpn_box: 0.0005, rcnn_cls: 0.0189, rcnn_box 0.0155
# [session 1][epoch  8][iter  100/1916] loss: 0.0708, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 97.139165
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.0264, rcnn_box 0.0095
# [session 1][epoch  8][iter  200/1916] loss: 0.0725, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.996135
# 			rpn_cls: 0.0035, rpn_box: 0.0015, rcnn_cls: 0.0960, rcnn_box 0.0210
# [session 1][epoch  8][iter  300/1916] loss: 0.0750, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.678264
# 			rpn_cls: 0.0005, rpn_box: 0.0017, rcnn_cls: 0.0467, rcnn_box 0.0287
# [session 1][epoch  8][iter  400/1916] loss: 0.0717, lr: 1.00e-04
# 			fg/bg=(228/796), time cost: 96.701100
# 			rpn_cls: 0.0005, rpn_box: 0.0017, rcnn_cls: 0.0449, rcnn_box 0.0287
# [session 1][epoch  8][iter  500/1916] loss: 0.0692, lr: 1.00e-04
# 			fg/bg=(195/829), time cost: 96.504235
# 			rpn_cls: 0.0049, rpn_box: 0.0021, rcnn_cls: 0.0555, rcnn_box 0.0238
# [session 1][epoch  8][iter  600/1916] loss: 0.0771, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.632976
# 			rpn_cls: 0.0040, rpn_box: 0.0027, rcnn_cls: 0.0384, rcnn_box 0.0240
# [session 1][epoch  8][iter  700/1916] loss: 0.0838, lr: 1.00e-04
# 			fg/bg=(240/784), time cost: 96.669044
# 			rpn_cls: 0.0049, rpn_box: 0.0013, rcnn_cls: 0.0499, rcnn_box 0.0186
# [session 1][epoch  8][iter  800/1916] loss: 0.0780, lr: 1.00e-04
# 			fg/bg=(231/793), time cost: 96.744979
# 			rpn_cls: 0.0008, rpn_box: 0.0019, rcnn_cls: 0.0669, rcnn_box 0.0252
# [session 1][epoch  8][iter  900/1916] loss: 0.0768, lr: 1.00e-04
# 			fg/bg=(188/836), time cost: 96.817256
# 			rpn_cls: 0.0087, rpn_box: 0.0009, rcnn_cls: 0.0506, rcnn_box 0.0144
# [session 1][epoch  8][iter 1000/1916] loss: 0.0759, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.554567
# 			rpn_cls: 0.0003, rpn_box: 0.0007, rcnn_cls: 0.0197, rcnn_box 0.0147
# [session 1][epoch  8][iter 1100/1916] loss: 0.0684, lr: 1.00e-04
# 			fg/bg=(219/805), time cost: 96.337584
# 			rpn_cls: 0.0007, rpn_box: 0.0022, rcnn_cls: 0.0296, rcnn_box 0.0248
# [session 1][epoch  8][iter 1200/1916] loss: 0.0710, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.718716
# 			rpn_cls: 0.0004, rpn_box: 0.0008, rcnn_cls: 0.0204, rcnn_box 0.0143
# [session 1][epoch  8][iter 1300/1916] loss: 0.0760, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.516590
# 			rpn_cls: 0.0028, rpn_box: 0.0013, rcnn_cls: 0.0474, rcnn_box 0.0172
# [session 1][epoch  8][iter 1400/1916] loss: 0.0785, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.555299
# 			rpn_cls: 0.0008, rpn_box: 0.0014, rcnn_cls: 0.0303, rcnn_box 0.0212
# [session 1][epoch  8][iter 1500/1916] loss: 0.0730, lr: 1.00e-04
# 			fg/bg=(186/838), time cost: 96.501093
# 			rpn_cls: 0.0029, rpn_box: 0.0023, rcnn_cls: 0.0273, rcnn_box 0.0190
# [session 1][epoch  8][iter 1600/1916] loss: 0.0717, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.499565
# 			rpn_cls: 0.0014, rpn_box: 0.0031, rcnn_cls: 0.0373, rcnn_box 0.0322
# [session 1][epoch  8][iter 1700/1916] loss: 0.0762, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.639357
# 			rpn_cls: 0.0003, rpn_box: 0.0007, rcnn_cls: 0.0158, rcnn_box 0.0096
# [session 1][epoch  8][iter 1800/1916] loss: 0.0805, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.528316
# 			rpn_cls: 0.0100, rpn_box: 0.0014, rcnn_cls: 0.0243, rcnn_box 0.0228
# [session 1][epoch  8][iter 1900/1916] loss: 0.0803, lr: 1.00e-04
# 			fg/bg=(219/805), time cost: 96.623830
# 			rpn_cls: 0.0006, rpn_box: 0.0014, rcnn_cls: 0.0280, rcnn_box 0.0183
# [session 1][epoch  9][iter    0/1916] loss: 0.0470, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 1.504271
# 			rpn_cls: 0.0061, rpn_box: 0.0012, rcnn_cls: 0.0166, rcnn_box 0.0231
# [session 1][epoch  9][iter  100/1916] loss: 0.0702, lr: 1.00e-04
# 			fg/bg=(224/800), time cost: 96.868314
# 			rpn_cls: 0.0006, rpn_box: 0.0008, rcnn_cls: 0.0721, rcnn_box 0.0176
# [session 1][epoch  9][iter  200/1916] loss: 0.0773, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 96.680869
# 			rpn_cls: 0.0011, rpn_box: 0.0007, rcnn_cls: 0.0452, rcnn_box 0.0170
# [session 1][epoch  9][iter  300/1916] loss: 0.0753, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.795370
# 			rpn_cls: 0.0007, rpn_box: 0.0023, rcnn_cls: 0.2200, rcnn_box 0.0209
# [session 1][epoch  9][iter  400/1916] loss: 0.0754, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.642909
# 			rpn_cls: 0.0084, rpn_box: 0.0016, rcnn_cls: 0.0773, rcnn_box 0.0199
# [session 1][epoch  9][iter  500/1916] loss: 0.0687, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 96.706107
# 			rpn_cls: 0.0012, rpn_box: 0.0009, rcnn_cls: 0.0258, rcnn_box 0.0106
# [session 1][epoch  9][iter  600/1916] loss: 0.0771, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.778909
# 			rpn_cls: 0.0059, rpn_box: 0.0038, rcnn_cls: 0.0331, rcnn_box 0.0257
# [session 1][epoch  9][iter  700/1916] loss: 0.0662, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.712239
# 			rpn_cls: 0.0005, rpn_box: 0.0022, rcnn_cls: 0.0232, rcnn_box 0.0160
# [session 1][epoch  9][iter  800/1916] loss: 0.0707, lr: 1.00e-04
# 			fg/bg=(195/829), time cost: 96.761222
# 			rpn_cls: 0.0008, rpn_box: 0.0016, rcnn_cls: 0.0136, rcnn_box 0.0168
# [session 1][epoch  9][iter  900/1916] loss: 0.0751, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.541251
# 			rpn_cls: 0.0055, rpn_box: 0.0046, rcnn_cls: 0.0919, rcnn_box 0.0509
# [session 1][epoch  9][iter 1000/1916] loss: 0.0645, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.591639
# 			rpn_cls: 0.0023, rpn_box: 0.0010, rcnn_cls: 0.0182, rcnn_box 0.0127
# [session 1][epoch  9][iter 1100/1916] loss: 0.0738, lr: 1.00e-04
# 			fg/bg=(232/792), time cost: 96.743082
# 			rpn_cls: 0.0026, rpn_box: 0.0023, rcnn_cls: 0.0270, rcnn_box 0.0406
# [session 1][epoch  9][iter 1200/1916] loss: 0.0783, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.691504
# 			rpn_cls: 0.0005, rpn_box: 0.0009, rcnn_cls: 0.0589, rcnn_box 0.0216
# [session 1][epoch  9][iter 1300/1916] loss: 0.0702, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.486657
# 			rpn_cls: 0.0009, rpn_box: 0.0012, rcnn_cls: 0.0369, rcnn_box 0.0223
# [session 1][epoch  9][iter 1400/1916] loss: 0.0674, lr: 1.00e-04
# 			fg/bg=(224/800), time cost: 96.783102
# 			rpn_cls: 0.0005, rpn_box: 0.0014, rcnn_cls: 0.0535, rcnn_box 0.0202
# [session 1][epoch  9][iter 1500/1916] loss: 0.0796, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.712981
# 			rpn_cls: 0.0005, rpn_box: 0.0012, rcnn_cls: 0.0709, rcnn_box 0.0099
# [session 1][epoch  9][iter 1600/1916] loss: 0.0708, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.750363
# 			rpn_cls: 0.0035, rpn_box: 0.0020, rcnn_cls: 0.0251, rcnn_box 0.0307
# [session 1][epoch  9][iter 1700/1916] loss: 0.0824, lr: 1.00e-04
# 			fg/bg=(222/802), time cost: 96.922329
# 			rpn_cls: 0.0007, rpn_box: 0.0021, rcnn_cls: 0.0332, rcnn_box 0.0384
# [session 1][epoch  9][iter 1800/1916] loss: 0.0736, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.660571
# 			rpn_cls: 0.0075, rpn_box: 0.0015, rcnn_cls: 0.0703, rcnn_box 0.0303
# [session 1][epoch  9][iter 1900/1916] loss: 0.0699, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 96.546323
# 			rpn_cls: 0.0003, rpn_box: 0.0008, rcnn_cls: 0.0367, rcnn_box 0.0116
# [session 1][epoch 10][iter    0/1916] loss: 0.0571, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 1.850080
# 			rpn_cls: 0.0017, rpn_box: 0.0028, rcnn_cls: 0.0244, rcnn_box 0.0281
# [session 1][epoch 10][iter  100/1916] loss: 0.0673, lr: 1.00e-04
# 			fg/bg=(229/795), time cost: 96.473729
# 			rpn_cls: 0.0007, rpn_box: 0.0011, rcnn_cls: 0.0286, rcnn_box 0.0259
# [session 1][epoch 10][iter  200/1916] loss: 0.0753, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 96.424992
# 			rpn_cls: 0.0004, rpn_box: 0.0013, rcnn_cls: 0.0246, rcnn_box 0.0177
# [session 1][epoch 10][iter  300/1916] loss: 0.0649, lr: 1.00e-04
# 			fg/bg=(207/817), time cost: 96.663090
# 			rpn_cls: 0.0006, rpn_box: 0.0020, rcnn_cls: 0.0345, rcnn_box 0.0157
# [session 1][epoch 10][iter  400/1916] loss: 0.0723, lr: 1.00e-04
# 			fg/bg=(228/796), time cost: 96.804294
# 			rpn_cls: 0.0021, rpn_box: 0.0031, rcnn_cls: 0.1320, rcnn_box 0.0521
# [session 1][epoch 10][iter  500/1916] loss: 0.0732, lr: 1.00e-04
# 			fg/bg=(189/835), time cost: 97.367811
# 			rpn_cls: 0.0004, rpn_box: 0.0009, rcnn_cls: 0.0265, rcnn_box 0.0115
# [session 1][epoch 10][iter  600/1916] loss: 0.0743, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.907330
# 			rpn_cls: 0.0017, rpn_box: 0.0020, rcnn_cls: 0.0149, rcnn_box 0.0281
# [session 1][epoch 10][iter  700/1916] loss: 0.0668, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.554929
# 			rpn_cls: 0.0003, rpn_box: 0.0008, rcnn_cls: 0.0262, rcnn_box 0.0108
# [session 1][epoch 10][iter  800/1916] loss: 0.0707, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 97.009953
# 			rpn_cls: 0.0003, rpn_box: 0.0010, rcnn_cls: 0.0366, rcnn_box 0.0187
# [session 1][epoch 10][iter  900/1916] loss: 0.0722, lr: 1.00e-04
# 			fg/bg=(219/805), time cost: 96.463013
# 			rpn_cls: 0.0014, rpn_box: 0.0022, rcnn_cls: 0.0520, rcnn_box 0.0591
# [session 1][epoch 10][iter 1000/1916] loss: 0.0673, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.535074
# 			rpn_cls: 0.0009, rpn_box: 0.0021, rcnn_cls: 0.0153, rcnn_box 0.0324
# [session 1][epoch 10][iter 1100/1916] loss: 0.0679, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.613850
# 			rpn_cls: 0.0067, rpn_box: 0.0006, rcnn_cls: 0.0407, rcnn_box 0.0120
# [session 1][epoch 10][iter 1200/1916] loss: 0.0723, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.644760
# 			rpn_cls: 0.0009, rpn_box: 0.0021, rcnn_cls: 0.0189, rcnn_box 0.0229
# [session 1][epoch 10][iter 1300/1916] loss: 0.0684, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.660204
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.0222, rcnn_box 0.0319
# [session 1][epoch 10][iter 1400/1916] loss: 0.0703, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 97.303989
# 			rpn_cls: 0.0006, rpn_box: 0.0009, rcnn_cls: 0.0240, rcnn_box 0.0083
# [session 1][epoch 10][iter 1500/1916] loss: 0.0672, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.564076
# 			rpn_cls: 0.0003, rpn_box: 0.0015, rcnn_cls: 0.0511, rcnn_box 0.0260
# [session 1][epoch 10][iter 1600/1916] loss: 0.0634, lr: 1.00e-04
# 			fg/bg=(219/805), time cost: 96.732063
# 			rpn_cls: 0.0105, rpn_box: 0.0025, rcnn_cls: 0.0379, rcnn_box 0.0300
# [session 1][epoch 10][iter 1700/1916] loss: 0.0705, lr: 1.00e-04
# 			fg/bg=(204/820), time cost: 96.843812
# 			rpn_cls: 0.0003, rpn_box: 0.0014, rcnn_cls: 0.0336, rcnn_box 0.0200
# [session 1][epoch 10][iter 1800/1916] loss: 0.0704, lr: 1.00e-04
# 			fg/bg=(223/801), time cost: 97.001010
# 			rpn_cls: 0.0005, rpn_box: 0.0016, rcnn_cls: 0.0494, rcnn_box 0.0214
# [session 1][epoch 10][iter 1900/1916] loss: 0.0740, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.608217
# 			rpn_cls: 0.0009, rpn_box: 0.0010, rcnn_cls: 0.0515, rcnn_box 0.0345
# save model: models/res101/Gender/faster_rcnn_1_10_1915.pth

# %%
# !CUDA_VISIBLE_DEVICES=0 python demo.py --net vgg16 --dataset Race  --checksession 1  --checkepoch 10 \
                --checkpoint 957  --cuda --load_dir models
# Out:
# Called with args:
# Namespace(batch_size=1, cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', image_dir='images', load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False, webcam_num=-1)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# load model successfully!
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# demo.py:234: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_data = Variable(im_data, volatile=True)
# demo.py:235: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_info = Variable(im_info, volatile=True)
# demo.py:236: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   num_boxes = Variable(num_boxes, volatile=True)
# demo.py:237: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   gt_boxes = Variable(gt_boxes, volatile=True)
# Loaded Photo: 8 images.
# demo.py:279: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   im_in = np.array(imread(im_file))
# /root/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# im_detect: 0/8 0.323s 0.007s

# %%
# !python test_net.py --dataset Gender --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Gender` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Gender_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Gender/faster_rcnn_1_10_957.pth
# load model successfully!
# Evaluating detections0.315s 0.002s
# Writing male VOC results file
# Writing female VOC results file
# Writing unsure VOC results file
# VOC07 metric? Yes
# Reading annotation for 1/3067
# Reading annotation for 101/3067
# Reading annotation for 201/3067
# Reading annotation for 301/3067
# Reading annotation for 401/3067
# Reading annotation for 501/3067
# Reading annotation for 601/3067
# Reading annotation for 701/3067
# Reading annotation for 801/3067
# Reading annotation for 901/3067
# Reading annotation for 1001/3067
# Reading annotation for 1101/3067
# Reading annotation for 1201/3067
# Reading annotation for 1301/3067
# Reading annotation for 1401/3067
# Reading annotation for 1501/3067
# Reading annotation for 1601/3067
# Reading annotation for 1701/3067
# Reading annotation for 1801/3067
# Reading annotation for 1901/3067
# Reading annotation for 2001/3067
# Reading annotation for 2101/3067
# Reading annotation for 2201/3067
# Reading annotation for 2301/3067
# Reading annotation for 2401/3067
# Reading annotation for 2501/3067
# Reading annotation for 2601/3067
# Reading annotation for 2701/3067
# Reading annotation for 2801/3067
# Reading annotation for 2901/3067
# Reading annotation for 3001/3067
# Saving cached annotations to /mnt/FasterRCNN/faster-rcnn.pytorch/data/Gender/ImageSets/Main/test.txt_annots.pkl
# AP for male = 0.8504
# AP for female = 0.8568
# AP for unsure = 0.6992
# Mean AP = 0.8021
# ~~~~~~~~
# Results:
# 0.850
# 0.857
# 0.699
# 0.802
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# test time: 1132.3115s

# %%
# !python test_net.py --dataset Emotion --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Emotion` for training
# Set proposal method: gt
# Preparing training data...
# Emotion gt roidb loaded from /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Emotion_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Emotion/faster_rcnn_1_10_957.pth
# load model successfully!
# ^C
# Traceback (most recent call last):
#   File "test_net.py", line 213, in <module>
#     fasterRCNN.cuda()
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 552, in _apply
#     param_applied = fn(param)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
# KeyboardInterrupt
