# %%
# %cd /mnt/FasterRCNN/faster-rcnn.pytorch
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# !pip install -r requirements.txt
# !pip install scipy==1.2.1
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting cython
#   Downloading https://mirrors.aliyun.com/pypi/packages/3d/48/bbca549da0b0f636c0f161e84d30172c40aafe99552680f297da7fedf102/Cython-0.29.24-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 49.0 MB/s eta 0:00:01
# Requirement already satisfied: cffi in /root/miniconda3/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.14.0)
# Collecting opencv-python
#   Downloading https://mirrors.aliyun.com/pypi/packages/6b/73/a8921d221a673600dc744033786eeab56ed5116686a1b932b724a33003c6/opencv_python-4.5.3.56-cp37-cp37m-manylinux2014_x86_64.whl (49.9 MB)
#      |████████████████████████████████| 49.9 MB 1.7 MB/s eta 0:00:011    |██████████████▍                 | 22.4 MB 1.6 MB/s eta 0:00:17     |█████████████████████████       | 39.0 MB 1.6 MB/s eta 0:00:07
# Collecting scipy
#   Downloading https://mirrors.aliyun.com/pypi/packages/b5/6b/8bc0b61ebf824f8c3979a31368bbe38dd247590049a994ab0ed077cb56dc/scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 1.6 MB/s eta 0:00:01     |███████████████████▌            | 17.4 MB 2.4 MB/s eta 0:00:05     |██████████████████████████████▋ | 27.2 MB 1.6 MB/s eta 0:00:01
# Collecting msgpack
#   Downloading https://mirrors.aliyun.com/pypi/packages/b7/88/b0d0c339044360036e51d3afda0d2b0f9503087fddff8867496198b24cda/msgpack-1.0.2-cp37-cp37m-manylinux1_x86_64.whl (273 kB)
#      |████████████████████████████████| 273 kB 35.9 MB/s eta 0:00:01
# Collecting easydict
#   Downloading https://mirrors.aliyun.com/pypi/packages/4c/c5/5757886c4f538c1b3f95f6745499a24bffa389a805dee92d093e2d9ba7db/easydict-1.9.tar.gz (6.4 kB)
# Collecting matplotlib
#   Downloading https://mirrors.aliyun.com/pypi/packages/7c/ec/3d77b10ac3d30590f5431fd2dc59c58d20c020af107b47f8974896afc5c9/matplotlib-3.4.3-cp37-cp37m-manylinux1_x86_64.whl (10.3 MB)
#      |████████████████████████████████| 10.3 MB 3.7 MB/s eta 0:00:01     |█████████████▌                  | 4.3 MB 33.7 MB/s eta 0:00:01     |█████████████████               | 5.5 MB 33.7 MB/s eta 0:00:01     |████████████████████████▊       | 8.0 MB 3.7 MB/s eta 0:00:01
# Collecting pyyaml
#   Downloading https://mirrors.aliyun.com/pypi/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636 kB)
#      |████████████████████████████████| 636 kB 41.8 MB/s eta 0:00:01
# Collecting tensorboardX
#   Downloading https://mirrors.aliyun.com/pypi/packages/99/0b/a26bbe92667c549d39c40b80c5ddec638fbae9521f04aeef26560e07e504/tensorboardX-2.4-py2.py3-none-any.whl (124 kB)
#      |████████████████████████████████| 124 kB 36.2 MB/s eta 0:00:01
# Requirement already satisfied: pycparser in /root/miniconda3/lib/python3.7/site-packages (from cffi->-r requirements.txt (line 2)) (2.19)
# Collecting numpy>=1.14.5
#   Downloading https://mirrors.aliyun.com/pypi/packages/68/2d/0fe6592a96a1da097a33fb87b9618197c8a1801e84c7483fa7b93794a87c/numpy-1.21.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.8.1)
# Collecting cycler>=0.10
#   Downloading https://mirrors.aliyun.com/pypi/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/09/6b/6e567cb2e86d4e5939a9233f8734e26021b6a9c1bc4b1edccba236a84cc2/kiwisolver-1.3.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 36.0 MB/s eta 0:00:01
# Collecting pillow>=6.2.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/41/07/ecb2a0d55460385163c82a4bd65263a00510966dddbd54876796bd18857c/Pillow-8.3.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 31.3 MB/s eta 0:00:01
# Collecting protobuf>=3.8.0
#   Downloading https://mirrors.aliyun.com/pypi/packages/6e/62/eeec5be0b69442d2ffc7acdf54469fb4c76aa42288fe38decc537973a90a/protobuf-3.18.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 43.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /root/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 7)) (1.14.0)
# Building wheels for collected packages: easydict
#   Building wheel for easydict (setup.py) ... done
#   Created wheel for easydict: filename=easydict-1.9-py3-none-any.whl size=6349 sha256=989e7ab268d520888cc39c800c7858f77e027120715fcb01adb866b5221c65c6
#   Stored in directory: /root/.cache/pip/wheels/fd/84/74/82b22ad24a25b8d076e622a39a4af726d0909790f5c299451c
# Successfully built easydict
# Installing collected packages: cython, numpy, opencv-python, scipy, msgpack, easydict, cycler, kiwisolver, pillow, matplotlib, pyyaml, protobuf, tensorboardX
# Successfully installed cycler-0.10.0 cython-0.29.24 easydict-1.9 kiwisolver-1.3.2 matplotlib-3.4.3 msgpack-1.0.2 numpy-1.21.2 opencv-python-4.5.3.56 pillow-8.3.2 protobuf-3.18.1 pyyaml-5.4.1 scipy-1.7.1 tensorboardX-2.4
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting scipy==1.2.1
#   Downloading https://mirrors.aliyun.com/pypi/packages/3e/7e/5cee36eee5b3194687232f6150a89a38f784883c612db7f4da2ab190980d/scipy-1.2.1-cp37-cp37m-manylinux1_x86_64.whl (24.8 MB)
#      |████████████████████████████████| 24.8 MB 2.5 MB/s eta 0:00:01    |███████████▊                    | 9.1 MB 427 kB/s eta 0:00:37
# Requirement already satisfied: numpy>=1.8.2 in /root/miniconda3/lib/python3.7/site-packages (from scipy==1.2.1) (1.21.2)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.1
#     Uninstalling scipy-1.7.1:
#       Successfully uninstalled scipy-1.7.1
# Successfully installed scipy-1.2.1

# %%
# !pip install pycocotools
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting pycocotools
#   Downloading https://mirrors.aliyun.com/pypi/packages/de/df/056875d697c45182ed6d2ae21f62015896fdb841906fe48e7268e791c467/pycocotools-2.0.2.tar.gz (23 kB)
# Requirement already satisfied: setuptools>=18.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (45.2.0.post20200210)
# Requirement already satisfied: cython>=0.27.3 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (0.29.24)
# Requirement already satisfied: matplotlib>=2.1.0 in /root/miniconda3/lib/python3.7/site-packages (from pycocotools) (3.4.3)
# Requirement already satisfied: python-dateutil>=2.7 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.21.2)
# Requirement already satisfied: pillow>=6.2.0 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /root/miniconda3/lib/python3.7/site-packages (from matplotlib>=2.1.0->pycocotools) (1.3.2)
# Requirement already satisfied: six>=1.5 in /root/miniconda3/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools) (1.14.0)
# Building wheels for collected packages: pycocotools
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0.2-cp37-cp37m-linux_x86_64.whl size=272850 sha256=fd74c1960e19eace11bc03d09a7fb8d863e1ab2b1fa6874265f822d269ded1cc
#   Stored in directory: /root/.cache/pip/wheels/60/03/30/0cc037d5ac8ecd261e4c9e4fdb4f2c429074cd52a7a844c61e
# Successfully built pycocotools
# Installing collected packages: pycocotools
# Successfully installed pycocotools-2.0.2

# %%
# !pip install torch==1.7.1+cu110 torchvision==0.8.2+cu110 -f https://download.pytorch.org/whl/torch_stable.html

# %%
# !conda install ipykernel -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# Warning: >10 possible package resolutions (only showing differing packages):
#   - https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, defaults/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::wheel-0.34.2-py37_0
#   - defaults/linux-64::libffi-3.2.1-hd88cf55_4, defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   - defaults/linux-64::wheel-0.34.2-py37_0, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::libffi-3.2.1-hd88cf55_4, https://repo.anaconda.com/pkgs/main/linux-64/linux-64::pycparser-2.19-py37_0
#   ... and othedone
#
# ## Package Plan ##
#
#   environment location: /root/miniconda3
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2021.7.5   |       h06a4308_1         113 KB  defaults
#     certifi-2021.5.30          |   py37h06a4308_0         139 KB  defaults
#     conda-4.10.3               |   py37h06a4308_0         2.9 MB  defaults
#     ipykernel-5.3.4            |   py37h5ca1d4c_0         179 KB  defaults
#     openssl-1.1.1l             |       h7f8727e_0         2.5 MB  defaults
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge::ca-certificates-2020.12.~ --> pkgs/main::ca-certificates-2021.7.5-h06a4308_1
#   certifi            conda-forge::certifi-2020.12.5-py37h8~ --> pkgs/main::certifi-2021.5.30-py37h06a4308_0
#   conda              conda-forge::conda-4.9.2-py37h89c1867~ --> pkgs/main::conda-4.10.3-py37h06a4308_0
#   openssl            conda-forge::openssl-1.1.1h-h516909a_0 --> pkgs/main::openssl-1.1.1l-h7f8727e_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ipykernel          conda-forge::ipykernel-5.4.2-py37h888~ --> pkgs/main::ipykernel-5.3.4-py37h5ca1d4c_0
#
#
#
# Downloading and Extracting Packages
# conda-4.10.3         | 2.9 MB    | ##################################### | 100%
# ca-certificates-2021 | 113 KB    | ##################################### | 100%
# openssl-1.1.1l       | 2.5 MB    | ##################################### | 100%
# ipykernel-5.3.4      | 179 KB    | ##################################### | 100%
# certifi-2021.5.30    | 139 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torch
#   Downloading https://mirrors.aliyun.com/pypi/packages/ad/da/a1693073397b30fc3390def5a33cbe630f1b9446ea296845680af95080af/torch-1.9.1-cp37-cp37m-manylinux1_x86_64.whl (831.4 MB)
#      |████████████████████████████████| 831.4 MB 2.7 MB/s eta 0:00:014  |▎                               | 7.7 MB 1.3 MB/s eta 0:10:18     |▍                               | 9.7 MB 1.9 MB/s eta 0:07:21     |█                               | 28.1 MB 2.5 MB/s eta 0:05:26     |█▏                              | 29.0 MB 5.4 MB/s eta 0:02:28     |█▋                              | 43.1 MB 3.3 MB/s eta 0:03:59     |█▉                              | 46.2 MB 1.4 MB/s eta 0:09:32     |██▏                             | 56.0 MB 1.2 MB/s eta 0:10:46     |███                             | 77.3 MB 6.0 MB/s eta 0:02:06     |███                             | 77.6 MB 6.0 MB/s eta 0:02:06     |███▊                            | 98.1 MB 3.9 MB/s eta 0:03:08     |███▉                            | 100.6 MB 3.9 MB/s eta 0:03:08     |████                            | 104.8 MB 2.7 MB/s eta 0:04:28     |████                            | 106.7 MB 5.1 MB/s eta 0:02:22     |████▏                           | 107.9 MB 5.1 MB/s eta 0:02:22     |████▍                           | 113.3 MB 4.3 MB/s eta 0:02:49     |████▌                           | 116.0 MB 2.9 MB/s eta 0:04:07     |████▊                           | 123.1 MB 3.9 MB/s eta 0:03:01     |█████▌                          | 143.6 MB 3.2 MB/s eta 0:03:37     |█████▉                          | 151.5 MB 16.2 MB/s eta 0:00:42     |███████                         | 181.2 MB 2.8 MB/s eta 0:03:53     |███████▍                        | 193.2 MB 6.4 MB/s eta 0:01:40     |███████▋                        | 197.5 MB 2.9 MB/s eta 0:03:37     |███████▉                        | 202.5 MB 4.9 MB/s eta 0:02:08     |████████▏                       | 211.2 MB 2.9 MB/s eta 0:03:35     |████████▎                       | 213.9 MB 5.3 MB/s eta 0:01:57     |█████████▉                      | 256.6 MB 3.3 MB/s eta 0:02:55     |██████████                      | 259.3 MB 3.3 MB/s eta 0:02:55     |██████████                      | 261.0 MB 3.6 MB/s eta 0:02:39     |██████████                      | 262.2 MB 3.6 MB/s eta 0:02:38     |██████████▍                     | 271.1 MB 5.1 MB/s eta 0:01:49     |███████████                     | 284.1 MB 5.9 MB/s eta 0:01:34     |███████████                     | 287.3 MB 5.9 MB/s eta 0:01:33     |███████████▎                    | 293.8 MB 2.7 MB/s eta 0:03:21     |███████████▊                    | 303.9 MB 5.7 MB/s eta 0:01:32     |████████████▉                   | 334.1 MB 3.6 MB/s eta 0:02:18     |█████████████                   | 339.6 MB 4.6 MB/s eta 0:01:48     |█████████████▋                  | 354.6 MB 5.5 MB/s eta 0:01:27     |█████████████▉                  | 360.6 MB 3.2 MB/s eta 0:02:26     |██████████████▎                 | 369.8 MB 3.0 MB/s eta 0:02:37     |███████████████▎                | 395.7 MB 2.1 MB/s eta 0:03:26     |███████████████▋                | 405.0 MB 5.9 MB/s eta 0:01:13     |███████████████▋                | 406.5 MB 5.9 MB/s eta 0:01:13     |███████████████▊                | 409.4 MB 5.9 MB/s eta 0:01:12     |████████████████▉               | 436.2 MB 15.0 MB/s eta 0:00:27��█               | 439.3 MB 15.0 MB/s eta 0:00:27     |█████████████████▍              | 450.8 MB 16.6 MB/s eta 0:00:23     |██████████████████▉             | 490.4 MB 10.0 MB/s eta 0:00:35     |███████████████████▏            | 498.4 MB 20.5 MB/s eta 0:00:17     |███████████████████▌            | 506.5 MB 1.1 MB/s eta 0:05:00     |████████████████████            | 517.6 MB 7.5 MB/s eta 0:00:42     |████████████████████▏           | 523.7 MB 9.8 MB/s eta 0:00:32     |████████████████████▌           | 532.4 MB 9.8 MB/s eta 0:00:31     |████████████████████▋           | 536.0 MB 10.4 MB/s eta 0:00:29     |█████████████████████           | 543.4 MB 10.4 MB/s eta 0:00:28     |█████████████████████           | 546.9 MB 9.1 MB/s eta 0:00:32     |█████████████████████           | 547.5 MB 9.1 MB/s eta 0:00:32     |█████████████████████▏          | 549.3 MB 9.1 MB/s eta 0:00:31     |██████████████████ ...
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch) (3.7.4.3)
# Installing collected packages: torch
# Successfully installed torch-1.9.1
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting torchvision
#   Downloading https://mirrors.aliyun.com/pypi/packages/56/6c/daa50a536812da895a4eecaefdffbffd90736c47898d942501080a5b42a5/torchvision-0.10.1-cp37-cp37m-manylinux1_x86_64.whl (22.1 MB)
#      |████████████████████████████████| 22.1 MB 1.4 MB/s eta 0:00:01     |███████████████████████████████▏| 21.6 MB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.21.2)
# Requirement already satisfied: torch==1.9.1 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (1.9.1)
# Requirement already satisfied: pillow>=5.3.0 in /root/miniconda3/lib/python3.7/site-packages (from torchvision) (8.3.2)
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.7/site-packages (from torch==1.9.1->torchvision) (3.7.4.3)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.10.1

# %%
# %cd lib
# !python setup.py build develop
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# running build
# running build_py
# running build_ext
# /root/miniconda3/lib/python3.7/site-packages/torch/utils/cpp_extension.py:370: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# running develop
# running egg_info
# writing faster_rcnn.egg-info/PKG-INFO
# writing dependency_links to faster_rcnn.egg-info/dependency_links.txt
# writing top-level names to faster_rcnn.egg-info/top_level.txt
# reading manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# writing manifest file 'faster_rcnn.egg-info/SOURCES.txt'
# running build_ext
# copying build/lib.linux-x86_64-3.7/model/_C.cpython-37m-x86_64-linux-gnu.so -> model
# Creating /root/miniconda3/lib/python3.7/site-packages/faster-rcnn.egg-link (link to .)
# Adding faster-rcnn 0.1 to easy-install.pth file
#
# Installed /mnt/FasterRCNN/faster-rcnn.pytorch/lib
# Processing dependencies for faster-rcnn==0.1
# Finished processing dependencies for faster-rcnn==0.1

# %%
# %cd ..
# Out:
# /mnt/FasterRCNN/faster-rcnn.pytorch

# %%
# modify trainval_net.py line 195

# !CUDA_VISIBLE_DEVICES=0 python trainval_net.py \
                   --dataset Race --net res101 \
                   --epoch 10 --bs 8 --nw 2\
                   --lr 1e-3 --lr_decay_step 5 \
                   --cuda --use_tfb  
#                    --r True --checksession 1 --checkepoch 5 --checkpoint 765
# Out:
# Called with args:
# Namespace(batch_size=8, checkepoch=1, checkpoint=0, checkpoint_interval=10000, checksession=1, class_agnostic=False, cuda=True, dataset='Race', disp_interval=100, large_scale=False, lr=0.001, lr_decay_gamma=0.1, lr_decay_step=5, mGPUs=False, max_epochs=10, net='res101', num_workers=2, optimizer='sgd', resume=False, save_dir='models', session=1, start_epoch=1, use_tfboard=True)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'res101',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 20,
#            'DOUBLE_BIAS': False,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.001,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0001},
#  'USE_GPU_NMS': True}
# Loaded dataset `Race` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Race_gt_roidb.pkl
# done
# before filtering, there are 15330 images...
# after filtering, there are 15330 images...
# 15330 roidb entries
# Loading pretrained weights from data/pretrained_model/resnet101_caffe.pth
# [session 1][epoch  1][iter    0/1916] loss: 2.3082, lr: 1.00e-03
# 			fg/bg=(58/966), time cost: 2.593352
# 			rpn_cls: 0.7746, rpn_box: 0.0581, rcnn_cls: 1.3422, rcnn_box 0.1332
# [session 1][epoch  1][iter  100/1916] loss: 0.7649, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.717861
# 			rpn_cls: 0.0032, rpn_box: 0.0074, rcnn_cls: 0.1479, rcnn_box 0.2761
# [session 1][epoch  1][iter  200/1916] loss: 0.5037, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.661354
# 			rpn_cls: 0.0053, rpn_box: 0.0098, rcnn_cls: 0.1890, rcnn_box 0.1287
# [session 1][epoch  1][iter  300/1916] loss: 0.3334, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 96.464462
# 			rpn_cls: 0.0041, rpn_box: 0.0068, rcnn_cls: 0.1891, rcnn_box 0.0813
# [session 1][epoch  1][iter  400/1916] loss: 0.3173, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 96.785143
# 			rpn_cls: 0.0037, rpn_box: 0.0058, rcnn_cls: 0.1726, rcnn_box 0.1029
# [session 1][epoch  1][iter  500/1916] loss: 0.2929, lr: 1.00e-03
# 			fg/bg=(191/833), time cost: 97.107967
# 			rpn_cls: 0.0034, rpn_box: 0.0069, rcnn_cls: 0.1879, rcnn_box 0.0485
# [session 1][epoch  1][iter  600/1916] loss: 0.2786, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 97.199426
# 			rpn_cls: 0.0035, rpn_box: 0.0050, rcnn_cls: 0.2211, rcnn_box 0.0661
# [session 1][epoch  1][iter  700/1916] loss: 0.2696, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.926851
# 			rpn_cls: 0.0137, rpn_box: 0.0052, rcnn_cls: 0.1403, rcnn_box 0.0655
# [session 1][epoch  1][iter  800/1916] loss: 0.2448, lr: 1.00e-03
# 			fg/bg=(220/804), time cost: 97.050513
# 			rpn_cls: 0.0019, rpn_box: 0.0051, rcnn_cls: 0.1598, rcnn_box 0.0625
# [session 1][epoch  1][iter  900/1916] loss: 0.2482, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 97.262171
# 			rpn_cls: 0.0067, rpn_box: 0.0033, rcnn_cls: 0.1275, rcnn_box 0.0604
# [session 1][epoch  1][iter 1000/1916] loss: 0.2340, lr: 1.00e-03
# 			fg/bg=(226/798), time cost: 97.324063
# 			rpn_cls: 0.0059, rpn_box: 0.0032, rcnn_cls: 0.1510, rcnn_box 0.0580
# [session 1][epoch  1][iter 1100/1916] loss: 0.2362, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 97.516778
# 			rpn_cls: 0.0046, rpn_box: 0.0039, rcnn_cls: 0.1331, rcnn_box 0.0445
# [session 1][epoch  1][iter 1200/1916] loss: 0.2463, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 97.359581
# 			rpn_cls: 0.0024, rpn_box: 0.0028, rcnn_cls: 0.1581, rcnn_box 0.0723
# [session 1][epoch  1][iter 1300/1916] loss: 0.2471, lr: 1.00e-03
# 			fg/bg=(223/801), time cost: 97.483641
# 			rpn_cls: 0.0013, rpn_box: 0.0051, rcnn_cls: 0.4197, rcnn_box 0.0887
# [session 1][epoch  1][iter 1400/1916] loss: 0.2161, lr: 1.00e-03
# 			fg/bg=(189/835), time cost: 97.506318
# 			rpn_cls: 0.0025, rpn_box: 0.0027, rcnn_cls: 0.1511, rcnn_box 0.0339
# [session 1][epoch  1][iter 1500/1916] loss: 0.2187, lr: 1.00e-03
# 			fg/bg=(207/817), time cost: 97.299221
# 			rpn_cls: 0.0064, rpn_box: 0.0044, rcnn_cls: 0.1662, rcnn_box 0.0598
# [session 1][epoch  1][iter 1600/1916] loss: 0.2155, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 97.380341
# 			rpn_cls: 0.0018, rpn_box: 0.0040, rcnn_cls: 0.1720, rcnn_box 0.0688
# [session 1][epoch  1][iter 1700/1916] loss: 0.2086, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.919724
# 			rpn_cls: 0.0041, rpn_box: 0.0045, rcnn_cls: 0.1108, rcnn_box 0.0792
# [session 1][epoch  1][iter 1800/1916] loss: 0.2217, lr: 1.00e-03
# 			fg/bg=(233/791), time cost: 96.982761
# 			rpn_cls: 0.0017, rpn_box: 0.0048, rcnn_cls: 0.2240, rcnn_box 0.0703
# [session 1][epoch  1][iter 1900/1916] loss: 0.2236, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 97.012751
# 			rpn_cls: 0.0189, rpn_box: 0.0044, rcnn_cls: 0.1099, rcnn_box 0.0880
# [session 1][epoch  2][iter    0/1916] loss: 0.0677, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 1.568625
# 			rpn_cls: 0.0013, rpn_box: 0.0017, rcnn_cls: 0.0331, rcnn_box 0.0315
# [session 1][epoch  2][iter  100/1916] loss: 0.2011, lr: 1.00e-03
# 			fg/bg=(232/792), time cost: 97.010159
# 			rpn_cls: 0.0074, rpn_box: 0.0038, rcnn_cls: 0.2482, rcnn_box 0.0495
# [session 1][epoch  2][iter  200/1916] loss: 0.1914, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 96.640208
# 			rpn_cls: 0.0013, rpn_box: 0.0024, rcnn_cls: 0.1260, rcnn_box 0.0380
# [session 1][epoch  2][iter  300/1916] loss: 0.1802, lr: 1.00e-03
# 			fg/bg=(192/832), time cost: 96.734284
# 			rpn_cls: 0.0043, rpn_box: 0.0028, rcnn_cls: 0.0944, rcnn_box 0.0463
# [session 1][epoch  2][iter  400/1916] loss: 0.1810, lr: 1.00e-03
# 			fg/bg=(196/828), time cost: 96.644255
# 			rpn_cls: 0.0016, rpn_box: 0.0034, rcnn_cls: 0.0754, rcnn_box 0.0241
# [session 1][epoch  2][iter  500/1916] loss: 0.1961, lr: 1.00e-03
# 			fg/bg=(198/826), time cost: 96.826187
# 			rpn_cls: 0.0013, rpn_box: 0.0039, rcnn_cls: 0.1547, rcnn_box 0.0445
# [session 1][epoch  2][iter  600/1916] loss: 0.1825, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 96.842932
# 			rpn_cls: 0.0101, rpn_box: 0.0052, rcnn_cls: 0.1273, rcnn_box 0.1296
# [session 1][epoch  2][iter  700/1916] loss: 0.1734, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.833954
# 			rpn_cls: 0.0024, rpn_box: 0.0014, rcnn_cls: 0.0782, rcnn_box 0.0283
# [session 1][epoch  2][iter  800/1916] loss: 0.1868, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.967076
# 			rpn_cls: 0.0338, rpn_box: 0.0035, rcnn_cls: 0.1430, rcnn_box 0.0862
# [session 1][epoch  2][iter  900/1916] loss: 0.1717, lr: 1.00e-03
# 			fg/bg=(225/799), time cost: 96.987604
# 			rpn_cls: 0.0055, rpn_box: 0.0074, rcnn_cls: 0.1535, rcnn_box 0.0679
# [session 1][epoch  2][iter 1000/1916] loss: 0.1837, lr: 1.00e-03
# 			fg/bg=(227/797), time cost: 97.099842
# 			rpn_cls: 0.0013, rpn_box: 0.0043, rcnn_cls: 0.2174, rcnn_box 0.0630
# [session 1][epoch  2][iter 1100/1916] loss: 0.1674, lr: 1.00e-03
# 			fg/bg=(218/806), time cost: 96.885264
# 			rpn_cls: 0.0057, rpn_box: 0.0045, rcnn_cls: 0.2162, rcnn_box 0.0602
# [session 1][epoch  2][iter 1200/1916] loss: 0.1694, lr: 1.00e-03
# 			fg/bg=(215/809), time cost: 96.823213
# 			rpn_cls: 0.0064, rpn_box: 0.0019, rcnn_cls: 0.0971, rcnn_box 0.0262
# [session 1][epoch  2][iter 1300/1916] loss: 0.1724, lr: 1.00e-03
# 			fg/bg=(185/839), time cost: 96.830791
# 			rpn_cls: 0.0008, rpn_box: 0.0024, rcnn_cls: 0.1070, rcnn_box 0.0331
# [session 1][epoch  2][iter 1400/1916] loss: 0.1783, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.896831
# 			rpn_cls: 0.0031, rpn_box: 0.0019, rcnn_cls: 0.0627, rcnn_box 0.0239
# [session 1][epoch  2][iter 1500/1916] loss: 0.1757, lr: 1.00e-03
# 			fg/bg=(184/840), time cost: 96.787442
# 			rpn_cls: 0.0034, rpn_box: 0.0022, rcnn_cls: 0.1148, rcnn_box 0.0383
# [session 1][epoch  2][iter 1600/1916] loss: 0.1742, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 96.661403
# 			rpn_cls: 0.0132, rpn_box: 0.0036, rcnn_cls: 0.2077, rcnn_box 0.0739
# [session 1][epoch  2][iter 1700/1916] loss: 0.1549, lr: 1.00e-03
# 			fg/bg=(183/841), time cost: 96.834983
# 			rpn_cls: 0.0122, rpn_box: 0.0037, rcnn_cls: 0.1120, rcnn_box 0.0348
# [session 1][epoch  2][iter 1800/1916] loss: 0.1659, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 96.938865
# 			rpn_cls: 0.0027, rpn_box: 0.0038, rcnn_cls: 0.2071, rcnn_box 0.0380
# [session 1][epoch  2][iter 1900/1916] loss: 0.1587, lr: 1.00e-03
# 			fg/bg=(203/821), time cost: 96.886476
# 			rpn_cls: 0.0011, rpn_box: 0.0020, rcnn_cls: 0.1036, rcnn_box 0.0213
# [session 1][epoch  3][iter    0/1916] loss: 0.0807, lr: 1.00e-03
# 			fg/bg=(227/797), time cost: 2.082325
# 			rpn_cls: 0.0010, rpn_box: 0.0022, rcnn_cls: 0.0532, rcnn_box 0.0242
# [session 1][epoch  3][iter  100/1916] loss: 0.1527, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.979623
# 			rpn_cls: 0.0017, rpn_box: 0.0022, rcnn_cls: 0.0593, rcnn_box 0.0535
# [session 1][epoch  3][iter  200/1916] loss: 0.1472, lr: 1.00e-03
# 			fg/bg=(172/852), time cost: 96.951514
# 			rpn_cls: 0.0069, rpn_box: 0.0017, rcnn_cls: 0.0661, rcnn_box 0.0297
# [session 1][epoch  3][iter  300/1916] loss: 0.1460, lr: 1.00e-03
# 			fg/bg=(186/838), time cost: 96.685878
# 			rpn_cls: 0.0033, rpn_box: 0.0016, rcnn_cls: 0.0589, rcnn_box 0.0231
# [session 1][epoch  3][iter  400/1916] loss: 0.1498, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.795262
# 			rpn_cls: 0.0048, rpn_box: 0.0012, rcnn_cls: 0.1120, rcnn_box 0.0301
# [session 1][epoch  3][iter  500/1916] loss: 0.1450, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.790317
# 			rpn_cls: 0.0006, rpn_box: 0.0026, rcnn_cls: 0.1200, rcnn_box 0.0268
# [session 1][epoch  3][iter  600/1916] loss: 0.1537, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.726928
# 			rpn_cls: 0.0122, rpn_box: 0.0036, rcnn_cls: 0.0916, rcnn_box 0.0328
# [session 1][epoch  3][iter  700/1916] loss: 0.1603, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.718488
# 			rpn_cls: 0.0021, rpn_box: 0.0039, rcnn_cls: 0.0785, rcnn_box 0.0237
# [session 1][epoch  3][iter  800/1916] loss: 0.1436, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 96.870935
# 			rpn_cls: 0.0039, rpn_box: 0.0016, rcnn_cls: 0.0761, rcnn_box 0.0189
# [session 1][epoch  3][iter  900/1916] loss: 0.1462, lr: 1.00e-03
# 			fg/bg=(231/793), time cost: 96.741355
# 			rpn_cls: 0.0022, rpn_box: 0.0023, rcnn_cls: 0.0743, rcnn_box 0.0361
# [session 1][epoch  3][iter 1000/1916] loss: 0.1421, lr: 1.00e-03
# 			fg/bg=(192/832), time cost: 96.899688
# 			rpn_cls: 0.0065, rpn_box: 0.0040, rcnn_cls: 0.0663, rcnn_box 0.0551
# [session 1][epoch  3][iter 1100/1916] loss: 0.1445, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.639704
# 			rpn_cls: 0.0006, rpn_box: 0.0012, rcnn_cls: 0.0883, rcnn_box 0.0213
# [session 1][epoch  3][iter 1200/1916] loss: 0.1457, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.700480
# 			rpn_cls: 0.0020, rpn_box: 0.0012, rcnn_cls: 0.1292, rcnn_box 0.0201
# [session 1][epoch  3][iter 1300/1916] loss: 0.1472, lr: 1.00e-03
# 			fg/bg=(199/825), time cost: 96.628805
# 			rpn_cls: 0.0007, rpn_box: 0.0015, rcnn_cls: 0.0890, rcnn_box 0.0207
# [session 1][epoch  3][iter 1400/1916] loss: 0.1421, lr: 1.00e-03
# 			fg/bg=(168/856), time cost: 96.720508
# 			rpn_cls: 0.0151, rpn_box: 0.0031, rcnn_cls: 0.1623, rcnn_box 0.0257
# [session 1][epoch  3][iter 1500/1916] loss: 0.1548, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.717281
# 			rpn_cls: 0.0012, rpn_box: 0.0019, rcnn_cls: 0.0902, rcnn_box 0.0460
# [session 1][epoch  3][iter 1600/1916] loss: 0.1506, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.482586
# 			rpn_cls: 0.0008, rpn_box: 0.0016, rcnn_cls: 0.0536, rcnn_box 0.0228
# [session 1][epoch  3][iter 1700/1916] loss: 0.1458, lr: 1.00e-03
# 			fg/bg=(190/834), time cost: 96.634603
# 			rpn_cls: 0.0007, rpn_box: 0.0018, rcnn_cls: 0.0772, rcnn_box 0.0211
# [session 1][epoch  3][iter 1800/1916] loss: 0.1389, lr: 1.00e-03
# 			fg/bg=(188/836), time cost: 96.522977
# 			rpn_cls: 0.0008, rpn_box: 0.0009, rcnn_cls: 0.1524, rcnn_box 0.0141
# [session 1][epoch  3][iter 1900/1916] loss: 0.1461, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.622776
# 			rpn_cls: 0.0010, rpn_box: 0.0029, rcnn_cls: 0.1817, rcnn_box 0.0270
# [session 1][epoch  4][iter    0/1916] loss: 0.1042, lr: 1.00e-03
# 			fg/bg=(196/828), time cost: 1.412750
# 			rpn_cls: 0.0008, rpn_box: 0.0007, rcnn_cls: 0.0841, rcnn_box 0.0185
# [session 1][epoch  4][iter  100/1916] loss: 0.1374, lr: 1.00e-03
# 			fg/bg=(186/838), time cost: 96.544102
# 			rpn_cls: 0.0005, rpn_box: 0.0012, rcnn_cls: 0.0839, rcnn_box 0.0285
# [session 1][epoch  4][iter  200/1916] loss: 0.1237, lr: 1.00e-03
# 			fg/bg=(192/832), time cost: 96.787204
# 			rpn_cls: 0.0011, rpn_box: 0.0026, rcnn_cls: 0.0686, rcnn_box 0.0198
# [session 1][epoch  4][iter  300/1916] loss: 0.1231, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.689614
# 			rpn_cls: 0.0014, rpn_box: 0.0023, rcnn_cls: 0.1272, rcnn_box 0.0407
# [session 1][epoch  4][iter  400/1916] loss: 0.1328, lr: 1.00e-03
# 			fg/bg=(189/835), time cost: 96.931380
# 			rpn_cls: 0.0011, rpn_box: 0.0013, rcnn_cls: 0.0600, rcnn_box 0.0434
# [session 1][epoch  4][iter  500/1916] loss: 0.1281, lr: 1.00e-03
# 			fg/bg=(187/837), time cost: 96.589579
# 			rpn_cls: 0.0010, rpn_box: 0.0020, rcnn_cls: 0.0872, rcnn_box 0.0193
# [session 1][epoch  4][iter  600/1916] loss: 0.1386, lr: 1.00e-03
# 			fg/bg=(180/844), time cost: 96.681816
# 			rpn_cls: 0.0035, rpn_box: 0.0013, rcnn_cls: 0.0853, rcnn_box 0.0171
# [session 1][epoch  4][iter  700/1916] loss: 0.1297, lr: 1.00e-03
# 			fg/bg=(210/814), time cost: 96.820025
# 			rpn_cls: 0.0072, rpn_box: 0.0019, rcnn_cls: 0.0689, rcnn_box 0.0202
# [session 1][epoch  4][iter  800/1916] loss: 0.1272, lr: 1.00e-03
# 			fg/bg=(208/816), time cost: 96.581503
# 			rpn_cls: 0.0008, rpn_box: 0.0021, rcnn_cls: 0.0660, rcnn_box 0.0296
# [session 1][epoch  4][iter  900/1916] loss: 0.1456, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.640503
# 			rpn_cls: 0.0007, rpn_box: 0.0013, rcnn_cls: 0.0456, rcnn_box 0.0089
# [session 1][epoch  4][iter 1000/1916] loss: 0.1353, lr: 1.00e-03
# 			fg/bg=(227/797), time cost: 96.762664
# 			rpn_cls: 0.0095, rpn_box: 0.0023, rcnn_cls: 0.0605, rcnn_box 0.0329
# [session 1][epoch  4][iter 1100/1916] loss: 0.1386, lr: 1.00e-03
# 			fg/bg=(223/801), time cost: 96.713356
# 			rpn_cls: 0.0030, rpn_box: 0.0025, rcnn_cls: 0.0958, rcnn_box 0.0278
# [session 1][epoch  4][iter 1200/1916] loss: 0.1352, lr: 1.00e-03
# 			fg/bg=(219/805), time cost: 96.567799
# 			rpn_cls: 0.0019, rpn_box: 0.0031, rcnn_cls: 0.0977, rcnn_box 0.0505
# [session 1][epoch  4][iter 1300/1916] loss: 0.1270, lr: 1.00e-03
# 			fg/bg=(213/811), time cost: 96.498274
# 			rpn_cls: 0.0009, rpn_box: 0.0032, rcnn_cls: 0.1113, rcnn_box 0.0260
# [session 1][epoch  4][iter 1400/1916] loss: 0.1384, lr: 1.00e-03
# 			fg/bg=(201/823), time cost: 96.518563
# 			rpn_cls: 0.0034, rpn_box: 0.0019, rcnn_cls: 0.0584, rcnn_box 0.0264
# [session 1][epoch  4][iter 1500/1916] loss: 0.1324, lr: 1.00e-03
# 			fg/bg=(233/791), time cost: 96.659755
# 			rpn_cls: 0.0012, rpn_box: 0.0080, rcnn_cls: 0.1592, rcnn_box 0.0875
# [session 1][epoch  4][iter 1600/1916] loss: 0.1265, lr: 1.00e-03
# 			fg/bg=(197/827), time cost: 96.468612
# 			rpn_cls: 0.0012, rpn_box: 0.0011, rcnn_cls: 0.1597, rcnn_box 0.0237
# [session 1][epoch  4][iter 1700/1916] loss: 0.1315, lr: 1.00e-03
# 			fg/bg=(212/812), time cost: 96.771577
# 			rpn_cls: 0.0015, rpn_box: 0.0012, rcnn_cls: 0.1825, rcnn_box 0.0181
# [session 1][epoch  4][iter 1800/1916] loss: 0.1319, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 96.558240
# 			rpn_cls: 0.0007, rpn_box: 0.0014, rcnn_cls: 0.0390, rcnn_box 0.0206
# [session 1][epoch  4][iter 1900/1916] loss: 0.1210, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.701053
# 			rpn_cls: 0.0009, rpn_box: 0.0018, rcnn_cls: 0.0697, rcnn_box 0.0305
# [session 1][epoch  5][iter    0/1916] loss: 0.1863, lr: 1.00e-03
# 			fg/bg=(200/824), time cost: 1.612506
# 			rpn_cls: 0.0239, rpn_box: 0.0041, rcnn_cls: 0.1110, rcnn_box 0.0472
# [session 1][epoch  5][iter  100/1916] loss: 0.1153, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.708038
# 			rpn_cls: 0.0007, rpn_box: 0.0016, rcnn_cls: 0.0372, rcnn_box 0.0239
# [session 1][epoch  5][iter  200/1916] loss: 0.1148, lr: 1.00e-03
# 			fg/bg=(214/810), time cost: 96.876901
# 			rpn_cls: 0.0006, rpn_box: 0.0017, rcnn_cls: 0.0431, rcnn_box 0.0209
# [session 1][epoch  5][iter  300/1916] loss: 0.1156, lr: 1.00e-03
# 			fg/bg=(196/828), time cost: 96.588785
# 			rpn_cls: 0.0017, rpn_box: 0.0019, rcnn_cls: 0.0784, rcnn_box 0.0374
# [session 1][epoch  5][iter  400/1916] loss: 0.1254, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.604359
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.1007, rcnn_box 0.0200
# [session 1][epoch  5][iter  500/1916] loss: 0.1118, lr: 1.00e-03
# 			fg/bg=(206/818), time cost: 96.500024
# 			rpn_cls: 0.0005, rpn_box: 0.0014, rcnn_cls: 0.0645, rcnn_box 0.0197
# [session 1][epoch  5][iter  600/1916] loss: 0.1154, lr: 1.00e-03
# 			fg/bg=(186/838), time cost: 96.769578
# 			rpn_cls: 0.0042, rpn_box: 0.0026, rcnn_cls: 0.0642, rcnn_box 0.0255
# [session 1][epoch  5][iter  700/1916] loss: 0.1186, lr: 1.00e-03
# 			fg/bg=(193/831), time cost: 96.775489
# 			rpn_cls: 0.0081, rpn_box: 0.0029, rcnn_cls: 0.0593, rcnn_box 0.0332
# [session 1][epoch  5][iter  800/1916] loss: 0.1165, lr: 1.00e-03
# 			fg/bg=(204/820), time cost: 96.918365
# 			rpn_cls: 0.0074, rpn_box: 0.0019, rcnn_cls: 0.1447, rcnn_box 0.0284
# [session 1][epoch  5][iter  900/1916] loss: 0.1099, lr: 1.00e-03
# 			fg/bg=(194/830), time cost: 96.645643
# 			rpn_cls: 0.0011, rpn_box: 0.0012, rcnn_cls: 0.1104, rcnn_box 0.0238
# [session 1][epoch  5][iter 1000/1916] loss: 0.1312, lr: 1.00e-03
# 			fg/bg=(174/850), time cost: 96.716861
# 			rpn_cls: 0.0026, rpn_box: 0.0020, rcnn_cls: 0.0528, rcnn_box 0.0264
# [session 1][epoch  5][iter 1100/1916] loss: 0.1363, lr: 1.00e-03
# 			fg/bg=(216/808), time cost: 96.712972
# 			rpn_cls: 0.0008, rpn_box: 0.0016, rcnn_cls: 0.0377, rcnn_box 0.0306
# [session 1][epoch  5][iter 1200/1916] loss: 0.1221, lr: 1.00e-03
# 			fg/bg=(196/828), time cost: 96.886313
# 			rpn_cls: 0.0015, rpn_box: 0.0013, rcnn_cls: 0.0847, rcnn_box 0.0195
# [session 1][epoch  5][iter 1300/1916] loss: 0.1154, lr: 1.00e-03
# 			fg/bg=(205/819), time cost: 96.579367
# 			rpn_cls: 0.0029, rpn_box: 0.0043, rcnn_cls: 0.1315, rcnn_box 0.0431
# [session 1][epoch  5][iter 1400/1916] loss: 0.1270, lr: 1.00e-03
# 			fg/bg=(203/821), time cost: 96.557899
# 			rpn_cls: 0.0013, rpn_box: 0.0027, rcnn_cls: 0.1367, rcnn_box 0.0351
# [session 1][epoch  5][iter 1500/1916] loss: 0.1125, lr: 1.00e-03
# 			fg/bg=(195/829), time cost: 96.699498
# 			rpn_cls: 0.0007, rpn_box: 0.0009, rcnn_cls: 0.0388, rcnn_box 0.0166
# [session 1][epoch  5][iter 1600/1916] loss: 0.1290, lr: 1.00e-03
# 			fg/bg=(196/828), time cost: 96.690628
# 			rpn_cls: 0.0094, rpn_box: 0.0025, rcnn_cls: 0.0427, rcnn_box 0.0222
# [session 1][epoch  5][iter 1700/1916] loss: 0.1241, lr: 1.00e-03
# 			fg/bg=(182/842), time cost: 96.730444
# 			rpn_cls: 0.0028, rpn_box: 0.0018, rcnn_cls: 0.0587, rcnn_box 0.0185
# [session 1][epoch  5][iter 1800/1916] loss: 0.1329, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 96.768131
# 			rpn_cls: 0.0005, rpn_box: 0.0024, rcnn_cls: 0.0480, rcnn_box 0.0332
# [session 1][epoch  5][iter 1900/1916] loss: 0.1334, lr: 1.00e-03
# 			fg/bg=(217/807), time cost: 96.836466
# 			rpn_cls: 0.0015, rpn_box: 0.0048, rcnn_cls: 0.0711, rcnn_box 0.0397
# [session 1][epoch  6][iter    0/1916] loss: 0.0488, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 1.777593
# 			rpn_cls: 0.0092, rpn_box: 0.0017, rcnn_cls: 0.0215, rcnn_box 0.0163
# [session 1][epoch  6][iter  100/1916] loss: 0.0943, lr: 1.00e-04
# 			fg/bg=(207/817), time cost: 96.706188
# 			rpn_cls: 0.0076, rpn_box: 0.0022, rcnn_cls: 0.1077, rcnn_box 0.0221
# [session 1][epoch  6][iter  200/1916] loss: 0.0971, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.692729
# 			rpn_cls: 0.0015, rpn_box: 0.0010, rcnn_cls: 0.1065, rcnn_box 0.0182
# [session 1][epoch  6][iter  300/1916] loss: 0.0884, lr: 1.00e-04
# 			fg/bg=(236/788), time cost: 96.473673
# 			rpn_cls: 0.0200, rpn_box: 0.0053, rcnn_cls: 0.0477, rcnn_box 0.0369
# [session 1][epoch  6][iter  400/1916] loss: 0.0907, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.660208
# 			rpn_cls: 0.0013, rpn_box: 0.0021, rcnn_cls: 0.0184, rcnn_box 0.0136
# [session 1][epoch  6][iter  500/1916] loss: 0.0900, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 96.680394
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.0268, rcnn_box 0.0201
# [session 1][epoch  6][iter  600/1916] loss: 0.0873, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.685610
# 			rpn_cls: 0.0005, rpn_box: 0.0015, rcnn_cls: 0.0407, rcnn_box 0.0155
# [session 1][epoch  6][iter  700/1916] loss: 0.0924, lr: 1.00e-04
# 			fg/bg=(194/830), time cost: 96.734741
# 			rpn_cls: 0.0006, rpn_box: 0.0014, rcnn_cls: 0.0390, rcnn_box 0.0149
# [session 1][epoch  6][iter  800/1916] loss: 0.0985, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.632933
# 			rpn_cls: 0.0006, rpn_box: 0.0010, rcnn_cls: 0.1258, rcnn_box 0.0179
# [session 1][epoch  6][iter  900/1916] loss: 0.0939, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.659976
# 			rpn_cls: 0.0024, rpn_box: 0.0007, rcnn_cls: 0.0363, rcnn_box 0.0116
# [session 1][epoch  6][iter 1000/1916] loss: 0.1013, lr: 1.00e-04
# 			fg/bg=(232/792), time cost: 96.718414
# 			rpn_cls: 0.0006, rpn_box: 0.0047, rcnn_cls: 0.0692, rcnn_box 0.0333
# [session 1][epoch  6][iter 1100/1916] loss: 0.0901, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.580974
# 			rpn_cls: 0.0006, rpn_box: 0.0013, rcnn_cls: 0.0656, rcnn_box 0.0190
# [session 1][epoch  6][iter 1200/1916] loss: 0.0852, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.500475
# 			rpn_cls: 0.0004, rpn_box: 0.0007, rcnn_cls: 0.0357, rcnn_box 0.0100
# [session 1][epoch  6][iter 1300/1916] loss: 0.0899, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.673623
# 			rpn_cls: 0.0051, rpn_box: 0.0016, rcnn_cls: 0.1688, rcnn_box 0.0287
# [session 1][epoch  6][iter 1400/1916] loss: 0.0906, lr: 1.00e-04
# 			fg/bg=(196/828), time cost: 96.823337
# 			rpn_cls: 0.0003, rpn_box: 0.0006, rcnn_cls: 0.1403, rcnn_box 0.0177
# [session 1][epoch  6][iter 1500/1916] loss: 0.0897, lr: 1.00e-04
# 			fg/bg=(236/788), time cost: 96.655836
# 			rpn_cls: 0.0021, rpn_box: 0.0037, rcnn_cls: 0.0425, rcnn_box 0.0244
# [session 1][epoch  6][iter 1600/1916] loss: 0.0959, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.800095
# 			rpn_cls: 0.0004, rpn_box: 0.0019, rcnn_cls: 0.0377, rcnn_box 0.0173
# [session 1][epoch  6][iter 1700/1916] loss: 0.0973, lr: 1.00e-04
# 			fg/bg=(225/799), time cost: 96.767027
# 			rpn_cls: 0.0028, rpn_box: 0.0028, rcnn_cls: 0.0648, rcnn_box 0.0222
# [session 1][epoch  6][iter 1800/1916] loss: 0.0903, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.765689
# 			rpn_cls: 0.0007, rpn_box: 0.0014, rcnn_cls: 0.1661, rcnn_box 0.0148
# [session 1][epoch  6][iter 1900/1916] loss: 0.0914, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.660358
# 			rpn_cls: 0.0062, rpn_box: 0.0040, rcnn_cls: 0.0544, rcnn_box 0.0389
# [session 1][epoch  7][iter    0/1916] loss: 0.0638, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 1.604293
# 			rpn_cls: 0.0021, rpn_box: 0.0019, rcnn_cls: 0.0415, rcnn_box 0.0182
# [session 1][epoch  7][iter  100/1916] loss: 0.0906, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.629017
# 			rpn_cls: 0.0003, rpn_box: 0.0009, rcnn_cls: 0.0377, rcnn_box 0.0170
# [session 1][epoch  7][iter  200/1916] loss: 0.0878, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.609426
# 			rpn_cls: 0.0035, rpn_box: 0.0011, rcnn_cls: 0.1341, rcnn_box 0.0205
# [session 1][epoch  7][iter  300/1916] loss: 0.0797, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.341226
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.0818, rcnn_box 0.0100
# [session 1][epoch  7][iter  400/1916] loss: 0.0911, lr: 1.00e-04
# 			fg/bg=(190/834), time cost: 96.735735
# 			rpn_cls: 0.0037, rpn_box: 0.0013, rcnn_cls: 0.0365, rcnn_box 0.0113
# [session 1][epoch  7][iter  500/1916] loss: 0.0847, lr: 1.00e-04
# 			fg/bg=(202/822), time cost: 96.645991
# 			rpn_cls: 0.0007, rpn_box: 0.0011, rcnn_cls: 0.0343, rcnn_box 0.0126
# [session 1][epoch  7][iter  600/1916] loss: 0.0868, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.723291
# 			rpn_cls: 0.0065, rpn_box: 0.0022, rcnn_cls: 0.0313, rcnn_box 0.0221
# [session 1][epoch  7][iter  700/1916] loss: 0.0848, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 96.686136
# 			rpn_cls: 0.0004, rpn_box: 0.0010, rcnn_cls: 0.0401, rcnn_box 0.0398
# [session 1][epoch  7][iter  800/1916] loss: 0.0888, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.919255
# 			rpn_cls: 0.0003, rpn_box: 0.0007, rcnn_cls: 0.0273, rcnn_box 0.0130
# [session 1][epoch  7][iter  900/1916] loss: 0.0833, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.816782
# 			rpn_cls: 0.0040, rpn_box: 0.0008, rcnn_cls: 0.0766, rcnn_box 0.0181
# [session 1][epoch  7][iter 1000/1916] loss: 0.0864, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.700994
# 			rpn_cls: 0.0045, rpn_box: 0.0008, rcnn_cls: 0.0273, rcnn_box 0.0209
# [session 1][epoch  7][iter 1100/1916] loss: 0.0832, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.900393
# 			rpn_cls: 0.0019, rpn_box: 0.0012, rcnn_cls: 0.0248, rcnn_box 0.0132
# [session 1][epoch  7][iter 1200/1916] loss: 0.0877, lr: 1.00e-04
# 			fg/bg=(207/817), time cost: 96.780578
# 			rpn_cls: 0.0003, rpn_box: 0.0008, rcnn_cls: 0.0227, rcnn_box 0.0138
# [session 1][epoch  7][iter 1300/1916] loss: 0.0852, lr: 1.00e-04
# 			fg/bg=(200/824), time cost: 96.887297
# 			rpn_cls: 0.0009, rpn_box: 0.0017, rcnn_cls: 0.0255, rcnn_box 0.0165
# [session 1][epoch  7][iter 1400/1916] loss: 0.0915, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.625105
# 			rpn_cls: 0.0004, rpn_box: 0.0026, rcnn_cls: 0.0723, rcnn_box 0.0308
# [session 1][epoch  7][iter 1500/1916] loss: 0.0859, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.758309
# 			rpn_cls: 0.0007, rpn_box: 0.0012, rcnn_cls: 0.0399, rcnn_box 0.0309
# [session 1][epoch  7][iter 1600/1916] loss: 0.0874, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.782453
# 			rpn_cls: 0.0013, rpn_box: 0.0016, rcnn_cls: 0.0371, rcnn_box 0.0295
# [session 1][epoch  7][iter 1700/1916] loss: 0.0874, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.794928
# 			rpn_cls: 0.0003, rpn_box: 0.0014, rcnn_cls: 0.1162, rcnn_box 0.0174
# [session 1][epoch  7][iter 1800/1916] loss: 0.0851, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.891839
# 			rpn_cls: 0.0077, rpn_box: 0.0017, rcnn_cls: 0.0345, rcnn_box 0.0195
# [session 1][epoch  7][iter 1900/1916] loss: 0.0857, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.877209
# 			rpn_cls: 0.0011, rpn_box: 0.0032, rcnn_cls: 0.0346, rcnn_box 0.0298
# [session 1][epoch  8][iter    0/1916] loss: 0.1606, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 1.298955
# 			rpn_cls: 0.0024, rpn_box: 0.0020, rcnn_cls: 0.1316, rcnn_box 0.0247
# [session 1][epoch  8][iter  100/1916] loss: 0.0888, lr: 1.00e-04
# 			fg/bg=(230/794), time cost: 96.842824
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.1010, rcnn_box 0.0297
# [session 1][epoch  8][iter  200/1916] loss: 0.0889, lr: 1.00e-04
# 			fg/bg=(220/804), time cost: 96.698533
# 			rpn_cls: 0.0006, rpn_box: 0.0011, rcnn_cls: 0.0273, rcnn_box 0.0128
# [session 1][epoch  8][iter  300/1916] loss: 0.0809, lr: 1.00e-04
# 			fg/bg=(237/787), time cost: 96.730889
# 			rpn_cls: 0.0004, rpn_box: 0.0039, rcnn_cls: 0.0341, rcnn_box 0.0316
# [session 1][epoch  8][iter  400/1916] loss: 0.0827, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.724160
# 			rpn_cls: 0.0085, rpn_box: 0.0014, rcnn_cls: 0.0429, rcnn_box 0.0103
# [session 1][epoch  8][iter  500/1916] loss: 0.0759, lr: 1.00e-04
# 			fg/bg=(223/801), time cost: 96.852488
# 			rpn_cls: 0.0007, rpn_box: 0.0021, rcnn_cls: 0.0545, rcnn_box 0.0233
# [session 1][epoch  8][iter  600/1916] loss: 0.0782, lr: 1.00e-04
# 			fg/bg=(228/796), time cost: 96.867310
# 			rpn_cls: 0.0004, rpn_box: 0.0012, rcnn_cls: 0.0821, rcnn_box 0.0157
# [session 1][epoch  8][iter  700/1916] loss: 0.0874, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.827909
# 			rpn_cls: 0.0032, rpn_box: 0.0010, rcnn_cls: 0.0526, rcnn_box 0.0113
# [session 1][epoch  8][iter  800/1916] loss: 0.0752, lr: 1.00e-04
# 			fg/bg=(202/822), time cost: 96.729121
# 			rpn_cls: 0.0056, rpn_box: 0.0012, rcnn_cls: 0.0312, rcnn_box 0.0168
# [session 1][epoch  8][iter  900/1916] loss: 0.0838, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.683458
# 			rpn_cls: 0.0004, rpn_box: 0.0008, rcnn_cls: 0.0233, rcnn_box 0.0130
# [session 1][epoch  8][iter 1000/1916] loss: 0.0818, lr: 1.00e-04
# 			fg/bg=(213/811), time cost: 96.786333
# 			rpn_cls: 0.0010, rpn_box: 0.0009, rcnn_cls: 0.0277, rcnn_box 0.0130
# [session 1][epoch  8][iter 1100/1916] loss: 0.0826, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.847234
# 			rpn_cls: 0.0006, rpn_box: 0.0017, rcnn_cls: 0.0390, rcnn_box 0.0300
# [session 1][epoch  8][iter 1200/1916] loss: 0.0891, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.834133
# 			rpn_cls: 0.0017, rpn_box: 0.0012, rcnn_cls: 0.1890, rcnn_box 0.0139
# [session 1][epoch  8][iter 1300/1916] loss: 0.0814, lr: 1.00e-04
# 			fg/bg=(192/832), time cost: 96.585294
# 			rpn_cls: 0.0024, rpn_box: 0.0015, rcnn_cls: 0.0296, rcnn_box 0.0188
# [session 1][epoch  8][iter 1400/1916] loss: 0.0824, lr: 1.00e-04
# 			fg/bg=(185/839), time cost: 96.739574
# 			rpn_cls: 0.0003, rpn_box: 0.0010, rcnn_cls: 0.0337, rcnn_box 0.0165
# [session 1][epoch  8][iter 1500/1916] loss: 0.0907, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.809834
# 			rpn_cls: 0.0124, rpn_box: 0.0029, rcnn_cls: 0.1309, rcnn_box 0.0373
# [session 1][epoch  8][iter 1600/1916] loss: 0.0810, lr: 1.00e-04
# 			fg/bg=(193/831), time cost: 96.814861
# 			rpn_cls: 0.0005, rpn_box: 0.0011, rcnn_cls: 0.0470, rcnn_box 0.0160
# [session 1][epoch  8][iter 1700/1916] loss: 0.0883, lr: 1.00e-04
# 			fg/bg=(202/822), time cost: 96.981941
# 			rpn_cls: 0.0031, rpn_box: 0.0019, rcnn_cls: 0.1463, rcnn_box 0.0267
# [session 1][epoch  8][iter 1800/1916] loss: 0.0821, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.814232
# 			rpn_cls: 0.0003, rpn_box: 0.0007, rcnn_cls: 0.0283, rcnn_box 0.0162
# [session 1][epoch  8][iter 1900/1916] loss: 0.0792, lr: 1.00e-04
# 			fg/bg=(227/797), time cost: 96.825947
# 			rpn_cls: 0.0018, rpn_box: 0.0012, rcnn_cls: 0.0512, rcnn_box 0.0275
# [session 1][epoch  9][iter    0/1916] loss: 0.2086, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 1.327371
# 			rpn_cls: 0.0184, rpn_box: 0.0029, rcnn_cls: 0.1519, rcnn_box 0.0354
# [session 1][epoch  9][iter  100/1916] loss: 0.0829, lr: 1.00e-04
# 			fg/bg=(221/803), time cost: 96.994904
# 			rpn_cls: 0.0003, rpn_box: 0.0011, rcnn_cls: 0.1292, rcnn_box 0.0184
# [session 1][epoch  9][iter  200/1916] loss: 0.0808, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.796422
# 			rpn_cls: 0.0003, rpn_box: 0.0011, rcnn_cls: 0.0395, rcnn_box 0.0343
# [session 1][epoch  9][iter  300/1916] loss: 0.0722, lr: 1.00e-04
# 			fg/bg=(209/815), time cost: 96.751173
# 			rpn_cls: 0.0003, rpn_box: 0.0010, rcnn_cls: 0.1467, rcnn_box 0.0127
# [session 1][epoch  9][iter  400/1916] loss: 0.0788, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 96.711077
# 			rpn_cls: 0.0009, rpn_box: 0.0017, rcnn_cls: 0.0461, rcnn_box 0.0272
# [session 1][epoch  9][iter  500/1916] loss: 0.0788, lr: 1.00e-04
# 			fg/bg=(207/817), time cost: 96.700556
# 			rpn_cls: 0.0215, rpn_box: 0.0022, rcnn_cls: 0.0660, rcnn_box 0.0345
# [session 1][epoch  9][iter  600/1916] loss: 0.0822, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 96.824313
# 			rpn_cls: 0.0002, rpn_box: 0.0004, rcnn_cls: 0.0353, rcnn_box 0.0161
# [session 1][epoch  9][iter  700/1916] loss: 0.0790, lr: 1.00e-04
# 			fg/bg=(195/829), time cost: 96.813663
# 			rpn_cls: 0.0003, rpn_box: 0.0014, rcnn_cls: 0.0292, rcnn_box 0.0095
# [session 1][epoch  9][iter  800/1916] loss: 0.0790, lr: 1.00e-04
# 			fg/bg=(192/832), time cost: 96.944853
# 			rpn_cls: 0.0084, rpn_box: 0.0016, rcnn_cls: 0.0542, rcnn_box 0.0204
# [session 1][epoch  9][iter  900/1916] loss: 0.0883, lr: 1.00e-04
# 			fg/bg=(205/819), time cost: 96.775309
# 			rpn_cls: 0.0003, rpn_box: 0.0026, rcnn_cls: 0.0309, rcnn_box 0.0106
# [session 1][epoch  9][iter 1000/1916] loss: 0.0789, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.803832
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.0674, rcnn_box 0.0188
# [session 1][epoch  9][iter 1100/1916] loss: 0.0728, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.835839
# 			rpn_cls: 0.0005, rpn_box: 0.0009, rcnn_cls: 0.0791, rcnn_box 0.0188
# [session 1][epoch  9][iter 1200/1916] loss: 0.0858, lr: 1.00e-04
# 			fg/bg=(209/815), time cost: 96.790215
# 			rpn_cls: 0.0005, rpn_box: 0.0020, rcnn_cls: 0.0477, rcnn_box 0.0186
# [session 1][epoch  9][iter 1300/1916] loss: 0.0814, lr: 1.00e-04
# 			fg/bg=(226/798), time cost: 96.643500
# 			rpn_cls: 0.0005, rpn_box: 0.0010, rcnn_cls: 0.1186, rcnn_box 0.0178
# [session 1][epoch  9][iter 1400/1916] loss: 0.0713, lr: 1.00e-04
# 			fg/bg=(225/799), time cost: 96.823574
# 			rpn_cls: 0.0004, rpn_box: 0.0014, rcnn_cls: 0.0219, rcnn_box 0.0245
# [session 1][epoch  9][iter 1500/1916] loss: 0.0751, lr: 1.00e-04
# 			fg/bg=(208/816), time cost: 96.683881
# 			rpn_cls: 0.0004, rpn_box: 0.0007, rcnn_cls: 0.0260, rcnn_box 0.0088
# [session 1][epoch  9][iter 1600/1916] loss: 0.0839, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.858317
# 			rpn_cls: 0.0043, rpn_box: 0.0014, rcnn_cls: 0.0403, rcnn_box 0.0247
# [session 1][epoch  9][iter 1700/1916] loss: 0.0783, lr: 1.00e-04
# 			fg/bg=(198/826), time cost: 96.853772
# 			rpn_cls: 0.0157, rpn_box: 0.0008, rcnn_cls: 0.0222, rcnn_box 0.0119
# [session 1][epoch  9][iter 1800/1916] loss: 0.0831, lr: 1.00e-04
# 			fg/bg=(212/812), time cost: 96.730116
# 			rpn_cls: 0.0003, rpn_box: 0.0008, rcnn_cls: 0.1307, rcnn_box 0.0179
# [session 1][epoch  9][iter 1900/1916] loss: 0.0821, lr: 1.00e-04
# 			fg/bg=(206/818), time cost: 96.714349
# 			rpn_cls: 0.0048, rpn_box: 0.0024, rcnn_cls: 0.0475, rcnn_box 0.0197
# [session 1][epoch 10][iter    0/1916] loss: 0.0368, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 1.315090
# 			rpn_cls: 0.0010, rpn_box: 0.0007, rcnn_cls: 0.0250, rcnn_box 0.0101
# [session 1][epoch 10][iter  100/1916] loss: 0.0736, lr: 1.00e-04
# 			fg/bg=(199/825), time cost: 96.824938
# 			rpn_cls: 0.0012, rpn_box: 0.0012, rcnn_cls: 0.0209, rcnn_box 0.0147
# [session 1][epoch 10][iter  200/1916] loss: 0.0707, lr: 1.00e-04
# 			fg/bg=(218/806), time cost: 96.754052
# 			rpn_cls: 0.0006, rpn_box: 0.0022, rcnn_cls: 0.0355, rcnn_box 0.0179
# [session 1][epoch 10][iter  300/1916] loss: 0.0835, lr: 1.00e-04
# 			fg/bg=(201/823), time cost: 96.800469
# 			rpn_cls: 0.0008, rpn_box: 0.0014, rcnn_cls: 0.0354, rcnn_box 0.0227
# [session 1][epoch 10][iter  400/1916] loss: 0.0753, lr: 1.00e-04
# 			fg/bg=(204/820), time cost: 96.748572
# 			rpn_cls: 0.0003, rpn_box: 0.0018, rcnn_cls: 0.1416, rcnn_box 0.0334
# [session 1][epoch 10][iter  500/1916] loss: 0.0822, lr: 1.00e-04
# 			fg/bg=(217/807), time cost: 96.746202
# 			rpn_cls: 0.0009, rpn_box: 0.0020, rcnn_cls: 0.0869, rcnn_box 0.0157
# [session 1][epoch 10][iter  600/1916] loss: 0.0773, lr: 1.00e-04
# 			fg/bg=(209/815), time cost: 96.642094
# 			rpn_cls: 0.0004, rpn_box: 0.0011, rcnn_cls: 0.0403, rcnn_box 0.0140
# [session 1][epoch 10][iter  700/1916] loss: 0.0776, lr: 1.00e-04
# 			fg/bg=(216/808), time cost: 96.692655
# 			rpn_cls: 0.0006, rpn_box: 0.0008, rcnn_cls: 0.0264, rcnn_box 0.0156
# [session 1][epoch 10][iter  800/1916] loss: 0.0695, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 96.733047
# 			rpn_cls: 0.0003, rpn_box: 0.0011, rcnn_cls: 0.0285, rcnn_box 0.0135
# [session 1][epoch 10][iter  900/1916] loss: 0.0807, lr: 1.00e-04
# 			fg/bg=(227/797), time cost: 96.724082
# 			rpn_cls: 0.0060, rpn_box: 0.0012, rcnn_cls: 0.0473, rcnn_box 0.0240
# [session 1][epoch 10][iter 1000/1916] loss: 0.0769, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.621865
# 			rpn_cls: 0.0019, rpn_box: 0.0010, rcnn_cls: 0.0226, rcnn_box 0.0136
# [session 1][epoch 10][iter 1100/1916] loss: 0.0786, lr: 1.00e-04
# 			fg/bg=(214/810), time cost: 96.902507
# 			rpn_cls: 0.0011, rpn_box: 0.0021, rcnn_cls: 0.0353, rcnn_box 0.0283
# [session 1][epoch 10][iter 1200/1916] loss: 0.0758, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.879951
# 			rpn_cls: 0.0031, rpn_box: 0.0018, rcnn_cls: 0.0513, rcnn_box 0.0268
# [session 1][epoch 10][iter 1300/1916] loss: 0.0740, lr: 1.00e-04
# 			fg/bg=(215/809), time cost: 96.827869
# 			rpn_cls: 0.0004, rpn_box: 0.0012, rcnn_cls: 0.0286, rcnn_box 0.0201
# [session 1][epoch 10][iter 1400/1916] loss: 0.0687, lr: 1.00e-04
# 			fg/bg=(197/827), time cost: 96.917161
# 			rpn_cls: 0.0035, rpn_box: 0.0017, rcnn_cls: 0.0256, rcnn_box 0.0193
# [session 1][epoch 10][iter 1500/1916] loss: 0.0731, lr: 1.00e-04
# 			fg/bg=(203/821), time cost: 97.209807
# 			rpn_cls: 0.0004, rpn_box: 0.0016, rcnn_cls: 0.1658, rcnn_box 0.0323
# [session 1][epoch 10][iter 1600/1916] loss: 0.0779, lr: 1.00e-04
# 			fg/bg=(220/804), time cost: 96.554432
# 			rpn_cls: 0.0049, rpn_box: 0.0017, rcnn_cls: 0.0307, rcnn_box 0.0352
# [session 1][epoch 10][iter 1700/1916] loss: 0.0739, lr: 1.00e-04
# 			fg/bg=(211/813), time cost: 96.041281
# 			rpn_cls: 0.0057, rpn_box: 0.0021, rcnn_cls: 0.0482, rcnn_box 0.0190
# [session 1][epoch 10][iter 1800/1916] loss: 0.0770, lr: 1.00e-04
# 			fg/bg=(210/814), time cost: 95.981322
# 			rpn_cls: 0.0004, rpn_box: 0.0009, rcnn_cls: 0.0125, rcnn_box 0.0114
# [session 1][epoch 10][iter 1900/1916] loss: 0.0789, lr: 1.00e-04
# 			fg/bg=(233/791), time cost: 96.039274
# 			rpn_cls: 0.0004, rpn_box: 0.0018, rcnn_cls: 0.0482, rcnn_box 0.0240
# save model: models/res101/Race/faster_rcnn_1_10_1915.pth

# %%
# !CUDA_VISIBLE_DEVICES=0 python demo.py --net vgg16 --dataset Race  --checksession 1  --checkepoch 10 \
                --checkpoint 957  --cuda --load_dir models
# Out:
# Called with args:
# Namespace(batch_size=1, cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Race', image_dir='images', load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False, webcam_num=-1)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# load model successfully!
# load checkpoint models/vgg16/Race/faster_rcnn_1_10_957.pth
# demo.py:234: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_data = Variable(im_data, volatile=True)
# demo.py:235: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   im_info = Variable(im_info, volatile=True)
# demo.py:236: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   num_boxes = Variable(num_boxes, volatile=True)
# demo.py:237: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   gt_boxes = Variable(gt_boxes, volatile=True)
# Loaded Photo: 8 images.
# demo.py:279: DeprecationWarning:     `imread` is deprecated!
#     `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
#     Use ``imageio.imread`` instead.
#   im_in = np.array(imread(im_file))
# /root/miniconda3/lib/python3.7/site-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# im_detect: 0/8 0.323s 0.007s

# %%
# !python test_net.py --dataset Gender --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Gender', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Gender` for training
# Set proposal method: gt
# Preparing training data...
# wrote gt roidb to /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Gender_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Gender/faster_rcnn_1_10_957.pth
# load model successfully!
# Evaluating detections0.315s 0.002s
# Writing male VOC results file
# Writing female VOC results file
# Writing unsure VOC results file
# VOC07 metric? Yes
# Reading annotation for 1/3067
# Reading annotation for 101/3067
# Reading annotation for 201/3067
# Reading annotation for 301/3067
# Reading annotation for 401/3067
# Reading annotation for 501/3067
# Reading annotation for 601/3067
# Reading annotation for 701/3067
# Reading annotation for 801/3067
# Reading annotation for 901/3067
# Reading annotation for 1001/3067
# Reading annotation for 1101/3067
# Reading annotation for 1201/3067
# Reading annotation for 1301/3067
# Reading annotation for 1401/3067
# Reading annotation for 1501/3067
# Reading annotation for 1601/3067
# Reading annotation for 1701/3067
# Reading annotation for 1801/3067
# Reading annotation for 1901/3067
# Reading annotation for 2001/3067
# Reading annotation for 2101/3067
# Reading annotation for 2201/3067
# Reading annotation for 2301/3067
# Reading annotation for 2401/3067
# Reading annotation for 2501/3067
# Reading annotation for 2601/3067
# Reading annotation for 2701/3067
# Reading annotation for 2801/3067
# Reading annotation for 2901/3067
# Reading annotation for 3001/3067
# Saving cached annotations to /mnt/FasterRCNN/faster-rcnn.pytorch/data/Gender/ImageSets/Main/test.txt_annots.pkl
# AP for male = 0.8504
# AP for female = 0.8568
# AP for unsure = 0.6992
# Mean AP = 0.8021
# ~~~~~~~~
# Results:
# 0.850
# 0.857
# 0.699
# 0.802
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# test time: 1132.3115s

# %%
# !python test_net.py --dataset Emotion --net vgg16 --checksession 1 --checkepoch 10 --checkpoint 957 --cuda
# Out:
# Called with args:
# Namespace(cfg_file='cfgs/vgg16.yml', checkepoch=10, checkpoint=957, checksession=1, class_agnostic=False, cuda=True, dataset='Emotion', large_scale=False, load_dir='models', mGPUs=False, net='vgg16', parallel_type=0, set_cfgs=None, vis=False)
# /mnt/FasterRCNN/faster-rcnn.pytorch/lib/model/utils/config.py:374: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   yaml_cfg = edict(yaml.load(f))
# Using config:
# {'ANCHOR_RATIOS': [0.5, 1, 2],
#  'ANCHOR_SCALES': [8, 16, 32],
#  'CROP_RESIZE_WITH_MAX_POOL': False,
#  'CUDA': False,
#  'DATA_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'vgg16',
#  'FEAT_STRIDE': [16],
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MAX_NUM_GT_BOXES': 20,
#  'MOBILENET': {'DEPTH_MULTIPLIER': 1.0,
#                'FIXED_LAYERS': 5,
#                'REGU_DEPTH': False,
#                'WEIGHT_DECAY': 4e-05},
#  'PIXEL_MEANS': array([[[102.9801, 115.9465, 122.7717]]]),
#  'POOLING_MODE': 'align',
#  'POOLING_SIZE': 7,
#  'RESNET': {'FIXED_BLOCKS': 1, 'MAX_POOL': False},
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/mnt/FasterRCNN/faster-rcnn.pytorch',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'MODE': 'nms',
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'gt',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'RPN_TOP_N': 5000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': False,
#            'BATCH_SIZE': 256,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': True,
#            'BBOX_REG': True,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'BIAS_DECAY': False,
#            'BN_TRAIN': False,
#            'DISPLAY': 10,
#            'DOUBLE_BIAS': True,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'GAMMA': 0.1,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'LEARNING_RATE': 0.01,
#            'MAX_SIZE': 1000,
#            'MOMENTUM': 0.9,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 8,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_ITERS': 5000,
#            'SNAPSHOT_KEPT': 3,
#            'SNAPSHOT_PREFIX': 'res101_faster_rcnn',
#            'STEPSIZE': [30000],
#            'SUMMARY_INTERVAL': 180,
#            'TRIM_HEIGHT': 600,
#            'TRIM_WIDTH': 600,
#            'TRUNCATED': False,
#            'USE_ALL_GT': True,
#            'USE_FLIPPED': True,
#            'USE_GT': False,
#            'WEIGHT_DECAY': 0.0005},
#  'USE_GPU_NMS': True}
# Loaded dataset `Emotion` for training
# Set proposal method: gt
# Preparing training data...
# Emotion gt roidb loaded from /mnt/FasterRCNN/faster-rcnn.pytorch/data/cache/Emotion_gt_roidb.pkl
# done
# 3067 roidb entries
# load checkpoint models/vgg16/Emotion/faster_rcnn_1_10_957.pth
# load model successfully!
# ^C
# Traceback (most recent call last):
#   File "test_net.py", line 213, in <module>
#     fasterRCNN.cuda()
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in cuda
#     return self._apply(lambda t: t.cuda(device))
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 530, in _apply
#     module._apply(fn)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 552, in _apply
#     param_applied = fn(param)
#   File "/root/miniconda3/lib/python3.7/site-packages/torch/nn/modules/module.py", line 637, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
# KeyboardInterrupt
